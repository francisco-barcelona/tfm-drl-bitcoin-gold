# %% [markdown]
# Descàrrega de dades de Bitcoin i Or

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17358, 6)
# GLD shape: (5074, 6)

# %% [markdown]
# Neteja de columnes multi índex

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)

btc.head(), gld.head()
# Out:
# (Price                         Adj Close         Close          High  \
#  Datetime
#  2024-04-07 00:00:00+00:00  69015.179688  69015.179688  69138.554688
#  2024-04-07 01:00:00+00:00  69572.406250  69572.406250  69608.593750
#  2024-04-07 02:00:00+00:00  69335.773438  69335.773438  69755.031250
#  2024-04-07 03:00:00+00:00  69431.601562  69431.601562  69502.390625
#  2024-04-07 04:00:00+00:00  69344.093750  69344.093750  69513.187500
#
#  Price                               Low          Open     Volume
#  Datetime
#  2024-04-07 00:00:00+00:00  68853.890625  68905.921875          0
#  2024-04-07 01:00:00+00:00  69021.453125  69021.453125  419897344
#  2024-04-07 02:00:00+00:00  69335.773438  69566.054688   84342784
#  2024-04-07 03:00:00+00:00  69269.484375  69329.781250   45486080
#  2024-04-07 04:00:00+00:00  69112.992188  69433.171875  162998272  ,
#  Price                       Adj Close       Close        High         Low  \
#  Datetime
#  2023-05-08 13:30:00+00:00  188.089996  188.089996  188.179993  187.490005
#  2023-05-08 14:30:00+00:00  188.339996  188.339996  188.429993  187.949997
#  2023-05-08 15:30:00+00:00  188.360001  188.360001  188.669998  188.270004
#  2023-05-08 16:30:00+00:00  188.199997  188.199997  188.460007  188.179993
#  2023-05-08 17:30:00+00:00  187.900101  187.900101  188.199997  187.735001
#
#  Price                            Open   Volume
#  Datetime
#  2023-05-08 13:30:00+00:00  187.820007  1464660
#  2023-05-08 14:30:00+00:00  188.080002  1024799
#  2023-05-08 15:30:00+00:00  188.330002   960078
#  2023-05-08 16:30:00+00:00  188.350006   523767
#  2023-05-08 17:30:00+00:00  188.199997   866617  )

# %% [markdown]
# Verificació ràpida

# %%
print(btc.columns)
print(gld.columns)
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %% [markdown]
# Sincronització de dades de Bitcoin i Or.
# Rang de dates coherent (Bitcoin funciona 24 hores, però l'or no).
# Normalitzar timestamps a inici d'hora.
# Renombrar columnes.

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")

btc_1h.columns.name = None
gld_1h.columns.name = None

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})

print(btc_1h.head())
print(gld_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-04-07 00:00:00+00:00  69015.179688
# 2024-04-07 01:00:00+00:00  69572.406250
# 2024-04-07 02:00:00+00:00  69335.773438
# 2024-04-07 03:00:00+00:00  69431.601562
# 2024-04-07 04:00:00+00:00  69344.093750
#                             gld_close
# Datetime
# 2023-05-08 13:00:00+00:00  188.089996
# 2023-05-08 14:00:00+00:00  188.339996
# 2023-05-08 15:00:00+00:00  188.360001
# 2023-05-08 16:00:00+00:00  188.199997
# 2023-05-08 17:00:00+00:00  187.900101

# %% [markdown]
# Obtenir intersecció de dades

# %%
common_index = btc_1h.index.intersection(gld_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3444, 1)
# GLD sync shape: (3444, 1)
# Start: 2024-04-08 13:00:00+00:00
# End: 2026-04-06 16:00:00+00:00

# %% [markdown]
# Fusió de datasets de Bitcoin i Or

# %%
df = btc_sync.join(gld_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3444, 2)
#                               btc_close   gld_close
# Datetime
# 2024-04-08 13:00:00+00:00  71936.625000  215.324997
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004

# %% [markdown]
# Crear returns

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000   -0.003124    0.001974
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996    0.000652   -0.000742
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005    0.000061    0.001345
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004   -0.000650    0.004123
# 2024-04-08 18:00:00+00:00  71955.953125  216.559998    0.003341   -0.000969

# %% [markdown]
# Passar a 4 hores, resamplejant el dataset. Frame final.

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum"
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1151, 4)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 12:00:00+00:00  71758.664062  215.589996   -0.002472    0.001232
# 2024-04-08 16:00:00+00:00  71656.507812  216.475006   -0.001410    0.004107
# 2024-04-09 12:00:00+00:00  69157.882812  217.235001   -0.035167    0.003572
# 2024-04-09 16:00:00+00:00  69071.023438  217.663605   -0.001218    0.001976
# 2024-04-10 12:00:00+00:00  68634.343750  216.309998   -0.006228   -0.006228

# %% [markdown]
# Creació de features mínimes útils

# %%
df_4h["btc_ret_4h"] = df_4h["btc_close"].pct_change()
df_4h["gld_ret_4h"] = df_4h["gld_close"].pct_change()

df_4h["btc_vol_12"] = df_4h["btc_ret_4h"].rolling(12).std()
df_4h["gld_vol_12"] = df_4h["gld_ret_4h"].rolling(12).std()

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1139, 8)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312  221.139999   -0.025451    0.001010
# 2024-04-16 16:00:00+00:00  62777.230469  221.220001    0.013930    0.000366
# 2024-04-17 12:00:00+00:00  60446.308594  220.270004   -0.037492   -0.004296
# 2024-04-17 16:00:00+00:00  61150.746094  219.610001    0.011792   -0.002991
# 2024-04-18 12:00:00+00:00  63519.785156  220.740005    0.038442    0.005139
#
#                            btc_ret_4h  gld_ret_4h  btc_vol_12  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.000951    0.017926    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.000362    0.019254    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130   -0.004294    0.019521    0.007941
# 2024-04-17 16:00:00+00:00    0.011654   -0.002996    0.020439    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.005146    0.024826    0.007792

# %%
features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

df_model = df_4h[features].copy()

print(df_model.shape)
df_model.head()
# Out:
# (1139, 4)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.017926    0.000951    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.019254    0.000362    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130    0.019521   -0.004294    0.007941
# 2024-04-17 16:00:00+00:00    0.011654    0.020439   -0.002996    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.024826    0.005146    0.007792

# %%
env_df = df_4h[[
    "btc_close",
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12"
]].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1139, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Baseline només BTC

# %%
btc_features = ["btc_ret_4h", "btc_vol_12"]
env_btc = env_df[["btc_close"] + btc_features].copy()

print(env_btc.shape)
env_btc.head()
# Out:
# (1139, 3)
#                               btc_close  btc_ret_4h  btc_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826

# %% [markdown]
# Model amb senyal exògena (BTC + GLD)

# %%
btc_gld_features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]
env_btc_gld = env_df[["btc_close"] + btc_gld_features].copy()

print(env_btc_gld.shape)
env_btc_gld.head()
# Out:
# (1139, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Split de Train / Test

# %%
split_idx = int(len(env_df) * 0.8)

train_btc = env_btc.iloc[:split_idx].copy()
test_btc  = env_btc.iloc[split_idx:].copy()

train_btc_gld = env_btc_gld.iloc[:split_idx].copy()
test_btc_gld  = env_btc_gld.iloc[split_idx:].copy()

print("train_btc:", train_btc.shape)
print("test_btc:", test_btc.shape)
print("train_btc_gld:", train_btc_gld.shape)
print("test_btc_gld:", test_btc_gld.shape)
# Out:
# train_btc: (911, 3)
# test_btc: (228, 3)
# train_btc_gld: (911, 5)
# test_btc_gld: (228, 5)

# %% [markdown]
# Importació de l'entorn Gym

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_vol_penalty import TradingEnv

# %% [markdown]
# Crear entorn baseline

# %%
EXPERIMENT_NAME = "volatility_penalty"
REWARD_TYPE = "volatility_penalty"
TRANSACTION_COST = 0.0
TOTAL_TIMESTEPS = 50000
ALPHA = 0.1

print("Experiment:", EXPERIMENT_NAME)
print("Reward:", REWARD_TYPE)
print("Transaction cost:", TRANSACTION_COST)
print("Timesteps:", TOTAL_TIMESTEPS)
print("Alpha:", ALPHA)
# Out:
# Experiment: volatility_penalty
# Reward: volatility_penalty
# Transaction cost: 0.0
# Timesteps: 50000
# Alpha: 0.1

# %%
btc_feature_columns = ["btc_ret_4h", "btc_vol_12"]

env_train_btc_vol = TradingEnv(
    data=train_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=TRANSACTION_COST,
    reward_mode="volatility_penalty",
    volatility_column="btc_vol_12",
    alpha=ALPHA,
)

obs, info = env_train_btc_vol.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.02525732  0.01792642  0.        ]
# Observation shape: (3,)
# Info: {}

# %% [markdown]
# Test d'uns steps

# %%
obs, reward, done, truncated, info = env_train_btc_vol.step(1)  # long
print("Reward:", reward)
print("Done:", done)
print("Info:", info)

obs, reward, done, truncated, info = env_train_btc_vol.step(0)  # hold
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# Reward: 0.012138382948394883
# Done: False
# Info: {'step': 1, 'position': 1, 'asset_return': np.float64(0.013931024805929448), 'volatility': np.float64(0.017926418575345653)}
# Reward: -0.0390554873218743
# Done: False
# Info: {'step': 2, 'position': 1, 'asset_return': np.float64(-0.037130052689411275), 'volatility': np.float64(0.01925434632463021)}

# %% [markdown]
# Test de l'entorn amb GLD

# %%
btc_gld_feature_columns = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

env_train_btc_gld_vol = TradingEnv(
    data=train_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=TRANSACTION_COST,
    reward_mode="volatility_penalty",
    volatility_column="btc_vol_12",
    alpha=ALPHA,
)

obs, info = env_train_btc_gld_vol.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.02525732  0.01792642  0.00095056  0.00777943  0.        ]
# Observation shape: (5,)
# Info: {}

# %%
obs, reward, done, truncated, info = env_train_btc_gld_vol.step(1)
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# Reward: 0.012138382948394883
# Done: False
# Info: {'step': 1, 'position': 1, 'asset_return': np.float64(0.013931024805929448), 'volatility': np.float64(0.017926418575345653)}

# %% [markdown]
# Crear entorns de test

# %%
env_test_btc_vol = TradingEnv(
    data=test_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=TRANSACTION_COST,
    reward_mode="volatility_penalty",
    volatility_column="btc_vol_12",
    alpha=ALPHA,
)

env_test_btc_gld_vol = TradingEnv(
    data=test_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=TRANSACTION_COST,
    reward_mode="volatility_penalty",
    volatility_column="btc_vol_12",
    alpha=ALPHA,
)

# %% [markdown]
# Entrenaments amb PPO

# %%
from stable_baselines3 import PPO

# %% [markdown]
# Model de BTC

# %%
model_btc_vol = PPO(
    "MlpPolicy",
    env_train_btc_vol,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_vol.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 856 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0075631747 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -11.1        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00198      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00915     |
# |    value_loss           | 0.0709       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.007308379 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.388      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0017      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -0.676      |
# | time/                   |             |
# |    fps                  | 652         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.010194065 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0306      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -0.676        |
# | time/                   |               |
# |    fps                  | 643           |
# |    iterations           | 5             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 0.00029530306 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | -0.0109       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00303      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000578     |
# |    value_loss           | 0.00336       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -0.676       |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 6            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0066696936 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.00089     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0133       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 0.00357      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -0.676        |
# | time/                   |               |
# |    fps                  | 596           |
# |    iterations           | 7             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 1792          |
# | train/                  |               |
# |    approx_kl            | 0.00083641335 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | -0.00267      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00485      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000457     |
# |    value_loss           | 0.00272       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -0.966       |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0036834492 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00259      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00641     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -0.966      |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 9           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.013314235 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00691    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0407     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 0.00649     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -0.966       |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0055328878 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | -0.0211      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0339      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -0.917     |
# | time/                   |            |
# |    fps                  | 593        |
# |    iterations           | 11         |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.01065612 |
# |    clip_fraction        | 0.034      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.958     |
# |    explained_variance   | -0.00764   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00721   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00543   |
# |    value_loss           | 0.00322    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -0.917       |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 12           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0102127325 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.912       |
# |    explained_variance   | -0.0628      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00342      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 0.00276      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -0.917      |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 13          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.007084392 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00442     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -0.917      |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.008220281 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.00341     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00965    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 0.00159     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.14       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 15          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.008340941 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | -0.0068     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00326    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00644    |
# |    value_loss           | 0.000637    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.14       |
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010082063 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.00405     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00479    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 0.00529     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.14         |
# | time/                   |               |
# |    fps                  | 541           |
# |    iterations           | 17            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 0.00037784944 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.984        |
# |    explained_variance   | 0.00925       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00296      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00108      |
# |    value_loss           | 0.00274       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.22        |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 18           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0071649207 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.0282      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.4e-05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 0.00157      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.22        |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 19           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0071945004 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.00549     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0178      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00609     |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.22       |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 20          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.012082211 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00831     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 0.003       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.22        |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 21           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0016161227 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | -0.0159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00707     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000854    |
# |    value_loss           | 0.00213      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.37       |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 22          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.022571249 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0306     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 23           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0011293849 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.00484     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.007        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 0.00339      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 24           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0002982947 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0108      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000722     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000314    |
# |    value_loss           | 0.00423      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 25           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0015948594 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0202       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00309      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.00261      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 26           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0025484995 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0419      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00157     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.00245      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 27           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0117406985 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | -0.00476     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0122      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.51       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 28          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.012473494 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.0177     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0348     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 0.00293     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.47        |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 29           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 0.0020785464 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0133       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0177       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.00135      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.47        |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 30           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0030216458 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00822     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00398     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 0.00363      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.47       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 31          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.006056741 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0361      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 0.005       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.54       |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 32          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006808309 |
# |    clip_fraction        | 0.00547     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0646     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00928    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.54        |
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 33           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0026175585 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.0474      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00928      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 0.00246      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.54        |
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 34           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0017099569 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.00427     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00357     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000802    |
# |    value_loss           | 0.00484      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.54        |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 35           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0064119864 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00526     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0208      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 0.00285      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.52        |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 36           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0010852753 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00482      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000545    |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.00328      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.52       |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 37          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.007095798 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0341     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0117      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.52         |
# | time/                   |               |
# |    fps                  | 491           |
# |    iterations           | 38            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 0.00054453197 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1            |
# |    explained_variance   | -0.0273       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00622       |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 0.000138      |
# |    value_loss           | 0.00345       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.52       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 39          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.009555744 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.051       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.49       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 40          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002061361 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00779     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.49       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 41          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | 0.009411316 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0494     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00416    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 0.00367     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.49       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 42          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.013322554 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.000744   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.52       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 43          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.005565781 |
# |    clip_fraction        | 0.00703     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00599    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00922    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.52        |
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 44           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0013102698 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00354      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 0.0031       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -1.52      |
# | time/                   |            |
# |    fps                  | 489        |
# |    iterations           | 45         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 11520      |
# | train/                  |            |
# |    approx_kl            | 0.01510598 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.99      |
# |    explained_variance   | -0.00339   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0216    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0201    |
# |    value_loss           | 0.00464    |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.52         |
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 46            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 0.00089766853 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.9          |
# |    explained_variance   | -0.0253       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0033        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000213     |
# |    value_loss           | 0.00177       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.54       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 47          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.009076287 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.00893     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -1.54      |
# | time/                   |            |
# |    fps                  | 486        |
# |    iterations           | 48         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00545236 |
# |    clip_fraction        | 0.0352     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.852     |
# |    explained_variance   | -0.0114    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00604   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00267   |
# |    value_loss           | 0.00511    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.54        |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 49           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0033964757 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.00539      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0204      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 0.00347      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 50           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0010910067 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.795       |
# |    explained_variance   | -0.0315      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0119      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 51           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0063395635 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | -0.000885    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00367     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.00235      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.51       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 52          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.008586485 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | -0.00732    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000446    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 0.00451     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.51        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 53           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 13568        |
# | train/                  |              |
# |    approx_kl            | 0.0062069194 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | -0.0161      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0217      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00612     |
# |    value_loss           | 0.00118      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.47        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 54           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0020831923 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.0116       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.47        |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 55           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0028431707 |
# |    clip_fraction        | 0.00742      |
# ...
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0256   |
# |    explained_variance   | 0.0448    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000842  |
# |    n_updates            | 1770      |
# |    policy_gradient_loss | -1.79e-07 |
# |    value_loss           | 0.00196   |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.3         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 179          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0003172825 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0237      |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.25e-05     |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.000416    |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.3         |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 180          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 5.816575e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0208      |
# |    explained_variance   | -0.041       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00172      |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -1.23e-05    |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.3          |
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 181           |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 46336         |
# | train/                  |               |
# |    approx_kl            | 0.00022562896 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0182       |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00118       |
# |    n_updates            | 1800          |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 0.00195       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.3          |
# | time/                   |               |
# |    fps                  | 467           |
# |    iterations           | 182           |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 46592         |
# | train/                  |               |
# |    approx_kl            | 4.6775676e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0167       |
# |    explained_variance   | 0.0223        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000929      |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | 2.15e-07      |
# |    value_loss           | 0.00168       |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 910       |
# |    ep_rew_mean          | -1.3      |
# | time/                   |           |
# |    fps                  | 467       |
# |    iterations           | 183       |
# |    time_elapsed         | 100       |
# |    total_timesteps      | 46848     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0158   |
# |    explained_variance   | 0.153     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00191   |
# |    n_updates            | 1820      |
# |    policy_gradient_loss | -8.89e-09 |
# |    value_loss           | 0.00305   |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.3          |
# | time/                   |               |
# |    fps                  | 467           |
# |    iterations           | 184           |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00012438558 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0148       |
# |    explained_variance   | 0.00596       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000412     |
# |    n_updates            | 1830          |
# |    policy_gradient_loss | -0.000284     |
# |    value_loss           | 0.00295       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.29         |
# | time/                   |               |
# |    fps                  | 467           |
# |    iterations           | 185           |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 47360         |
# | train/                  |               |
# |    approx_kl            | 0.00031419517 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0112       |
# |    explained_variance   | 0.0946        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00109       |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.000662     |
# |    value_loss           | 0.00193       |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 910       |
# |    ep_rew_mean          | -1.29     |
# | time/                   |           |
# |    fps                  | 467       |
# |    iterations           | 186       |
# |    time_elapsed         | 101       |
# |    total_timesteps      | 47616     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00999  |
# |    explained_variance   | 0.146     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00118   |
# |    n_updates            | 1850      |
# |    policy_gradient_loss | -2.09e-08 |
# |    value_loss           | 0.00206   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.29    |
# | time/                   |          |
# |    fps                  | 468      |
# |    iterations           | 187      |
# |    time_elapsed         | 102      |
# |    total_timesteps      | 47872    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00984 |
# |    explained_variance   | -0.0417  |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00224  |
# |    n_updates            | 1860     |
# |    policy_gradient_loss | -1.4e-08 |
# |    value_loss           | 0.00403  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 910       |
# |    ep_rew_mean          | -1.29     |
# | time/                   |           |
# |    fps                  | 468       |
# |    iterations           | 188       |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 48128     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00988  |
# |    explained_variance   | 0.12      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000688  |
# |    n_updates            | 1870      |
# |    policy_gradient_loss | -1.09e-09 |
# |    value_loss           | 0.00148   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.29    |
# | time/                   |          |
# |    fps                  | 468      |
# |    iterations           | 189      |
# |    time_elapsed         | 103      |
# |    total_timesteps      | 48384    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00995 |
# |    explained_variance   | 0.176    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000682 |
# |    n_updates            | 1880     |
# |    policy_gradient_loss | 3.48e-09 |
# |    value_loss           | 0.00123  |
# --------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.29         |
# | time/                   |               |
# |    fps                  | 468           |
# |    iterations           | 190           |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 48640         |
# | train/                  |               |
# |    approx_kl            | 0.00015354808 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0115       |
# |    explained_variance   | 0.175         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00157      |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -0.000435     |
# |    value_loss           | 0.00302       |
# -------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.29    |
# | time/                   |          |
# |    fps                  | 468      |
# |    iterations           | 191      |
# |    time_elapsed         | 104      |
# |    total_timesteps      | 48896    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0123  |
# |    explained_variance   | -0.06    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0011   |
# |    n_updates            | 1900     |
# |    policy_gradient_loss | 2.94e-08 |
# |    value_loss           | 0.00311  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.29        |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 192          |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0005202058 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0116      |
# |    explained_variance   | 0.0572       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00189     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.000569    |
# |    value_loss           | 0.00196      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 910       |
# |    ep_rew_mean          | -1.29     |
# | time/                   |           |
# |    fps                  | 469       |
# |    iterations           | 193       |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 49408     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00954  |
# |    explained_variance   | 0.123     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00136   |
# |    n_updates            | 1920      |
# |    policy_gradient_loss | -3.97e-08 |
# |    value_loss           | 0.00227   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.29    |
# | time/                   |          |
# |    fps                  | 469      |
# |    iterations           | 194      |
# |    time_elapsed         | 105      |
# |    total_timesteps      | 49664    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0094  |
# |    explained_variance   | 0.0124   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00124  |
# |    n_updates            | 1930     |
# |    policy_gradient_loss | 1.43e-08 |
# |    value_loss           | 0.00239  |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.29    |
# | time/                   |          |
# |    fps                  | 469      |
# |    iterations           | 195      |
# |    time_elapsed         | 106      |
# |    total_timesteps      | 49920    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00947 |
# |    explained_variance   | 0.107    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00158  |
# |    n_updates            | 1940     |
# |    policy_gradient_loss | 1.51e-10 |
# |    value_loss           | 0.00282  |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 910      |
# |    ep_rew_mean          | -1.28    |
# | time/                   |          |
# |    fps                  | 469      |
# |    iterations           | 196      |
# |    time_elapsed         | 106      |
# |    total_timesteps      | 50176    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00949 |
# |    explained_variance   | 0.0775   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000691 |
# |    n_updates            | 1950     |
# |    policy_gradient_loss | 1.06e-08 |
# |    value_loss           | 0.00147  |
# --------------------------------------

# %% [markdown]
# Model de BTC + GLD

# %%
model_btc_gld_vol = PPO(
    "MlpPolicy",
    env_train_btc_gld_vol,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_gld_vol.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 525 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 444          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0039787795 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -4.47        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0106      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 0.0104       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.012144307 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00574     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000912    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 0.00342     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.4        |
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.005360199 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.00411     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.4        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.008050728 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000461   |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.4        |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.002780229 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.0137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 0.00352     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.4        |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.011580254 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00904     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -2.09         |
# | time/                   |               |
# |    fps                  | 447           |
# |    iterations           | 8             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 5.5646524e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0.0312        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00143       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | 9.06e-05      |
# |    value_loss           | 0.00213       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -2.09        |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0052967137 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0293      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0152      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 0.00546      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.09       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 10          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.012767839 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.00213     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00896     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00351     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.14       |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.020178355 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0294     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -2.14        |
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 12           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0039197663 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.108       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0147      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 0.00348      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.14       |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.011142122 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0082     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00707    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.14       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 14          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.010850547 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0231      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00773    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.83        |
# | time/                   |              |
# |    fps                  | 450          |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0013654009 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0371       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00433     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.83        |
# | time/                   |              |
# |    fps                  | 450          |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0022604642 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.00619     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00986     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 0.00558      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.83        |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 17           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0029853783 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0.00883      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0039       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.00192      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.91        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0053474773 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.0373       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00728     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 0.00188      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.91        |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 19           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0003941313 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.0264      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00506      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000507    |
# |    value_loss           | 0.00637      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.91        |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0026943968 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00893      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.00439      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.91        |
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 21           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0139787495 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.00363     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00612     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00733     |
# |    value_loss           | 0.0034       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.02       |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 22          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.010314822 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.0668      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0415     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 0.00185     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -2.02       |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 23          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.015492819 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -0.0197     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0332     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.0042      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -2.02        |
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 24           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057306285 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | -0.00214     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000211    |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 0.00398      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.94        |
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 25           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0017717769 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | -0.00609     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000225    |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.00531      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.94       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 26          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.006615473 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 0.0118      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00285     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 0.00515     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.94       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 27          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.009564238 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0035     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 0.00333     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.94        |
# | time/                   |              |
# |    fps                  | 464          |
# |    iterations           | 28           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0062559657 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.00175      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00287      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 0.00595      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.89       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 29          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.005980139 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.0146      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00539    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.89       |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 30          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.005457279 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | -0.0414     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00881    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.0037      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.89       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 31          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.011767116 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.00464     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.92        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 32           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0037007658 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | -0.0319      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0146      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 0.00128      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.92        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 33           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0036226246 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.024       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00716      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 0.00147      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.92        |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 34           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0011311639 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.00971      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00516     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 0.002        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.92         |
# | time/                   |               |
# |    fps                  | 469           |
# |    iterations           | 35            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8960          |
# | train/                  |               |
# |    approx_kl            | 0.00056802225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | -0.012        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00604       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00031      |
# |    value_loss           | 0.00225       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.84        |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 36           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0072342576 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | -0.0498      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 0.00222      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.84        |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 37           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0046518035 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.0361       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00678      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.00286      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.84       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 38          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.012968116 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | -0.0291     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 0.00429     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.84       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 39          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.007676998 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.0621      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.74       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 40          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012114284 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.00152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 0.000934    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -1.74      |
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 41         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 10496      |
# | train/                  |            |
# |    approx_kl            | 0.00360789 |
# |    clip_fraction        | 0.00859    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.941     |
# |    explained_variance   | 0.0203     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00058    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00209   |
# |    value_loss           | 0.00336    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.74        |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 42           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0024471204 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | -0.00143     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00465     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00093     |
# |    value_loss           | 0.00246      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.76       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 43          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.002725873 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | -0.0364     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00948    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.76        |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 44           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0068406705 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.946       |
# |    explained_variance   | -0.013       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00123      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 0.00463      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.76       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 45          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.004316697 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | -0.00966    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 0.00338     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.76       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 46          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.005322245 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00058    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.68       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 47          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.009940223 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.025       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00754    |
# |    value_loss           | 0.000909    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.68       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 48          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004390681 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00703    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 0.00489     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.68       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 49          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.006707073 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | -0.0158     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0075     |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.67       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 50          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.003807587 |
# |    clip_fraction        | 0.00742     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | -0.0284     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00963     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000906   |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.67        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 51           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0056167883 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.0422       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0168      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 0.00566      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.67       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 52          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.005327181 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | -0.0882     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00526     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.67       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 53          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.004367144 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | -0.019      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 0.00452     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.66       |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 54          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.012001421 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | -0.0625     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 55           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0050003612 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.769       |
# |    explained_variance   | 0.0227       |
# |    learning_rate        | 0.0003       |
# ...
# |    fps                  | 479          |
# |    iterations           | 179          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0021407502 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | -0.0159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0123      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.00266      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.64        |
# | time/                   |              |
# |    fps                  | 479          |
# |    iterations           | 180          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0043392014 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0.0195       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00221      |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.00507      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.64       |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 181         |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 46336       |
# | train/                  |             |
# |    approx_kl            | 0.008498969 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | -0.00748    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 910            |
# |    ep_rew_mean          | -1.64          |
# | time/                   |                |
# |    fps                  | 480            |
# |    iterations           | 182            |
# |    time_elapsed         | 97             |
# |    total_timesteps      | 46592          |
# | train/                  |                |
# |    approx_kl            | 0.000119642355 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.375         |
# |    explained_variance   | -0.0615        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.00229        |
# |    n_updates            | 1810           |
# |    policy_gradient_loss | 2.34e-05       |
# |    value_loss           | 0.00172        |
# --------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.64       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 183         |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 46848       |
# | train/                  |             |
# |    approx_kl            | 0.001242355 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00561    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.000313   |
# |    value_loss           | 0.0048      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.64        |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 184          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0035966649 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | 0.00782      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00385      |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | -1.66       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 185         |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.004111643 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | -0.0478     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00303    |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 0.00516     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 186          |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0066804164 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.409       |
# |    explained_variance   | 0.0672       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00422      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 0.0025       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 187          |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 47872        |
# | train/                  |              |
# |    approx_kl            | 0.0051814457 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | -0.00545     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00485      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 0.00462      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 188          |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0060711238 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.372       |
# |    explained_variance   | -0.041       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00562      |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.65        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 189          |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0040868917 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.326       |
# |    explained_variance   | 0.0463       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00449     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 0.00167      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 910           |
# |    ep_rew_mean          | -1.65         |
# | time/                   |               |
# |    fps                  | 481           |
# |    iterations           | 190           |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 48640         |
# | train/                  |               |
# |    approx_kl            | 7.8710495e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.309        |
# |    explained_variance   | 0.0143        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0031        |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 0.00504       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.65        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 191          |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 48896        |
# | train/                  |              |
# |    approx_kl            | 0.0022284873 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.321       |
# |    explained_variance   | -0.083       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00273     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 0.00272      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 192          |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035535984 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -0.0298      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00277      |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.00254      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 193          |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 49408        |
# | train/                  |              |
# |    approx_kl            | 0.0054843887 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | 0.000779     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0034       |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 0.00281      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -1.66      |
# | time/                   |            |
# |    fps                  | 482        |
# |    iterations           | 194        |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 49664      |
# | train/                  |            |
# |    approx_kl            | 0.00342777 |
# |    clip_fraction        | 0.00469    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.318     |
# |    explained_variance   | -0.0438    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0042     |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | -0.00296   |
# |    value_loss           | 0.0031     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.66        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 195          |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 49920        |
# | train/                  |              |
# |    approx_kl            | 0.0032080763 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.323       |
# |    explained_variance   | -0.0021      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000619    |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 0.00159      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | -1.64        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 196          |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0005245877 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.313       |
# |    explained_variance   | 0.0441       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00348     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 0.00219      |
# ------------------------------------------

# %% [markdown]
# Guardar models

# %%
model_btc_vol.save("../results/model_btc_baseline")
model_btc_gld_vol.save("../results/model_btc_gld")

# %% [markdown]
# Avaluació en Test.
# Retorna Equity Cruve, Rewards, Posicions i Retorns d'Estratègia.

# %%
import numpy as np
import pandas as pd

def evaluate_model(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    positions = []
    asset_returns = []
    actions = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        positions.append(info["position"])
        asset_returns.append(info["asset_return"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "position": positions,
        "asset_return": asset_returns,
        "action": actions,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    return results

# %% [markdown]
# Execució en els dos models

# %%
results_btc_vol = evaluate_model(model_btc_vol, env_test_btc_vol, test_btc)
results_btc_gld_vol = evaluate_model(model_btc_gld_vol, env_test_btc_gld_vol, test_btc_gld)

results_btc_vol.head(), results_btc_gld_vol.head()
# Out:
# (                             reward  position  asset_return  action    equity
#  Datetime
#  2025-12-04 16:00:00+00:00 -0.013585         1     -0.010522       1  0.986415
#  2025-12-04 20:00:00+00:00  0.002450         1      0.005439       1  0.988832
#  2025-12-05 12:00:00+00:00 -0.026829         1     -0.023877       1  0.962302
#  2025-12-05 16:00:00+00:00 -0.008712         1     -0.006586       1  0.953919
#  2025-12-05 20:00:00+00:00 -0.006491         1     -0.004336       1  0.947726,
#                               reward  position  asset_return  action    equity
#  Datetime
#  2025-12-04 16:00:00+00:00 -0.013585         1     -0.010522       1  0.986415
#  2025-12-04 20:00:00+00:00 -0.008427        -1      0.005439       2  0.978102
#  2025-12-05 12:00:00+00:00 -0.026829         1     -0.023877       1  0.951860
#  2025-12-05 16:00:00+00:00  0.004460        -1     -0.006586       2  0.956105
#  2025-12-05 20:00:00+00:00 -0.006491         1     -0.004336       1  0.949899)

# %%
results_btc_vol["action"].value_counts()
results_btc_gld_vol["action"].value_counts()
# Out:
# action
# 1    114
# 2    113
# Name: count, dtype: int64

# %% [markdown]
# Funció de mètriques bàsiques

# %%
def compute_metrics(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 0:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 0:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    position_changes = results_df["position"].diff().fillna(0)
    initial_trade = 1 if results_df["position"].iloc[0] != 0 else 0
    n_trades = int((position_changes != 0).sum() + initial_trade)

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_trades": int(n_trades),
    }

# %% [markdown]
# Aplicació de la funció de mètriques

# %%
metrics_btc = compute_metrics(results_btc_vol)
metrics_btc_gld = compute_metrics(results_btc_gld_vol)

metrics_btc, metrics_btc_gld
# Out:
# ({'cumulative_return': np.float64(-0.49782845155834266),
#   'sharpe': np.float64(-3.3869079043182926),
#   'sortino': np.float64(-4.592176605841411),
#   'max_drawdown': np.float64(-0.5115836154851117),
#   'n_trades': 1},
#  {'cumulative_return': np.float64(-0.4553440852010734),
#   'sharpe': np.float64(-2.9629062001854156),
#   'sortino': np.float64(-3.9513664778275954),
#   'max_drawdown': np.float64(-0.45261146984873835),
#   'n_trades': 227})

# %% [markdown]
# Taula comparativa

# %%
comparison = pd.DataFrame([metrics_btc, metrics_btc_gld], index=["BTC", "BTC+GLD"])
comparison
# Out:
#          cumulative_return    sharpe   sortino  max_drawdown  n_trades
# BTC              -0.497828 -3.386908 -4.592177     -0.511584         1
# BTC+GLD          -0.455344 -2.962906 -3.951366     -0.452611       227

# %% [markdown]
# Gràfica d'Equity

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(results_btc_vol.index, results_btc_vol["equity"], label="BTC")
plt.plot(results_btc_gld_vol.index, results_btc_gld_vol["equity"], label="BTC+GLD")
plt.title("Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Comparació contra buy-and-hold

# %%
buy_hold_ret = test_btc["btc_close"].iloc[-1] / test_btc["btc_close"].iloc[0] - 1
print("Buy & Hold return:", buy_hold_ret)
# Out:
# Buy & Hold return: -0.24914827510115745

# %% [markdown]
# Veure accions dels dos models per separat

# %%
print("BTC actions:")
print(results_btc_vol["action"].value_counts())

print("\nBTC+GLD actions:")
print(results_btc_gld_vol["action"].value_counts())

print("\nBTC positions:")
print(results_btc_vol["position"].value_counts())

print("\nBTC+GLD positions:")
print(results_btc_gld_vol["position"].value_counts())
# Out:
# BTC actions:
# action
# 1    227
# Name: count, dtype: int64
#
# BTC+GLD actions:
# action
# 1    114
# 2    113
# Name: count, dtype: int64
#
# BTC positions:
# position
# 1    227
# Name: count, dtype: int64
#
# BTC+GLD positions:
# position
#  1    114
# -1    113
# Name: count, dtype: int64
