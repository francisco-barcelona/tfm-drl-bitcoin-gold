# %% [markdown]
# # Experiment multi-asset: BTC vs GLD vs USO
#
# Aquest notebook reformula el problema com una tasca d'assignació dinàmica d'actius.
#
# L'agent decideix quin actiu mantenir en cada pas temporal:
#
# - `0 = BTC`
# - `1 = GLD`
# - `2 = USO`

# %%
import sys
from pathlib import Path

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_multi_asset_relative_reward import TradingEnv
from stable_baselines3 import PPO

# %% [markdown]
# ## 1. Configuració de l'experiment

# %%
EXPERIMENT_NAME = "multi_asset_relative_strength_relative_reward_long"
ACTION_TYPE = "asset_allocation_relative_reward"

BASE_TRANSACTION_COST = 0.001
DYNAMIC_COST_WEIGHT = 0.05
INACTIVITY_PENALTY = 0.001

TOTAL_TIMESTEPS = 1000000
TRAIN_SPLIT = 0.8

print("Experiment:", EXPERIMENT_NAME)
print("Action type:", ACTION_TYPE)
print("Base transaction cost:", BASE_TRANSACTION_COST)
print("Dynamic cost weight:", DYNAMIC_COST_WEIGHT)
print("Inactivity penalty:", INACTIVITY_PENALTY)
print("Timesteps:", TOTAL_TIMESTEPS)
print("Train split:", TRAIN_SPLIT)
# Out:
# Experiment: multi_asset_relative_strength_relative_reward_long
# Action type: asset_allocation_relative_reward
# Base transaction cost: 0.001
# Dynamic cost weight: 0.05
# Inactivity penalty: 0.001
# Timesteps: 200000
# Train split: 0.8

# %% [markdown]
# ## 2. Descàrrega de dades

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)
uso = yf.download("USO", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
print("USO shape:", uso.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17357, 6)
# GLD shape: (5077, 6)
# USO shape: (5078, 6)

# %% [markdown]
# ## 3. Neteja de columnes

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)
uso.columns = uso.columns.get_level_values(0)

btc.columns.name = None
gld.columns.name = None
uso.columns.name = None

print(btc.columns)
print(gld.columns)
print(uso.columns)

btc.head(), gld.head(), uso.head()
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# (                              Adj Close         Close          High  \
#  Datetime
#  2024-05-03 00:00:00+00:00  59048.851562  59048.851562  59128.941406
#  2024-05-03 01:00:00+00:00  59359.304688  59359.304688  59490.843750
#  2024-05-03 02:00:00+00:00  59561.472656  59561.472656  59928.902344
#  2024-05-03 03:00:00+00:00  59740.558594  59740.558594  59992.253906
#  2024-05-03 04:00:00+00:00  59585.773438  59585.773438  59825.601562
#
#                                      Low          Open     Volume
#  Datetime
#  2024-05-03 00:00:00+00:00  58851.484375  59087.492188          0
#  2024-05-03 01:00:00+00:00  59040.808594  59053.320312          0
#  2024-05-03 02:00:00+00:00  59302.406250  59336.199219   26249216
#  2024-05-03 03:00:00+00:00  59557.214844  59557.214844  431472640
#  2024-05-03 04:00:00+00:00  59573.722656  59736.585938          0  ,
#                              Adj Close       Close        High         Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  181.940002  181.940002  182.235001  180.600006
#  2023-06-05 14:30:00+00:00  181.850006  181.850006  182.029999  181.649994
#  2023-06-05 15:30:00+00:00  181.919998  181.919998  182.151993  181.649994
#  2023-06-05 16:30:00+00:00  181.869995  181.869995  181.970001  181.779999
#  2023-06-05 17:30:00+00:00  182.169998  182.169998  182.330002  181.830002
#
#                                   Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  180.789993  1608462
#  2023-06-05 14:30:00+00:00  181.929993   521884
#  2023-06-05 15:30:00+00:00  181.852005   415074
#  2023-06-05 16:30:00+00:00  181.919998   675305
#  2023-06-05 17:30:00+00:00  181.875000  1027578  ,
#                             Adj Close      Close       High        Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  64.680000  64.680000  65.410004  64.220001
#  2023-06-05 14:30:00+00:00  64.930000  64.930000  64.959999  64.320000
#  2023-06-05 15:30:00+00:00  64.879997  64.879997  64.959999  64.580002
#  2023-06-05 16:30:00+00:00  64.629997  64.629997  65.040001  64.629997
#  2023-06-05 17:30:00+00:00  64.300003  64.300003  64.764999  64.239998
#
#                                  Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  65.370003  1253341
#  2023-06-05 14:30:00+00:00  64.669998   503423
#  2023-06-05 15:30:00+00:00  64.939102   273453
#  2023-06-05 16:30:00+00:00  64.879997   306210
#  2023-06-05 17:30:00+00:00  64.654999   277808  )

# %% [markdown]
# ## 4. Normalització temporal i sincronització

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()
uso_1h = uso[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")
uso_1h.index = uso_1h.index.floor("1h")

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})
uso_1h = uso_1h.rename(columns={"Close": "uso_close"})

print(btc_1h.head())
print(gld_1h.head())
print(uso_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-05-03 00:00:00+00:00  59048.851562
# 2024-05-03 01:00:00+00:00  59359.304688
# 2024-05-03 02:00:00+00:00  59561.472656
# 2024-05-03 03:00:00+00:00  59740.558594
# 2024-05-03 04:00:00+00:00  59585.773438
#                             gld_close
# Datetime
# 2023-06-05 13:00:00+00:00  181.940002
# 2023-06-05 14:00:00+00:00  181.850006
# 2023-06-05 15:00:00+00:00  181.919998
# 2023-06-05 16:00:00+00:00  181.869995
# 2023-06-05 17:00:00+00:00  182.169998
#                            uso_close
# Datetime
# 2023-06-05 13:00:00+00:00  64.680000
# 2023-06-05 14:00:00+00:00  64.930000
# 2023-06-05 15:00:00+00:00  64.879997
# 2023-06-05 16:00:00+00:00  64.629997
# 2023-06-05 17:00:00+00:00  64.300003

# %%
common_index = btc_1h.index.intersection(gld_1h.index).intersection(uso_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()
uso_sync = uso_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("USO sync shape:", uso_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3447, 1)
# GLD sync shape: (3447, 1)
# USO sync shape: (3447, 1)
# Start: 2024-05-03 13:00:00+00:00
# End: 2026-05-01 19:00:00+00:00

# %%
df = btc_sync.join(gld_sync, how="inner").join(uso_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3447, 3)
#                               btc_close   gld_close  uso_close
# Datetime
# 2024-05-03 13:00:00+00:00  61662.195312  211.570007  75.550003
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000

# %% [markdown]
# ## 5. Creació de retorns i agregació a 4 hores

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()
df["uso_ret_1h"] = df["uso_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000   -0.000032
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002    0.001729
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004   -0.001502
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000    0.002895
# 2024-05-03 18:00:00+00:00  61821.207031  212.720001  75.099998   -0.000508
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 14:00:00+00:00    0.002552    0.000265
# 2024-05-03 15:00:00+00:00    0.002263   -0.001720
# 2024-05-03 16:00:00+00:00    0.001153   -0.000398
# 2024-05-03 17:00:00+00:00   -0.000728   -0.004509
# 2024-05-03 18:00:00+00:00    0.000188    0.000400

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "uso_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum",
    "uso_ret_1h": "sum",
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1151, 6)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 12:00:00+00:00  61766.851562  212.589996  75.440002    0.001697
# 2024-05-03 16:00:00+00:00  62025.589844  212.979996  75.150002    0.004191
# 2024-05-06 12:00:00+00:00  63701.535156  215.139999  75.970001    0.027139
# 2024-05-06 16:00:00+00:00  63191.597656  215.169998  75.650002   -0.007982
# 2024-05-07 12:00:00+00:00  63724.531250  214.300003  75.800003    0.008454
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 12:00:00+00:00    0.004815   -0.001456
# 2024-05-03 16:00:00+00:00    0.001835   -0.003841
# 2024-05-06 12:00:00+00:00    0.010143    0.010888
# 2024-05-06 16:00:00+00:00    0.000141   -0.004177
# 2024-05-07 12:00:00+00:00   -0.004047    0.002050

# %% [markdown]
# ## 6. Feature engineering

# %%
# Target returns: retorns utilitzats per calcular la recompensa
df_4h["btc_target_ret"] = df_4h["btc_close"].pct_change()
df_4h["gld_target_ret"] = df_4h["gld_close"].pct_change()
df_4h["uso_target_ret"] = df_4h["uso_close"].pct_change()

# Features bàsiques amb informació passada
df_4h["btc_ret_4h"] = df_4h["btc_target_ret"].shift(1)
df_4h["gld_ret_4h"] = df_4h["gld_target_ret"].shift(1)
df_4h["uso_ret_4h"] = df_4h["uso_target_ret"].shift(1)

df_4h["btc_vol_12"] = df_4h["btc_target_ret"].rolling(12).std().shift(1)
df_4h["gld_vol_12"] = df_4h["gld_target_ret"].rolling(12).std().shift(1)
df_4h["uso_vol_12"] = df_4h["uso_target_ret"].rolling(12).std().shift(1)

# Momentum passat: rendiment acumulat en finestres més llargues
df_4h["btc_mom_12"] = df_4h["btc_close"].pct_change(12).shift(1)
df_4h["gld_mom_12"] = df_4h["gld_close"].pct_change(12).shift(1)
df_4h["uso_mom_12"] = df_4h["uso_close"].pct_change(12).shift(1)

df_4h["btc_mom_24"] = df_4h["btc_close"].pct_change(24).shift(1)
df_4h["gld_mom_24"] = df_4h["gld_close"].pct_change(24).shift(1)
df_4h["uso_mom_24"] = df_4h["uso_close"].pct_change(24).shift(1)

# Relative strength: comparació de força relativa entre actius
df_4h["btc_vs_gld_mom_12"] = df_4h["btc_mom_12"] - df_4h["gld_mom_12"]
df_4h["btc_vs_uso_mom_12"] = df_4h["btc_mom_12"] - df_4h["uso_mom_12"]
df_4h["gld_vs_uso_mom_12"] = df_4h["gld_mom_12"] - df_4h["uso_mom_12"]

df_4h["btc_vs_gld_mom_24"] = df_4h["btc_mom_24"] - df_4h["gld_mom_24"]
df_4h["btc_vs_uso_mom_24"] = df_4h["btc_mom_24"] - df_4h["uso_mom_24"]
df_4h["gld_vs_uso_mom_24"] = df_4h["gld_mom_24"] - df_4h["uso_mom_24"]

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1126, 27)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-21 16:00:00+00:00  69363.851562  224.220001  76.150002   -0.004709
# 2024-05-22 12:00:00+00:00  70434.546875  221.300003  75.595001    0.015375
# 2024-05-22 16:00:00+00:00  69718.234375  220.119995  74.889999   -0.010192
# 2024-05-23 12:00:00+00:00  68048.742188  216.869995  74.820000   -0.023934
# 2024-05-23 16:00:00+00:00  67128.031250  215.710007  74.459999   -0.013599
#
#                            gld_ret_1h  uso_ret_1h  btc_target_ret  \
# Datetime
# 2024-05-21 16:00:00+00:00    0.001611    0.005212       -0.004718
# 2024-05-22 12:00:00+00:00   -0.012989   -0.007253        0.015436
# 2024-05-22 16:00:00+00:00   -0.005336   -0.009350       -0.010170
# 2024-05-23 12:00:00+00:00   -0.014792   -0.000832       -0.023946
# 2024-05-23 16:00:00+00:00   -0.005357   -0.004796       -0.013530
#
#                            gld_target_ret  uso_target_ret  btc_ret_4h  ...  \
# Datetime                                                               ...
# 2024-05-21 16:00:00+00:00        0.001608        0.005214   -0.002706  ...
# 2024-05-22 12:00:00+00:00       -0.013023       -0.007288   -0.004718  ...
# 2024-05-22 16:00:00+00:00       -0.005332       -0.009326    0.015436  ...
# 2024-05-23 12:00:00+00:00       -0.014765       -0.000935   -0.010170  ...
# 2024-05-23 16:00:00+00:00       -0.005349       -0.004812   -0.023946  ...
#
#                            uso_mom_12  btc_mom_24  gld_mom_24  uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318    0.053013    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310    0.052775    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696    0.028633   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283    0.023005   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858    0.011992   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 7. Dataset de l'entorn multi-asset

# %%
feature_columns = [
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12",
    "uso_ret_4h",
    "uso_vol_12",

    "btc_mom_12",
    "gld_mom_12",
    "uso_mom_12",

    "btc_mom_24",
    "gld_mom_24",
    "uso_mom_24",

    "btc_vs_gld_mom_12",
    "btc_vs_uso_mom_12",
    "gld_vs_uso_mom_12",

    "btc_vs_gld_mom_24",
    "btc_vs_uso_mom_24",
    "gld_vs_uso_mom_24",
]

target_columns = [
    "btc_target_ret",
    "gld_target_ret",
    "uso_target_ret",
]

env_df = df_4h[feature_columns + target_columns].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1126, 21)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002706    0.021136   -0.003072    0.005197
# 2024-05-22 12:00:00+00:00   -0.004718    0.021402    0.001608    0.005164
# 2024-05-22 16:00:00+00:00    0.015436    0.019438   -0.013023    0.006874
# 2024-05-23 12:00:00+00:00   -0.010170    0.019984   -0.005332    0.007115
# 2024-05-23 16:00:00+00:00   -0.023946    0.017984   -0.014765    0.007459
#
#                            uso_ret_4h  uso_vol_12  btc_mom_12  gld_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.012836    0.007127    0.106514    0.035670
# 2024-05-22 12:00:00+00:00    0.005214    0.007248    0.099664    0.036712
# 2024-05-22 16:00:00+00:00   -0.007288    0.005950    0.140127    0.018127
# 2024-05-23 12:00:00+00:00   -0.009326    0.006557    0.132473    0.009262
# 2024-05-23 16:00:00+00:00   -0.000935    0.006547    0.052487   -0.017487
#
#                            uso_mom_12  btc_mom_24  ...  uso_mom_24  \
# Datetime                                           ...
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318  ...    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310  ...    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696  ...   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283  ...   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858  ...   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
#                            btc_target_ret  gld_target_ret  uso_target_ret
# Datetime
# 2024-05-21 16:00:00+00:00       -0.004718        0.001608        0.005214
# 2024-05-22 12:00:00+00:00        0.015436       -0.013023       -0.007288
# 2024-05-22 16:00:00+00:00       -0.010170       -0.005332       -0.009326
# 2024-05-23 12:00:00+00:00       -0.023946       -0.014765       -0.000935
# 2024-05-23 16:00:00+00:00       -0.013530       -0.005349       -0.004812
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 8. Split train/test temporal

# %%
split_idx = int(len(env_df) * TRAIN_SPLIT)

train_data = env_df.iloc[:split_idx].copy()
test_data = env_df.iloc[split_idx:].copy()

print("train_data:", train_data.shape)
print("test_data:", test_data.shape)
# Out:
# train_data: (900, 21)
# test_data: (226, 21)

# %% [markdown]
# ## 9. Creació dels entorns

# %%
env_train_multi = TradingEnv(
    data=train_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

env_test_multi = TradingEnv(
    data=test_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

obs, info = env_train_multi.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.00270647  0.02113599 -0.00307235  0.00519702 -0.01283556  0.00712712
#   0.10651411  0.0356702  -0.0024362   0.12831771  0.05301337  0.00417543
#   0.07084391  0.10895031  0.0381064   0.07530435  0.12414228  0.04883793
#   0.          0.        ]
# Observation shape: (20,)
# Info: {}

# %% [markdown]
# ## 10. Entrenament PPO

# %%
model_multi = PPO(
    "MlpPolicy",
    env_train_multi,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_multi.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 866 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0055233254 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -7.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0143       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0067      |
# |    value_loss           | 0.00646      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.003947411 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -3.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00213    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 0.00135     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.15       |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.008448788 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00796    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.15       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.005964934 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0319      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00322     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.15        |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0028144494 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.411       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0233      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.15       |
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.008404227 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | -0.0897     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0023775897 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | -0.352       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00252      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 0.000694     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.37        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0019550957 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | -0.214       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00159     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.37       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 10          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008218737 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -0.364      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00842    |
# |    value_loss           | 0.000815    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.35       |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.006228118 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | -0.922      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00709     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.35        |
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 12           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0014745081 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.0604       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0109      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -1.35         |
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 13            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 0.00035505416 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.825        |
# |    explained_variance   | -0.398        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00892      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 0.000931      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.35        |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0017196885 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0094      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 0.00058      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.33        |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0017203044 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0162      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 0.000527     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 16          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007302316 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0.0297      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 17          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.004262484 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | -0.67       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00678    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 0.000719    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.31        |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0034857907 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | -0.0769      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00829     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.31       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 19          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4864        |
# | train/                  |             |
# |    approx_kl            | 0.008409174 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | -0.179      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00424    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.31        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0028869067 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | -0.144       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0051      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00563     |
# |    value_loss           | 0.000543     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.31        |
# | time/                   |              |
# |    fps                  | 440          |
# |    iterations           | 21           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0030713168 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.738       |
# |    explained_variance   | -0.0586      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0134      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 0.00094      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.35        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 22           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0040683364 |
# |    clip_fraction        | 0.0621       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.774       |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00659     |
# |    value_loss           | 0.000654     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.35        |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 23           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0018654112 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.000397     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0137      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 0.00143      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.35        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 24           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0026435985 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00733      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 0.000645     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.33        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 25           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0042934613 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.33        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 26           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0049288413 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.00443      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00916     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 27          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.004533234 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | -0.0825     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00545    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.000803    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.33        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 28           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0075988895 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | -0.223       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.038       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 0.000795     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.32        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 29           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 0.0053431923 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.0147       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0256      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00817     |
# |    value_loss           | 0.00047      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.32        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0026011884 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | -0.0503      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0136       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 0.00112      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.32        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 31           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0028772373 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | -0.128       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0153      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0075      |
# |    value_loss           | 0.000472     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.29        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 32           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0049269865 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | -0.0505      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 0.00055      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.29       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 33          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.007843906 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | -0.0694     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -1.29      |
# | time/                   |            |
# |    fps                  | 438        |
# |    iterations           | 34         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.00930164 |
# |    clip_fraction        | 0.0367     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.86      |
# |    explained_variance   | -0.114     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00652   |
# |    value_loss           | 0.000739   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.29        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 35           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0041876175 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | -0.0903      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00526      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.28        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 36           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0016361594 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | -0.0939      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00961      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 0.000902     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.28       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 37          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.004888084 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00798    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 0.0013      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -1.28      |
# | time/                   |            |
# |    fps                  | 434        |
# |    iterations           | 38         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.00427015 |
# |    clip_fraction        | 0.0164     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.891     |
# |    explained_variance   | 0.16       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0171    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00321   |
# |    value_loss           | 0.000577   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.25       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 39          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.004350835 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00657    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 0.000955    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.25        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 40           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0057024257 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | -0.0689      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00694     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.25        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 41           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10496        |
# | train/                  |              |
# |    approx_kl            | 0.0037543008 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | -0.124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0245      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00784     |
# |    value_loss           | 0.000602     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.25        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 42           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0034181147 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00886      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.000409     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.25       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 43          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.002393604 |
# |    clip_fraction        | 0.0043      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.007      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 0.000397    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.25       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 44          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.012408072 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | -0.0937     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.25        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 45           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0018663115 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | -0.281       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000363     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 0.000472     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.21        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 46           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0025513056 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.0643       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00623      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 0.000539     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.21       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 47          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.011887627 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | -0.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00429     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.21       |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 48          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003779997 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.21       |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 49          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.006296295 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.412      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.2         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 50           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0075672306 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | -0.0171      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00933      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00671     |
# |    value_loss           | 0.000983     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.2         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 51           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0023154258 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | -0.184       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0154       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.00149      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.2         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 52           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0014046002 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00507      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.2         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 53           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 13568        |
# | train/                  |              |
# |    approx_kl            | 0.0007152078 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | -0.521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00438     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 0.00169      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.2        |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 54          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.008542638 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.2        |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 55          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.012686816 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# ...
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.65       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 765         |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 195840      |
# | train/                  |             |
# |    approx_kl            | 0.002885781 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0839     |
# |    explained_variance   | -0.0873     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0034     |
# |    n_updates            | 7640        |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 0.000556    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.65        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 766          |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 196096       |
# | train/                  |              |
# |    approx_kl            | 0.0038190973 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0959      |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000421     |
# |    n_updates            | 7650         |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 0.000834     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.65        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 767          |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 196352       |
# | train/                  |              |
# |    approx_kl            | 0.0063919257 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | -0.538       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000737    |
# |    n_updates            | 7660         |
# |    policy_gradient_loss | -0.00703     |
# |    value_loss           | 0.000796     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.65       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 768         |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004307691 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0879     |
# |    explained_variance   | -0.0951     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00563    |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 0.000598    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.65        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 769          |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 196864       |
# | train/                  |              |
# |    approx_kl            | 0.0008540666 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0905      |
# |    explained_variance   | -0.0647      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0047      |
# |    n_updates            | 7680         |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 0.00135      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.652       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 770          |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 197120       |
# | train/                  |              |
# |    approx_kl            | 0.0030260498 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.109       |
# |    explained_variance   | -0.116       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 7690         |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 0.000562     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.652      |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 771         |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 197376      |
# | train/                  |             |
# |    approx_kl            | 0.009548556 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.0995      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00274    |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.000723    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.652       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 772          |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 197632       |
# | train/                  |              |
# |    approx_kl            | 0.0014160995 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.061       |
# |    explained_variance   | -0.218       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000965    |
# |    n_updates            | 7710         |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.648      |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 773         |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 197888      |
# | train/                  |             |
# |    approx_kl            | 0.002727013 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0921     |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00709    |
# |    n_updates            | 7720        |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.000711    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.648     |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 774        |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 198144     |
# | train/                  |            |
# |    approx_kl            | 0.00393455 |
# |    clip_fraction        | 0.016      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0909    |
# |    explained_variance   | -0.249     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0147    |
# |    n_updates            | 7730       |
# |    policy_gradient_loss | -0.00503   |
# |    value_loss           | 0.000786   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.648     |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 775        |
# |    time_elapsed         | 407        |
# |    total_timesteps      | 198400     |
# | train/                  |            |
# |    approx_kl            | 0.00062235 |
# |    clip_fraction        | 0.00508    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.085     |
# |    explained_variance   | 0.205      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00184   |
# |    n_updates            | 7740       |
# |    policy_gradient_loss | -0.00286   |
# |    value_loss           | 0.000359   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.648      |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 776         |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.003398392 |
# |    clip_fraction        | 0.0184      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0908     |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00671    |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.00129     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.643       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 777          |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 198912       |
# | train/                  |              |
# |    approx_kl            | 0.0018781852 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0993      |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00538      |
# |    n_updates            | 7760         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 0.000677     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.643        |
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 778           |
# |    time_elapsed         | 408           |
# |    total_timesteps      | 199168        |
# | train/                  |               |
# |    approx_kl            | 0.00071241613 |
# |    clip_fraction        | 0.0125        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.105        |
# |    explained_variance   | -0.533        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00296      |
# |    n_updates            | 7770          |
# |    policy_gradient_loss | -0.00168      |
# |    value_loss           | 0.00141       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.643       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 779          |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 199424       |
# | train/                  |              |
# |    approx_kl            | 0.0044082985 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0836      |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00426     |
# |    n_updates            | 7780         |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 0.000683     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.639       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 780          |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 199680       |
# | train/                  |              |
# |    approx_kl            | 0.0043104347 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.1         |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 7790         |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.639      |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 781         |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 199936      |
# | train/                  |             |
# |    approx_kl            | 0.002988071 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00169    |
# |    n_updates            | 7800        |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 0.000754    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.639       |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 782          |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 200192       |
# | train/                  |              |
# |    approx_kl            | 0.0035224406 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | -0.772       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0136      |
# |    n_updates            | 7810         |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 0.000547     |
# ------------------------------------------

# %% [markdown]
# ## 11. Funcions d'avaluació

# %%
def evaluate_model_multi_asset(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    actions = []
    assets = []
    switching_costs = []
    inactivity_costs = []
    selected_returns = []
    selected_volatilities = []
    holding_durations = []
    market_mean_returns = []
    relative_returns = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        assets.append(info["asset"])
        switching_costs.append(info["switching_cost"])
        inactivity_costs.append(info["inactivity_cost"])
        selected_returns.append(info["selected_return"])
        selected_volatilities.append(info["selected_volatility"])
        holding_durations.append(info["holding_duration"])
        market_mean_returns.append(info["market_mean_return"])
        relative_returns.append(info["relative_return"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "action": actions,
        "asset": assets,
        "holding_duration": holding_durations,
        "selected_return": selected_returns,
        "market_mean_return": market_mean_returns,
        "relative_return": relative_returns,
        "selected_volatility": selected_volatilities,
        "switching_cost": switching_costs,
        "inactivity_cost": inactivity_costs,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    results["real_equity"] = (1 + results["selected_return"]).cumprod()
    return results

def compute_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

def compute_real_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["selected_return"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = (1 + rets).cumprod()
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

# %% [markdown]
# ## 12. Avaluació del model

# %%
results_multi = evaluate_model_multi_asset(model_multi, env_test_multi, test_data)

results_multi.head()
# Out:
#                              reward  action  asset  holding_duration  \
# Datetime
# 2025-12-23 20:00:00+00:00  0.000235       1      1                 0
# 2025-12-24 12:00:00+00:00  0.000425       1      1                 1
# 2025-12-24 16:00:00+00:00 -0.005022       0      0                 0
# 2025-12-26 12:00:00+00:00 -0.001478       1      1                 0
# 2025-12-26 16:00:00+00:00  0.016517       1      1                 1
#
#                            selected_return  market_mean_return  \
# Datetime
# 2025-12-23 20:00:00+00:00         0.006955            0.005355
# 2025-12-24 12:00:00+00:00         0.001380            0.000262
# 2025-12-24 16:00:00+00:00        -0.008407           -0.005472
# 2025-12-26 12:00:00+00:00         0.002148            0.002234
# 2025-12-26 16:00:00+00:00         0.015451           -0.001759
#
#                            relative_return  selected_volatility  \
# Datetime
# 2025-12-23 20:00:00+00:00         0.001601             0.007308
# 2025-12-24 12:00:00+00:00         0.001118             0.007418
# 2025-12-24 16:00:00+00:00        -0.002935             0.021747
# 2025-12-26 12:00:00+00:00        -0.000087             0.007832
# 2025-12-26 16:00:00+00:00         0.017210             0.007175
#
#                            switching_cost  inactivity_cost    equity  \
# Datetime
# 2025-12-23 20:00:00+00:00        0.001365         0.000000  1.000235
# 2025-12-24 12:00:00+00:00        0.000000         0.000693  1.000660
# 2025-12-24 16:00:00+00:00        0.002087         0.000000  0.995635
# 2025-12-26 12:00:00+00:00        0.001392         0.000000  0.994163
# 2025-12-26 16:00:00+00:00        0.000000         0.000693  1.010584
#
#                            real_equity
# Datetime
# 2025-12-23 20:00:00+00:00     1.006955
# 2025-12-24 12:00:00+00:00     1.008345
# 2025-12-24 16:00:00+00:00     0.999868
# 2025-12-26 12:00:00+00:00     1.002016
# 2025-12-26 16:00:00+00:00     1.017498

# %%
metrics_multi_reward = compute_metrics_multi_asset(results_multi)
metrics_multi_real = compute_real_metrics_multi_asset(results_multi)

comparison_multi = pd.DataFrame(
    [metrics_multi_reward, metrics_multi_real],
    index=[
        "MultiAsset_relative_reward",
        "MultiAsset_real_return",
    ]
)

comparison_multi
# Out:
#                             cumulative_return    sharpe   sortino  \
# MultiAsset_relative_reward          -0.342137 -3.025480 -4.198248
# MultiAsset_real_return               0.165193  1.231613  1.597190
#
#                             max_drawdown  n_switches
# MultiAsset_relative_reward     -0.361838         112
# MultiAsset_real_return         -0.181774         112

# %% [markdown]
# ## 13. Benchmarks buy-and-hold

# %%
btc_bh = (1 + test_data["btc_target_ret"]).prod() - 1
gld_bh = (1 + test_data["gld_target_ret"]).prod() - 1
uso_bh = (1 + test_data["uso_target_ret"]).prod() - 1

benchmarks = pd.DataFrame(
    [{
        "BTC Buy & Hold": btc_bh,
        "GLD Buy & Hold": gld_bh,
        "USO Buy & Hold": uso_bh,
    }]
)

benchmarks
# Out:
#    BTC Buy & Hold  GLD Buy & Hold  USO Buy & Hold
# 0       -0.103544        0.032093        1.045084

# %% [markdown]
# ## 14. Distribució d'accions i actius

# %%
print("Actions:")
print(results_multi["action"].value_counts())

print("\nAssets:")
print(results_multi["asset"].value_counts())
# Out:
# Actions:
# action
# 1    138
# 0     78
# 2      9
# Name: count, dtype: int64
#
# Assets:
# asset
# 1    138
# 0     78
# 2      9
# Name: count, dtype: int64

# %% [markdown]
# ## 15. Corba d'equity

# %%
plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["real_equity"], label="Multi-Asset Agent Real Equity")
plt.title("Multi-Asset Real Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 16. Comparació visual amb buy-and-hold dels actius

# %%
bh_curves = pd.DataFrame(index=test_data.index)
bh_curves["BTC_BH"] = (1 + test_data["btc_target_ret"]).cumprod()
bh_curves["GLD_BH"] = (1 + test_data["gld_target_ret"]).cumprod()
bh_curves["USO_BH"] = (1 + test_data["uso_target_ret"]).cumprod()

plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["real_equity"], label="Multi-Asset Agent")
plt.plot(bh_curves.index, bh_curves["BTC_BH"], label="BTC Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["GLD_BH"], label="GLD Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["USO_BH"], label="USO Buy & Hold", linestyle="--")
plt.title("Multi-Asset Agent vs Buy & Hold Benchmarks")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 17. Guardat de resultats

# %%
results_dir = project_root / "results"
results_dir.mkdir(exist_ok=True)

results_multi.to_csv(results_dir / "results_multi_asset_btc_gld_uso.csv")
comparison_multi.to_csv(results_dir / "comparison_multi_asset_btc_gld_uso.csv")
benchmarks.to_csv(results_dir / "benchmarks_multi_asset_btc_gld_uso.csv")

print("Results saved in:", results_dir)
# Out:
# Results saved in: c:\Users\rfran\OneDrive\Documentos\UOC\Master\TFM\tfm-drl-trading\results

# %%
np.random.seed(42)
test_data_shuffled = test_data.sample(frac=1)

env_test_random = TradingEnv(
    data=test_data_shuffled,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

results_random = evaluate_model_multi_asset(
    model_multi,
    env_test_random,
    test_data_shuffled
)

compute_metrics_multi_asset(results_random)
# Out:
# {'cumulative_return': np.float64(-0.2780417912340436),
#  'sharpe': np.float64(-2.215187214192311),
#  'sortino': np.float64(-3.148675018199422),
#  'max_drawdown': np.float64(-0.30628967104878224),
#  'n_switches': 120}
