# %% [markdown]
# # Experiment multi-asset: BTC vs GLD vs USO
#
# Aquest notebook reformula el problema com una tasca d'assignació dinàmica d'actius.
#
# L'agent decideix quin actiu mantenir en cada pas temporal:
#
# - `0 = BTC`
# - `1 = GLD`
# - `2 = USO`

# %%
import sys
from pathlib import Path

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_multi_asset_forced_trading import TradingEnv
from stable_baselines3 import PPO

# %% [markdown]
# ## 1. Configuració de l'experiment

# %%
EXPERIMENT_NAME = "multi_asset_forced_trading"
ACTION_TYPE = "asset_allocation_with_inactivity_penalty"
TRANSACTION_COST = 0.001
INACTIVITY_PENALTY = 0.001
TOTAL_TIMESTEPS = 50000
TRAIN_SPLIT = 0.8

print("Experiment:", EXPERIMENT_NAME)
print("Action type:", ACTION_TYPE)
print("Transaction cost:", TRANSACTION_COST)
print("Timesteps:", TOTAL_TIMESTEPS)
print("Inactivity penalty:", INACTIVITY_PENALTY)
print("Train split:", TRAIN_SPLIT)
# Out:
# Experiment: multi_asset_forced_trading
# Action type: asset_allocation_with_inactivity_penalty
# Transaction cost: 0.001
# Timesteps: 50000
# Inactivity penalty: 0.001
# Train split: 0.8

# %% [markdown]
# ## 2. Descàrrega de dades

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)
uso = yf.download("USO", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
print("USO shape:", uso.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17351, 6)
# GLD shape: (5077, 6)
# USO shape: (5078, 6)

# %% [markdown]
# ## 3. Neteja de columnes

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)
uso.columns = uso.columns.get_level_values(0)

btc.columns.name = None
gld.columns.name = None
uso.columns.name = None

print(btc.columns)
print(gld.columns)
print(uso.columns)

btc.head(), gld.head(), uso.head()
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# (                              Adj Close         Close          High  \
#  Datetime
#  2024-05-03 00:00:00+00:00  59048.851562  59048.851562  59128.941406
#  2024-05-03 01:00:00+00:00  59359.304688  59359.304688  59490.843750
#  2024-05-03 02:00:00+00:00  59561.472656  59561.472656  59928.902344
#  2024-05-03 03:00:00+00:00  59740.558594  59740.558594  59992.253906
#  2024-05-03 04:00:00+00:00  59585.773438  59585.773438  59825.601562
#
#                                      Low          Open     Volume
#  Datetime
#  2024-05-03 00:00:00+00:00  58851.484375  59087.492188          0
#  2024-05-03 01:00:00+00:00  59040.808594  59053.320312          0
#  2024-05-03 02:00:00+00:00  59302.406250  59336.199219   26249216
#  2024-05-03 03:00:00+00:00  59557.214844  59557.214844  431472640
#  2024-05-03 04:00:00+00:00  59573.722656  59736.585938          0  ,
#                              Adj Close       Close        High         Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  181.940002  181.940002  182.235001  180.600006
#  2023-06-05 14:30:00+00:00  181.850006  181.850006  182.029999  181.649994
#  2023-06-05 15:30:00+00:00  181.919998  181.919998  182.151993  181.649994
#  2023-06-05 16:30:00+00:00  181.869995  181.869995  181.970001  181.779999
#  2023-06-05 17:30:00+00:00  182.169998  182.169998  182.330002  181.830002
#
#                                   Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  180.789993  1608462
#  2023-06-05 14:30:00+00:00  181.929993   521884
#  2023-06-05 15:30:00+00:00  181.852005   415074
#  2023-06-05 16:30:00+00:00  181.919998   675305
#  2023-06-05 17:30:00+00:00  181.875000  1027578  ,
#                             Adj Close      Close       High        Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  64.680000  64.680000  65.410004  64.220001
#  2023-06-05 14:30:00+00:00  64.930000  64.930000  64.959999  64.320000
#  2023-06-05 15:30:00+00:00  64.879997  64.879997  64.959999  64.580002
#  2023-06-05 16:30:00+00:00  64.629997  64.629997  65.040001  64.629997
#  2023-06-05 17:30:00+00:00  64.300003  64.300003  64.764999  64.239998
#
#                                  Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  65.370003  1253341
#  2023-06-05 14:30:00+00:00  64.669998   503423
#  2023-06-05 15:30:00+00:00  64.939102   273453
#  2023-06-05 16:30:00+00:00  64.879997   306210
#  2023-06-05 17:30:00+00:00  64.654999   277808  )

# %% [markdown]
# ## 4. Normalització temporal i sincronització

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()
uso_1h = uso[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")
uso_1h.index = uso_1h.index.floor("1h")

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})
uso_1h = uso_1h.rename(columns={"Close": "uso_close"})

print(btc_1h.head())
print(gld_1h.head())
print(uso_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-05-03 00:00:00+00:00  59048.851562
# 2024-05-03 01:00:00+00:00  59359.304688
# 2024-05-03 02:00:00+00:00  59561.472656
# 2024-05-03 03:00:00+00:00  59740.558594
# 2024-05-03 04:00:00+00:00  59585.773438
#                             gld_close
# Datetime
# 2023-06-05 13:00:00+00:00  181.940002
# 2023-06-05 14:00:00+00:00  181.850006
# 2023-06-05 15:00:00+00:00  181.919998
# 2023-06-05 16:00:00+00:00  181.869995
# 2023-06-05 17:00:00+00:00  182.169998
#                            uso_close
# Datetime
# 2023-06-05 13:00:00+00:00  64.680000
# 2023-06-05 14:00:00+00:00  64.930000
# 2023-06-05 15:00:00+00:00  64.879997
# 2023-06-05 16:00:00+00:00  64.629997
# 2023-06-05 17:00:00+00:00  64.300003

# %%
common_index = btc_1h.index.intersection(gld_1h.index).intersection(uso_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()
uso_sync = uso_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("USO sync shape:", uso_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3447, 1)
# GLD sync shape: (3447, 1)
# USO sync shape: (3447, 1)
# Start: 2024-05-03 13:00:00+00:00
# End: 2026-05-01 19:00:00+00:00

# %%
df = btc_sync.join(gld_sync, how="inner").join(uso_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3447, 3)
#                               btc_close   gld_close  uso_close
# Datetime
# 2024-05-03 13:00:00+00:00  61662.195312  211.570007  75.550003
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000

# %% [markdown]
# ## 5. Creació de retorns i agregació a 4 hores

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()
df["uso_ret_1h"] = df["uso_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000   -0.000032
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002    0.001729
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004   -0.001502
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000    0.002895
# 2024-05-03 18:00:00+00:00  61821.207031  212.720001  75.099998   -0.000508
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 14:00:00+00:00    0.002552    0.000265
# 2024-05-03 15:00:00+00:00    0.002263   -0.001720
# 2024-05-03 16:00:00+00:00    0.001153   -0.000398
# 2024-05-03 17:00:00+00:00   -0.000728   -0.004509
# 2024-05-03 18:00:00+00:00    0.000188    0.000400

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "uso_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum",
    "uso_ret_1h": "sum",
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1151, 6)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 12:00:00+00:00  61766.851562  212.589996  75.440002    0.001697
# 2024-05-03 16:00:00+00:00  62025.589844  212.979996  75.150002    0.004191
# 2024-05-06 12:00:00+00:00  63701.535156  215.139999  75.970001    0.027139
# 2024-05-06 16:00:00+00:00  63191.597656  215.169998  75.650002   -0.007982
# 2024-05-07 12:00:00+00:00  63724.531250  214.300003  75.800003    0.008454
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 12:00:00+00:00    0.004815   -0.001456
# 2024-05-03 16:00:00+00:00    0.001835   -0.003841
# 2024-05-06 12:00:00+00:00    0.010143    0.010888
# 2024-05-06 16:00:00+00:00    0.000141   -0.004177
# 2024-05-07 12:00:00+00:00   -0.004047    0.002050

# %% [markdown]
# ## 6. Feature engineering

# %%
# Target returns: retorns utilitzats per calcular la recompensa
df_4h["btc_target_ret"] = df_4h["btc_close"].pct_change()
df_4h["gld_target_ret"] = df_4h["gld_close"].pct_change()
df_4h["uso_target_ret"] = df_4h["uso_close"].pct_change()

# Features bàsiques amb informació passada
df_4h["btc_ret_4h"] = df_4h["btc_target_ret"].shift(1)
df_4h["gld_ret_4h"] = df_4h["gld_target_ret"].shift(1)
df_4h["uso_ret_4h"] = df_4h["uso_target_ret"].shift(1)

df_4h["btc_vol_12"] = df_4h["btc_target_ret"].rolling(12).std().shift(1)
df_4h["gld_vol_12"] = df_4h["gld_target_ret"].rolling(12).std().shift(1)
df_4h["uso_vol_12"] = df_4h["uso_target_ret"].rolling(12).std().shift(1)

# Momentum passat: rendiment acumulat en finestres més llargues
df_4h["btc_mom_12"] = df_4h["btc_close"].pct_change(12).shift(1)
df_4h["gld_mom_12"] = df_4h["gld_close"].pct_change(12).shift(1)
df_4h["uso_mom_12"] = df_4h["uso_close"].pct_change(12).shift(1)

df_4h["btc_mom_24"] = df_4h["btc_close"].pct_change(24).shift(1)
df_4h["gld_mom_24"] = df_4h["gld_close"].pct_change(24).shift(1)
df_4h["uso_mom_24"] = df_4h["uso_close"].pct_change(24).shift(1)

# Relative strength: comparació de força relativa entre actius
df_4h["btc_vs_gld_mom_12"] = df_4h["btc_mom_12"] - df_4h["gld_mom_12"]
df_4h["btc_vs_uso_mom_12"] = df_4h["btc_mom_12"] - df_4h["uso_mom_12"]
df_4h["gld_vs_uso_mom_12"] = df_4h["gld_mom_12"] - df_4h["uso_mom_12"]

df_4h["btc_vs_gld_mom_24"] = df_4h["btc_mom_24"] - df_4h["gld_mom_24"]
df_4h["btc_vs_uso_mom_24"] = df_4h["btc_mom_24"] - df_4h["uso_mom_24"]
df_4h["gld_vs_uso_mom_24"] = df_4h["gld_mom_24"] - df_4h["uso_mom_24"]

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1126, 27)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-21 16:00:00+00:00  69363.851562  224.220001  76.150002   -0.004709
# 2024-05-22 12:00:00+00:00  70434.546875  221.300003  75.595001    0.015375
# 2024-05-22 16:00:00+00:00  69718.234375  220.119995  74.889999   -0.010192
# 2024-05-23 12:00:00+00:00  68048.742188  216.869995  74.820000   -0.023934
# 2024-05-23 16:00:00+00:00  67128.031250  215.710007  74.459999   -0.013599
#
#                            gld_ret_1h  uso_ret_1h  btc_target_ret  \
# Datetime
# 2024-05-21 16:00:00+00:00    0.001611    0.005212       -0.004718
# 2024-05-22 12:00:00+00:00   -0.012989   -0.007253        0.015436
# 2024-05-22 16:00:00+00:00   -0.005336   -0.009350       -0.010170
# 2024-05-23 12:00:00+00:00   -0.014792   -0.000832       -0.023946
# 2024-05-23 16:00:00+00:00   -0.005357   -0.004796       -0.013530
#
#                            gld_target_ret  uso_target_ret  btc_ret_4h  ...  \
# Datetime                                                               ...
# 2024-05-21 16:00:00+00:00        0.001608        0.005214   -0.002706  ...
# 2024-05-22 12:00:00+00:00       -0.013023       -0.007288   -0.004718  ...
# 2024-05-22 16:00:00+00:00       -0.005332       -0.009326    0.015436  ...
# 2024-05-23 12:00:00+00:00       -0.014765       -0.000935   -0.010170  ...
# 2024-05-23 16:00:00+00:00       -0.005349       -0.004812   -0.023946  ...
#
#                            uso_mom_12  btc_mom_24  gld_mom_24  uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318    0.053013    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310    0.052775    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696    0.028633   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283    0.023005   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858    0.011992   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 7. Dataset de l'entorn multi-asset

# %%
feature_columns = [
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12",
    "uso_ret_4h",
    "uso_vol_12",

    "btc_mom_12",
    "gld_mom_12",
    "uso_mom_12",

    "btc_mom_24",
    "gld_mom_24",
    "uso_mom_24",

    "btc_vs_gld_mom_12",
    "btc_vs_uso_mom_12",
    "gld_vs_uso_mom_12",

    "btc_vs_gld_mom_24",
    "btc_vs_uso_mom_24",
    "gld_vs_uso_mom_24",
]

target_columns = [
    "btc_target_ret",
    "gld_target_ret",
    "uso_target_ret",
]

env_df = df_4h[feature_columns + target_columns].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1126, 21)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002706    0.021136   -0.003072    0.005197
# 2024-05-22 12:00:00+00:00   -0.004718    0.021402    0.001608    0.005164
# 2024-05-22 16:00:00+00:00    0.015436    0.019438   -0.013023    0.006874
# 2024-05-23 12:00:00+00:00   -0.010170    0.019984   -0.005332    0.007115
# 2024-05-23 16:00:00+00:00   -0.023946    0.017984   -0.014765    0.007459
#
#                            uso_ret_4h  uso_vol_12  btc_mom_12  gld_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.012836    0.007127    0.106514    0.035670
# 2024-05-22 12:00:00+00:00    0.005214    0.007248    0.099664    0.036712
# 2024-05-22 16:00:00+00:00   -0.007288    0.005950    0.140127    0.018127
# 2024-05-23 12:00:00+00:00   -0.009326    0.006557    0.132473    0.009262
# 2024-05-23 16:00:00+00:00   -0.000935    0.006547    0.052487   -0.017487
#
#                            uso_mom_12  btc_mom_24  ...  uso_mom_24  \
# Datetime                                           ...
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318  ...    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310  ...    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696  ...   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283  ...   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858  ...   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
#                            btc_target_ret  gld_target_ret  uso_target_ret
# Datetime
# 2024-05-21 16:00:00+00:00       -0.004718        0.001608        0.005214
# 2024-05-22 12:00:00+00:00        0.015436       -0.013023       -0.007288
# 2024-05-22 16:00:00+00:00       -0.010170       -0.005332       -0.009326
# 2024-05-23 12:00:00+00:00       -0.023946       -0.014765       -0.000935
# 2024-05-23 16:00:00+00:00       -0.013530       -0.005349       -0.004812
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 8. Split train/test temporal

# %%
split_idx = int(len(env_df) * TRAIN_SPLIT)

train_data = env_df.iloc[:split_idx].copy()
test_data = env_df.iloc[split_idx:].copy()

print("train_data:", train_data.shape)
print("test_data:", test_data.shape)
# Out:
# train_data: (900, 21)
# test_data: (226, 21)

# %% [markdown]
# ## 9. Creació dels entorns

# %%
env_train_multi = TradingEnv(
    data=train_data,
    feature_columns=feature_columns,
    transaction_cost=TRANSACTION_COST,
    inactivity_penalty=INACTIVITY_PENALTY,
)

env_test_multi = TradingEnv(
    data=test_data,
    feature_columns=feature_columns,
    transaction_cost=TRANSACTION_COST,
    inactivity_penalty=INACTIVITY_PENALTY,
)

obs, info = env_train_multi.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.00270647  0.02113599 -0.00307235  0.00519702 -0.01283556  0.00712712
#   0.10651411  0.0356702  -0.0024362   0.12831771  0.05301337  0.00417543
#   0.07084391  0.10895031  0.0381064   0.07530435  0.12414228  0.04883793
#   0.          0.        ]
# Observation shape: (20,)
# Info: {}

# %% [markdown]
# ## 10. Entrenament PPO

# %%
model_multi = PPO(
    "MlpPolicy",
    env_train_multi,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_multi.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 944 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.002238761 |
# |    clip_fraction        | 0.00703     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -3.72       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000659   |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.00412     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.009588974 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.544      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0277     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.314       |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0020208869 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.875       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0139      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 0.001        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.314       |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0022071213 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.141       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 0.00152      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.314      |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.009587146 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.0421     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00397    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 0.00305     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.314       |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0040537165 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.593       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00744     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 0.00284      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.352       |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0074325893 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.163       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0054      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.352     |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 9          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | 0.00598538 |
# |    clip_fraction        | 0.00937    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.0578    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00329   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00632   |
# |    value_loss           | 0.00133    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.352       |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0019847704 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.236       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00333      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.647     |
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 11         |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.01905195 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.126      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0459    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0236    |
# |    value_loss           | 0.000721   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.647       |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 12           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0020631773 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.0433       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.00228      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.647      |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 13          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.011781254 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0083     |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.647       |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 14           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0053574443 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00255      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0143      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.768       |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 15           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0019557371 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.057        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00886      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 0.00122      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.768       |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 16           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0053465087 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0381      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00641     |
# |    value_loss           | 0.000722     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.768      |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.003802685 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.055      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 0.00071     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.689      |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 18          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.004533565 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.189      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000551   |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.689      |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 19          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4864        |
# | train/                  |             |
# |    approx_kl            | 0.006409766 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.0374     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.689        |
# | time/                   |               |
# |    fps                  | 548           |
# |    iterations           | 20            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00092946924 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.0438        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000975     |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 0.0027        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.689       |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 21           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0014609601 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0439       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00058     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.00324      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.716      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 22          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.007892366 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.288      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 0.00234     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.716      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 23          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.006034001 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.297      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 0.0011      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.716     |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 24         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01975747 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.114     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.049     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0214    |
# |    value_loss           | 0.00104    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.727      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 25          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.008621194 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.133      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00224    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.727      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 26          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.002668715 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.258      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00703    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0013     |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.727      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 27          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.015181735 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 0.0294      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.727      |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 28          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.005786609 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.748      |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 29          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.007675558 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.011       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.748       |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 30           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0018767233 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00429     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.748      |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 31          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.001189423 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | -0.585      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00194     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.719      |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 32          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004026847 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.719       |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 33           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0037482297 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | -0.115       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00323      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 0.002        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.719       |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 34           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0018010575 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00349     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.000886     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.719        |
# | time/                   |               |
# |    fps                  | 541           |
# |    iterations           | 35            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 8960          |
# | train/                  |               |
# |    approx_kl            | 0.00048840186 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.797        |
# |    explained_variance   | 0.131         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00387      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000673     |
# |    value_loss           | 0.00154       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.713      |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 36          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.005639999 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000331   |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 0.000716    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.713      |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 37          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.008290421 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 0.000793    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.713       |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 38           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0036738282 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | -0.209       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00938     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.682       |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 39           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0054693115 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00359      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 0.0016       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.682       |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 40           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0017956083 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.671       |
# |    explained_variance   | -0.233       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0163      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00474     |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.682       |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 41           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10496        |
# | train/                  |              |
# |    approx_kl            | 0.0014696897 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.0228       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00888     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 0.00112      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.682      |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 42          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.007360145 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.703      |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 43          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.002600453 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | -0.185      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00849    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.703      |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 44          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.001589898 |
# |    clip_fraction        | 0.00117     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | -0.116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0014     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.703       |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 45           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0049829194 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | -0.0172      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0055      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 0.00122      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.644       |
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 46           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0019266522 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0127       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.644       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 47           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12032        |
# | train/                  |              |
# |    approx_kl            | 0.0046945475 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | -0.0277      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00632     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00852     |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.644       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 48           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0020370735 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.0034       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0106      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.644      |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 49          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.003979179 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00801    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 0.000882    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.617       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 50           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0037025993 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | -0.00193     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00676     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.617       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 51           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0011573511 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.161        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00368     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 0.00137      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.617       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 52           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0052114977 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000753    |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00616     |
# |    value_loss           | 0.00139      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.606       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 53           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 13568        |
# | train/                  |              |
# |    approx_kl            | 0.0034847097 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | -0.068       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00584     |
# |    value_loss           | 0.000913     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.606       |
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 54           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0008493026 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | -0.105       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00067     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 0.0022       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.606      |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 55          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.007863382 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | -0.173      |
# ...
# |    fps                  | 515          |
# |    iterations           | 179          |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0008657472 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.397       |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00156      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 0.00178      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.543       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 180          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0020951775 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | 0.0634       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00227     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.543       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 181          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 46336        |
# | train/                  |              |
# |    approx_kl            | 0.0033365756 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.351       |
# |    explained_variance   | -0.072       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00989     |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00865     |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.543       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 182          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46592        |
# | train/                  |              |
# |    approx_kl            | 0.0016189867 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.345       |
# |    explained_variance   | -0.0421      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0143      |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.00104      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.542      |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 183         |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 46848       |
# | train/                  |             |
# |    approx_kl            | 0.005438588 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00961    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.542       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 184          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0025217899 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.395       |
# |    explained_variance   | 0.0767       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -8.42e-05    |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.0039      |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.542       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 185          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 47360        |
# | train/                  |              |
# |    approx_kl            | 0.0025373795 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00684     |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.542      |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 186         |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 47616       |
# | train/                  |             |
# |    approx_kl            | 0.004984863 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.544       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 187          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 47872        |
# | train/                  |              |
# |    approx_kl            | 0.0015688094 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.414       |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0177      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.544      |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 188         |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.002146698 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.391      |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00401    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.544       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 189          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0025154224 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | -0.134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00548      |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 0.00183      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.539       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 190          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 48640        |
# | train/                  |              |
# |    approx_kl            | 0.0056797042 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | -0.0956      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000266    |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00942     |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.539       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 191          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 48896        |
# | train/                  |              |
# |    approx_kl            | 0.0032693788 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.417       |
# |    explained_variance   | 0.0134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00719     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 0.00264      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.539       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 192          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033468811 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | 0.0055       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00578     |
# |    value_loss           | 0.00346      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.539       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 193          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 49408        |
# | train/                  |              |
# |    approx_kl            | 0.0012025083 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 0.00201      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.528       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 194          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 49664        |
# | train/                  |              |
# |    approx_kl            | 0.0028178063 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00704      |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 0.00191      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.528       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 195          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 49920        |
# | train/                  |              |
# |    approx_kl            | 0.0015039376 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00558      |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.00188      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.528       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 196          |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0037378694 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.481       |
# |    explained_variance   | 0.00503      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000395     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.00152      |
# ------------------------------------------

# %% [markdown]
# ## 11. Funcions d'avaluació

# %%
def evaluate_model_multi_asset(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    actions = []
    assets = []
    holding_durations = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        assets.append(info["asset"])
        holding_durations.append(info["holding_duration"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "action": actions,
        "asset": assets,
        "holding_duration": holding_durations,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    return results


def compute_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

# %% [markdown]
# ## 12. Avaluació del model

# %%
results_multi = evaluate_model_multi_asset(model_multi, env_test_multi, test_data)

results_multi.head()
# Out:
#                              reward  action  asset  holding_duration    equity
# Datetime
# 2025-12-23 20:00:00+00:00  0.002098       0      0                 1  1.002098
# 2025-12-24 12:00:00+00:00 -0.001071       2      2                 0  1.001024
# 2025-12-24 16:00:00+00:00 -0.009407       0      0                 0  0.991608
# 2025-12-26 12:00:00+00:00  0.001917       0      0                 1  0.993509
# 2025-12-26 16:00:00+00:00 -0.019702       2      2                 0  0.973935

# %%
metrics_multi = compute_metrics_multi_asset(results_multi)

comparison_multi = pd.DataFrame(
    [metrics_multi],
    index=["MultiAsset_BTC_GLD_USO"]
)

comparison_multi
# Out:
#                         cumulative_return    sharpe  sortino  max_drawdown  \
# MultiAsset_BTC_GLD_USO          -0.079576 -0.259515 -0.35566     -0.291234
#
#                         n_switches
# MultiAsset_BTC_GLD_USO         141

# %% [markdown]
# ## 13. Benchmarks buy-and-hold

# %%
btc_bh = (1 + test_data["btc_ret_4h"]).prod() - 1
gld_bh = (1 + test_data["gld_ret_4h"]).prod() - 1
uso_bh = (1 + test_data["uso_ret_4h"]).prod() - 1

benchmarks = pd.DataFrame(
    [{
        "BTC Buy & Hold": btc_bh,
        "GLD Buy & Hold": gld_bh,
        "USO Buy & Hold": uso_bh,
    }]
)

benchmarks
# Out:
#    BTC Buy & Hold  GLD Buy & Hold  USO Buy & Hold
# 0       -0.112645        0.042992        1.055277

# %% [markdown]
# ## 14. Distribució d'accions i actius

# %%
print("Actions:")
print(results_multi["action"].value_counts())

print("\nAssets:")
print(results_multi["asset"].value_counts())
# Out:
# Actions:
# action
# 0    154
# 1     62
# 2      9
# Name: count, dtype: int64
#
# Assets:
# asset
# 0    154
# 1     62
# 2      9
# Name: count, dtype: int64

# %% [markdown]
# ## 15. Corba d'equity

# %%
plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["equity"], label="Multi-Asset Agent")
plt.title("Multi-Asset Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 16. Comparació visual amb buy-and-hold dels actius

# %%
bh_curves = pd.DataFrame(index=test_data.index)
bh_curves["BTC_BH"] = (1 + test_data["btc_ret_4h"]).cumprod()
bh_curves["GLD_BH"] = (1 + test_data["gld_ret_4h"]).cumprod()
bh_curves["USO_BH"] = (1 + test_data["uso_ret_4h"]).cumprod()

plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["equity"], label="Multi-Asset Agent")
plt.plot(bh_curves.index, bh_curves["BTC_BH"], label="BTC Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["GLD_BH"], label="GLD Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["USO_BH"], label="USO Buy & Hold", linestyle="--")
plt.title("Multi-Asset Agent vs Buy & Hold Benchmarks")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 17. Guardat de resultats

# %%
results_dir = project_root / "results"
results_dir.mkdir(exist_ok=True)

results_multi.to_csv(results_dir / "results_multi_asset_btc_gld_uso.csv")
comparison_multi.to_csv(results_dir / "comparison_multi_asset_btc_gld_uso.csv")
benchmarks.to_csv(results_dir / "benchmarks_multi_asset_btc_gld_uso.csv")

print("Results saved in:", results_dir)
# Out:
# Results saved in: c:\Users\rfran\OneDrive\Documentos\UOC\Master\TFM\tfm-drl-trading\results

# %%
np.random.seed(42)
test_data_shuffled = test_data.sample(frac=1)

env_test_random = TradingEnv(
    data=test_data_shuffled,
    feature_columns=feature_columns,
    transaction_cost=TRANSACTION_COST,
    inactivity_penalty=INACTIVITY_PENALTY,
)

results_random = evaluate_model_multi_asset(model_multi, env_test_random, test_data_shuffled)

compute_metrics_multi_asset(results_random)
# Out:
# {'cumulative_return': np.float64(-0.02422015125909427),
#  'sharpe': np.float64(0.0558003351175469),
#  'sortino': np.float64(0.0815269973649829),
#  'max_drawdown': np.float64(-0.24463523091893347),
#  'n_switches': 136}
