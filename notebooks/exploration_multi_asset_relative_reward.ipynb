# %% [markdown]
# # Experiment multi-asset: BTC vs GLD vs USO
#
# Aquest notebook reformula el problema com una tasca d'assignació dinàmica d'actius.
#
# L'agent decideix quin actiu mantenir en cada pas temporal:
#
# - `0 = BTC`
# - `1 = GLD`
# - `2 = USO`

# %%
import sys
from pathlib import Path

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_multi_asset_relative_reward import TradingEnv
from stable_baselines3 import PPO

# %% [markdown]
# ## 1. Configuració de l'experiment

# %%
EXPERIMENT_NAME = "multi_asset_relative_strength_relative_reward"
ACTION_TYPE = "asset_allocation_relative_reward"

BASE_TRANSACTION_COST = 0.001
DYNAMIC_COST_WEIGHT = 0.05
INACTIVITY_PENALTY = 0.001

TOTAL_TIMESTEPS = 50000
TRAIN_SPLIT = 0.8

print("Experiment:", EXPERIMENT_NAME)
print("Action type:", ACTION_TYPE)
print("Base transaction cost:", BASE_TRANSACTION_COST)
print("Dynamic cost weight:", DYNAMIC_COST_WEIGHT)
print("Inactivity penalty:", INACTIVITY_PENALTY)
print("Timesteps:", TOTAL_TIMESTEPS)
print("Train split:", TRAIN_SPLIT)
# Out:
# Experiment: multi_asset_relative_strength_relative_reward
# Action type: asset_allocation_relative_reward
# Base transaction cost: 0.001
# Dynamic cost weight: 0.05
# Inactivity penalty: 0.001
# Timesteps: 50000
# Train split: 0.8

# %% [markdown]
# ## 2. Descàrrega de dades

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)
uso = yf.download("USO", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
print("USO shape:", uso.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17356, 6)
# GLD shape: (5077, 6)
# USO shape: (5078, 6)

# %% [markdown]
# ## 3. Neteja de columnes

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)
uso.columns = uso.columns.get_level_values(0)

btc.columns.name = None
gld.columns.name = None
uso.columns.name = None

print(btc.columns)
print(gld.columns)
print(uso.columns)

btc.head(), gld.head(), uso.head()
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# (                              Adj Close         Close          High  \
#  Datetime
#  2024-05-03 00:00:00+00:00  59048.851562  59048.851562  59128.941406
#  2024-05-03 01:00:00+00:00  59359.304688  59359.304688  59490.843750
#  2024-05-03 02:00:00+00:00  59561.472656  59561.472656  59928.902344
#  2024-05-03 03:00:00+00:00  59740.558594  59740.558594  59992.253906
#  2024-05-03 04:00:00+00:00  59585.773438  59585.773438  59825.601562
#
#                                      Low          Open     Volume
#  Datetime
#  2024-05-03 00:00:00+00:00  58851.484375  59087.492188          0
#  2024-05-03 01:00:00+00:00  59040.808594  59053.320312          0
#  2024-05-03 02:00:00+00:00  59302.406250  59336.199219   26249216
#  2024-05-03 03:00:00+00:00  59557.214844  59557.214844  431472640
#  2024-05-03 04:00:00+00:00  59573.722656  59736.585938          0  ,
#                              Adj Close       Close        High         Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  181.940002  181.940002  182.235001  180.600006
#  2023-06-05 14:30:00+00:00  181.850006  181.850006  182.029999  181.649994
#  2023-06-05 15:30:00+00:00  181.919998  181.919998  182.151993  181.649994
#  2023-06-05 16:30:00+00:00  181.869995  181.869995  181.970001  181.779999
#  2023-06-05 17:30:00+00:00  182.169998  182.169998  182.330002  181.830002
#
#                                   Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  180.789993  1608462
#  2023-06-05 14:30:00+00:00  181.929993   521884
#  2023-06-05 15:30:00+00:00  181.852005   415074
#  2023-06-05 16:30:00+00:00  181.919998   675305
#  2023-06-05 17:30:00+00:00  181.875000  1027578  ,
#                             Adj Close      Close       High        Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  64.680000  64.680000  65.410004  64.220001
#  2023-06-05 14:30:00+00:00  64.930000  64.930000  64.959999  64.320000
#  2023-06-05 15:30:00+00:00  64.879997  64.879997  64.959999  64.580002
#  2023-06-05 16:30:00+00:00  64.629997  64.629997  65.040001  64.629997
#  2023-06-05 17:30:00+00:00  64.300003  64.300003  64.764999  64.239998
#
#                                  Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  65.370003  1253341
#  2023-06-05 14:30:00+00:00  64.669998   503423
#  2023-06-05 15:30:00+00:00  64.939102   273453
#  2023-06-05 16:30:00+00:00  64.879997   306210
#  2023-06-05 17:30:00+00:00  64.654999   277808  )

# %% [markdown]
# ## 4. Normalització temporal i sincronització

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()
uso_1h = uso[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")
uso_1h.index = uso_1h.index.floor("1h")

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})
uso_1h = uso_1h.rename(columns={"Close": "uso_close"})

print(btc_1h.head())
print(gld_1h.head())
print(uso_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-05-03 00:00:00+00:00  59048.851562
# 2024-05-03 01:00:00+00:00  59359.304688
# 2024-05-03 02:00:00+00:00  59561.472656
# 2024-05-03 03:00:00+00:00  59740.558594
# 2024-05-03 04:00:00+00:00  59585.773438
#                             gld_close
# Datetime
# 2023-06-05 13:00:00+00:00  181.940002
# 2023-06-05 14:00:00+00:00  181.850006
# 2023-06-05 15:00:00+00:00  181.919998
# 2023-06-05 16:00:00+00:00  181.869995
# 2023-06-05 17:00:00+00:00  182.169998
#                            uso_close
# Datetime
# 2023-06-05 13:00:00+00:00  64.680000
# 2023-06-05 14:00:00+00:00  64.930000
# 2023-06-05 15:00:00+00:00  64.879997
# 2023-06-05 16:00:00+00:00  64.629997
# 2023-06-05 17:00:00+00:00  64.300003

# %%
common_index = btc_1h.index.intersection(gld_1h.index).intersection(uso_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()
uso_sync = uso_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("USO sync shape:", uso_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3447, 1)
# GLD sync shape: (3447, 1)
# USO sync shape: (3447, 1)
# Start: 2024-05-03 13:00:00+00:00
# End: 2026-05-01 19:00:00+00:00

# %%
df = btc_sync.join(gld_sync, how="inner").join(uso_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3447, 3)
#                               btc_close   gld_close  uso_close
# Datetime
# 2024-05-03 13:00:00+00:00  61662.195312  211.570007  75.550003
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000

# %% [markdown]
# ## 5. Creació de retorns i agregació a 4 hores

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()
df["uso_ret_1h"] = df["uso_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000   -0.000032
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002    0.001729
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004   -0.001502
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000    0.002895
# 2024-05-03 18:00:00+00:00  61821.207031  212.720001  75.099998   -0.000508
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 14:00:00+00:00    0.002552    0.000265
# 2024-05-03 15:00:00+00:00    0.002263   -0.001720
# 2024-05-03 16:00:00+00:00    0.001153   -0.000398
# 2024-05-03 17:00:00+00:00   -0.000728   -0.004509
# 2024-05-03 18:00:00+00:00    0.000188    0.000400

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "uso_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum",
    "uso_ret_1h": "sum",
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1151, 6)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 12:00:00+00:00  61766.851562  212.589996  75.440002    0.001697
# 2024-05-03 16:00:00+00:00  62025.589844  212.979996  75.150002    0.004191
# 2024-05-06 12:00:00+00:00  63701.535156  215.139999  75.970001    0.027139
# 2024-05-06 16:00:00+00:00  63191.597656  215.169998  75.650002   -0.007982
# 2024-05-07 12:00:00+00:00  63724.531250  214.300003  75.800003    0.008454
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 12:00:00+00:00    0.004815   -0.001456
# 2024-05-03 16:00:00+00:00    0.001835   -0.003841
# 2024-05-06 12:00:00+00:00    0.010143    0.010888
# 2024-05-06 16:00:00+00:00    0.000141   -0.004177
# 2024-05-07 12:00:00+00:00   -0.004047    0.002050

# %% [markdown]
# ## 6. Feature engineering

# %%
# Target returns: retorns utilitzats per calcular la recompensa
df_4h["btc_target_ret"] = df_4h["btc_close"].pct_change()
df_4h["gld_target_ret"] = df_4h["gld_close"].pct_change()
df_4h["uso_target_ret"] = df_4h["uso_close"].pct_change()

# Features bàsiques amb informació passada
df_4h["btc_ret_4h"] = df_4h["btc_target_ret"].shift(1)
df_4h["gld_ret_4h"] = df_4h["gld_target_ret"].shift(1)
df_4h["uso_ret_4h"] = df_4h["uso_target_ret"].shift(1)

df_4h["btc_vol_12"] = df_4h["btc_target_ret"].rolling(12).std().shift(1)
df_4h["gld_vol_12"] = df_4h["gld_target_ret"].rolling(12).std().shift(1)
df_4h["uso_vol_12"] = df_4h["uso_target_ret"].rolling(12).std().shift(1)

# Momentum passat: rendiment acumulat en finestres més llargues
df_4h["btc_mom_12"] = df_4h["btc_close"].pct_change(12).shift(1)
df_4h["gld_mom_12"] = df_4h["gld_close"].pct_change(12).shift(1)
df_4h["uso_mom_12"] = df_4h["uso_close"].pct_change(12).shift(1)

df_4h["btc_mom_24"] = df_4h["btc_close"].pct_change(24).shift(1)
df_4h["gld_mom_24"] = df_4h["gld_close"].pct_change(24).shift(1)
df_4h["uso_mom_24"] = df_4h["uso_close"].pct_change(24).shift(1)

# Relative strength: comparació de força relativa entre actius
df_4h["btc_vs_gld_mom_12"] = df_4h["btc_mom_12"] - df_4h["gld_mom_12"]
df_4h["btc_vs_uso_mom_12"] = df_4h["btc_mom_12"] - df_4h["uso_mom_12"]
df_4h["gld_vs_uso_mom_12"] = df_4h["gld_mom_12"] - df_4h["uso_mom_12"]

df_4h["btc_vs_gld_mom_24"] = df_4h["btc_mom_24"] - df_4h["gld_mom_24"]
df_4h["btc_vs_uso_mom_24"] = df_4h["btc_mom_24"] - df_4h["uso_mom_24"]
df_4h["gld_vs_uso_mom_24"] = df_4h["gld_mom_24"] - df_4h["uso_mom_24"]

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1126, 27)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-21 16:00:00+00:00  69363.851562  224.220001  76.150002   -0.004709
# 2024-05-22 12:00:00+00:00  70434.546875  221.300003  75.595001    0.015375
# 2024-05-22 16:00:00+00:00  69718.234375  220.119995  74.889999   -0.010192
# 2024-05-23 12:00:00+00:00  68048.742188  216.869995  74.820000   -0.023934
# 2024-05-23 16:00:00+00:00  67128.031250  215.710007  74.459999   -0.013599
#
#                            gld_ret_1h  uso_ret_1h  btc_target_ret  \
# Datetime
# 2024-05-21 16:00:00+00:00    0.001611    0.005212       -0.004718
# 2024-05-22 12:00:00+00:00   -0.012989   -0.007253        0.015436
# 2024-05-22 16:00:00+00:00   -0.005336   -0.009350       -0.010170
# 2024-05-23 12:00:00+00:00   -0.014792   -0.000832       -0.023946
# 2024-05-23 16:00:00+00:00   -0.005357   -0.004796       -0.013530
#
#                            gld_target_ret  uso_target_ret  btc_ret_4h  ...  \
# Datetime                                                               ...
# 2024-05-21 16:00:00+00:00        0.001608        0.005214   -0.002706  ...
# 2024-05-22 12:00:00+00:00       -0.013023       -0.007288   -0.004718  ...
# 2024-05-22 16:00:00+00:00       -0.005332       -0.009326    0.015436  ...
# 2024-05-23 12:00:00+00:00       -0.014765       -0.000935   -0.010170  ...
# 2024-05-23 16:00:00+00:00       -0.005349       -0.004812   -0.023946  ...
#
#                            uso_mom_12  btc_mom_24  gld_mom_24  uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318    0.053013    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310    0.052775    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696    0.028633   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283    0.023005   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858    0.011992   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 7. Dataset de l'entorn multi-asset

# %%
feature_columns = [
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12",
    "uso_ret_4h",
    "uso_vol_12",

    "btc_mom_12",
    "gld_mom_12",
    "uso_mom_12",

    "btc_mom_24",
    "gld_mom_24",
    "uso_mom_24",

    "btc_vs_gld_mom_12",
    "btc_vs_uso_mom_12",
    "gld_vs_uso_mom_12",

    "btc_vs_gld_mom_24",
    "btc_vs_uso_mom_24",
    "gld_vs_uso_mom_24",
]

target_columns = [
    "btc_target_ret",
    "gld_target_ret",
    "uso_target_ret",
]

env_df = df_4h[feature_columns + target_columns].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1126, 21)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002706    0.021136   -0.003072    0.005197
# 2024-05-22 12:00:00+00:00   -0.004718    0.021402    0.001608    0.005164
# 2024-05-22 16:00:00+00:00    0.015436    0.019438   -0.013023    0.006874
# 2024-05-23 12:00:00+00:00   -0.010170    0.019984   -0.005332    0.007115
# 2024-05-23 16:00:00+00:00   -0.023946    0.017984   -0.014765    0.007459
#
#                            uso_ret_4h  uso_vol_12  btc_mom_12  gld_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.012836    0.007127    0.106514    0.035670
# 2024-05-22 12:00:00+00:00    0.005214    0.007248    0.099664    0.036712
# 2024-05-22 16:00:00+00:00   -0.007288    0.005950    0.140127    0.018127
# 2024-05-23 12:00:00+00:00   -0.009326    0.006557    0.132473    0.009262
# 2024-05-23 16:00:00+00:00   -0.000935    0.006547    0.052487   -0.017487
#
#                            uso_mom_12  btc_mom_24  ...  uso_mom_24  \
# Datetime                                           ...
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318  ...    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310  ...    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696  ...   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283  ...   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858  ...   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
#                            btc_target_ret  gld_target_ret  uso_target_ret
# Datetime
# 2024-05-21 16:00:00+00:00       -0.004718        0.001608        0.005214
# 2024-05-22 12:00:00+00:00        0.015436       -0.013023       -0.007288
# 2024-05-22 16:00:00+00:00       -0.010170       -0.005332       -0.009326
# 2024-05-23 12:00:00+00:00       -0.023946       -0.014765       -0.000935
# 2024-05-23 16:00:00+00:00       -0.013530       -0.005349       -0.004812
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 8. Split train/test temporal

# %%
split_idx = int(len(env_df) * TRAIN_SPLIT)

train_data = env_df.iloc[:split_idx].copy()
test_data = env_df.iloc[split_idx:].copy()

print("train_data:", train_data.shape)
print("test_data:", test_data.shape)
# Out:
# train_data: (900, 21)
# test_data: (226, 21)

# %% [markdown]
# ## 9. Creació dels entorns

# %%
env_train_multi = TradingEnv(
    data=train_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

env_test_multi = TradingEnv(
    data=test_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

obs, info = env_train_multi.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.00270647  0.02113599 -0.00307235  0.00519702 -0.01283556  0.00712712
#   0.10651411  0.0356702  -0.0024362   0.12831771  0.05301337  0.00417543
#   0.07084391  0.10895031  0.0381064   0.07530435  0.12414228  0.04883793
#   0.          0.        ]
# Observation shape: (20,)
# Info: {}

# %% [markdown]
# ## 10. Entrenament PPO

# %%
model_multi = PPO(
    "MlpPolicy",
    env_train_multi,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_multi.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 772 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 634          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0021703287 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -27.3        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0143      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00575     |
# |    value_loss           | 0.0346       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0047255456 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -4.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00455     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00606     |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.3        |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.002145343 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0592     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00436    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 0.00132     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.3        |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.004572194 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.598      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000186    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -1.3          |
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 6             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00050804066 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -0.237        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00638      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 0.000916      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.3         |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0045309784 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0379      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0221      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 0.000942     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.1        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008226779 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.164      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00322    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 0.000935    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -1.1        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.004221661 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -1.1         |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0033417477 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | -0.479       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00591     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 0.000418     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.947      |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.004000295 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 0.000644    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.947       |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 12           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0016986548 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | -0.167       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0112      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.947      |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 13          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.008980478 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | -0.217      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00293    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.947      |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.009167652 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -0.0359     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00657    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 0.00119     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.947       |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 15           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0018482336 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | -0.716       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0147      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 0.000798     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.947     |
# | time/                   |            |
# |    fps                  | 545        |
# |    iterations           | 16         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00914887 |
# |    clip_fraction        | 0.0988     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.823     |
# |    explained_variance   | -0.0116    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.01      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 0.00101    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.947       |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 17           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0023818929 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | -0.489       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00498      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.000684     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.95       |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 18          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.010874219 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.0506      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0311     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.000646    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.95        |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 19           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0039182575 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | -0.271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0185      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 0.00118      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.95        |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 20           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0025673034 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | -0.131       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00783     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 0.000564     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.95        |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 21           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0047614826 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | -0.298       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0126       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.000393     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.953       |
# | time/                   |              |
# |    fps                  | 529          |
# |    iterations           | 22           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0021780222 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0136      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 0.000571     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.953      |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 23          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.002039763 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | -0.158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00225     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.953      |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 24          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002227504 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | -0.274      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00337    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 0.000473    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.955       |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 25           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0059599755 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | -0.165       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0121      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.000375     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.955       |
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 26           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0042453036 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0105      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00733     |
# |    value_loss           | 0.000951     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.955      |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 27          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.008839427 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | -0.0479     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0377     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.000865    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.955       |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 28           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0072213486 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.663       |
# |    explained_variance   | -0.0608      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0058       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00537     |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 29          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.005365231 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.000614    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.98        |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 30           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0036066507 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.0157       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00731     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00795     |
# |    value_loss           | 0.000845     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 31          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.005082566 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | -0.797      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00786    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00458    |
# |    value_loss           | 0.000519    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 32          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003530102 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.707      |
# |    explained_variance   | -0.0319     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 0.000716    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 33          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.003969905 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 0.000883    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.98        |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 34           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0022748546 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | -0.0017      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00995      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 0.00136      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 35          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.002989583 |
# |    clip_fraction        | 0.0184      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | -0.0682     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00524    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.000443    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.932       |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 36           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0025943136 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.663       |
# |    explained_variance   | -0.102       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00896     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 0.000567     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.932       |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 37           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0035622716 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | -0.133       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00635     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.932      |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 38          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.004730518 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 0.000643    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.914       |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 39           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0041384334 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | -0.291       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0243      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00846     |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.914       |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 40           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0033436217 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | -0.14        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00313      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.914     |
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 41         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 10496      |
# | train/                  |            |
# |    approx_kl            | 0.00183822 |
# |    clip_fraction        | 0.0187     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.556     |
# |    explained_variance   | -0.254     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0107    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00419   |
# |    value_loss           | 0.000747   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.914       |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 42           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0025936041 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.0944       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00175     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 0.000627     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.894       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 43           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 11008        |
# | train/                  |              |
# |    approx_kl            | 0.0043973955 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | -0.306       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00107      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 0.000573     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.894       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 44           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0041301623 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | -0.0161      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00435     |
# |    value_loss           | 0.000909     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.894       |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 45           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0050157504 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.039        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00346      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00729     |
# |    value_loss           | 0.000494     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.902       |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 46           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0015748332 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.0112       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00599     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.000771     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.902      |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 47          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.004086173 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.00119     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.902       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 48           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0031155073 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | 0.00871      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00576     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 0.00109      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.902       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 49           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0048333714 |
# |    clip_fraction        | 0.098        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.523       |
# |    explained_variance   | 0.066        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000187    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.000663     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.927       |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 50           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0025229878 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | -0.0613      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00895     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 0.000629     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.927       |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 51           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0040531806 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.0431       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00226     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00637     |
# |    value_loss           | 0.000917     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.927      |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 52          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.004934852 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | -0.0382     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 0.000594    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.92        |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 53           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 13568        |
# | train/                  |              |
# |    approx_kl            | 0.0029925904 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.0638       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00772     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.000858     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.92       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 54          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.004644105 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | -0.00608    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00403    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.92        |
# | time/                   |              |
# |    fps                  | 517          |
# |    iterations           | 55           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0035739455 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# ...
# |    iterations           | 179          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0017370745 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.422        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0038      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.000966    |
# |    value_loss           | 0.000845     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.973       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 180          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0010174522 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000773     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 0.000448     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.973       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 181          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46336        |
# | train/                  |              |
# |    approx_kl            | 0.0009906436 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.145       |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00857     |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.000492    |
# |    value_loss           | 0.00065      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.973       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 182          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 46592        |
# | train/                  |              |
# |    approx_kl            | 0.0021425658 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00318     |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 0.000462     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.975       |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 183          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 46848        |
# | train/                  |              |
# |    approx_kl            | 0.0003943015 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000181     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.000462    |
# |    value_loss           | 0.000514     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.975     |
# | time/                   |            |
# |    fps                  | 511        |
# |    iterations           | 184        |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00131975 |
# |    clip_fraction        | 0.0164     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.139     |
# |    explained_variance   | -0.0959    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00192   |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | 0.000176   |
# |    value_loss           | 0.000953   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.975       |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 185          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 47360        |
# | train/                  |              |
# |    approx_kl            | 0.0020273076 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.133       |
# |    explained_variance   | -0.00414     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00876      |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 0.000735     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.975       |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 186          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0016197469 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.141       |
# |    explained_variance   | 0.415        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00636     |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 0.000593     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.973        |
# | time/                   |               |
# |    fps                  | 511           |
# |    iterations           | 187           |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 47872         |
# | train/                  |               |
# |    approx_kl            | 0.00039425725 |
# |    clip_fraction        | 0.00937       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.131        |
# |    explained_variance   | -0.243        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00315      |
# |    n_updates            | 1860          |
# |    policy_gradient_loss | -0.00142      |
# |    value_loss           | 0.00068       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.973        |
# | time/                   |               |
# |    fps                  | 511           |
# |    iterations           | 188           |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.00065646553 |
# |    clip_fraction        | 0.00273       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.137        |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00323      |
# |    n_updates            | 1870          |
# |    policy_gradient_loss | -0.000629     |
# |    value_loss           | 0.001         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.973       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 189          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0020703182 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.149       |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00643     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 0.000737     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.971       |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 190          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 48640        |
# | train/                  |              |
# |    approx_kl            | 0.0019410744 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | -0.531       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00268      |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 0.000725     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.971       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 191          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 48896        |
# | train/                  |              |
# |    approx_kl            | 0.0028687187 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.149       |
# |    explained_variance   | 0.0587       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00108     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00838     |
# |    value_loss           | 0.000874     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.971       |
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 192          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0014305143 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | -0.0952      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00566      |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 0.000812     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.971       |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 193          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 49408        |
# | train/                  |              |
# |    approx_kl            | 0.0016868345 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00383     |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 0.000607     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.963       |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 194          |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 49664        |
# | train/                  |              |
# |    approx_kl            | 0.0016553365 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | -0.0599      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000642    |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.000369     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.963       |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 195          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 49920        |
# | train/                  |              |
# |    approx_kl            | 0.0024845523 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000907     |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 0.00101      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.963      |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 196         |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.003479027 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00836     |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 0.000715    |
# -----------------------------------------

# %% [markdown]
# ## 11. Funcions d'avaluació

# %%
def evaluate_model_multi_asset(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    actions = []
    assets = []
    switching_costs = []
    inactivity_costs = []
    selected_returns = []
    selected_volatilities = []
    holding_durations = []
    market_mean_returns = []
    relative_returns = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        assets.append(info["asset"])
        switching_costs.append(info["switching_cost"])
        inactivity_costs.append(info["inactivity_cost"])
        selected_returns.append(info["selected_return"])
        selected_volatilities.append(info["selected_volatility"])
        holding_durations.append(info["holding_duration"])
        market_mean_returns.append(info["market_mean_return"])
        relative_returns.append(info["relative_return"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "action": actions,
        "asset": assets,
        "holding_duration": holding_durations,
        "selected_return": selected_returns,
        "market_mean_return": market_mean_returns,
        "relative_return": relative_returns,
        "selected_volatility": selected_volatilities,
        "switching_cost": switching_costs,
        "inactivity_cost": inactivity_costs,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    results["real_equity"] = (1 + results["selected_return"]).cumprod()
    return results

def compute_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

def compute_real_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["selected_return"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = (1 + rets).cumprod()
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

# %% [markdown]
# ## 12. Avaluació del model

# %%
results_multi = evaluate_model_multi_asset(model_multi, env_test_multi, test_data)

results_multi.head()
# Out:
#                              reward  action  asset  holding_duration  \
# Datetime
# 2025-12-23 20:00:00+00:00  0.000235       1      1                 0
# 2025-12-24 12:00:00+00:00  0.000425       1      1                 1
# 2025-12-24 16:00:00+00:00 -0.002426       1      1                 2
# 2025-12-26 12:00:00+00:00 -0.001939       2      2                 0
# 2025-12-26 16:00:00+00:00  0.015851       1      1                 0
#
#                            selected_return  market_mean_return  \
# Datetime
# 2025-12-23 20:00:00+00:00         0.006955            0.005355
# 2025-12-24 12:00:00+00:00         0.001380            0.000262
# 2025-12-24 16:00:00+00:00        -0.006800           -0.005472
# 2025-12-26 12:00:00+00:00         0.001638            0.002234
# 2025-12-26 16:00:00+00:00         0.015451           -0.001759
#
#                            relative_return  selected_volatility  \
# Datetime
# 2025-12-23 20:00:00+00:00         0.001601             0.007308
# 2025-12-24 12:00:00+00:00         0.001118             0.007418
# 2025-12-24 16:00:00+00:00        -0.001328             0.007381
# 2025-12-26 12:00:00+00:00        -0.000596             0.006864
# 2025-12-26 16:00:00+00:00         0.017210             0.007175
#
#                            switching_cost  inactivity_cost    equity  \
# Datetime
# 2025-12-23 20:00:00+00:00        0.001365         0.000000  1.000235
# 2025-12-24 12:00:00+00:00        0.000000         0.000693  1.000660
# 2025-12-24 16:00:00+00:00        0.000000         0.001099  0.998232
# 2025-12-26 12:00:00+00:00        0.001343         0.000000  0.996296
# 2025-12-26 16:00:00+00:00        0.001359         0.000000  1.012089
#
#                            real_equity
# Datetime
# 2025-12-23 20:00:00+00:00     1.006955
# 2025-12-24 12:00:00+00:00     1.008345
# 2025-12-24 16:00:00+00:00     1.001489
# 2025-12-26 12:00:00+00:00     1.003129
# 2025-12-26 16:00:00+00:00     1.018629

# %%
metrics_multi_reward = compute_metrics_multi_asset(results_multi)
metrics_multi_real = compute_real_metrics_multi_asset(results_multi)

comparison_multi = pd.DataFrame(
    [metrics_multi_reward, metrics_multi_real],
    index=[
        "MultiAsset_relative_reward",
        "MultiAsset_real_return",
    ]
)

comparison_multi
# Out:
#                             cumulative_return    sharpe   sortino  \
# MultiAsset_relative_reward          -0.313562 -2.443995 -3.771441
# MultiAsset_real_return               0.197114  1.248130  1.672969
#
#                             max_drawdown  n_switches
# MultiAsset_relative_reward     -0.377533         106
# MultiAsset_real_return         -0.244579         106

# %% [markdown]
# ## 13. Benchmarks buy-and-hold

# %%
btc_bh = (1 + test_data["btc_target_ret"]).prod() - 1
gld_bh = (1 + test_data["gld_target_ret"]).prod() - 1
uso_bh = (1 + test_data["uso_target_ret"]).prod() - 1

benchmarks = pd.DataFrame(
    [{
        "BTC Buy & Hold": btc_bh,
        "GLD Buy & Hold": gld_bh,
        "USO Buy & Hold": uso_bh,
    }]
)

benchmarks
# Out:
#    BTC Buy & Hold  GLD Buy & Hold  USO Buy & Hold
# 0       -0.103544        0.032093        1.045084

# %% [markdown]
# ## 14. Distribució d'accions i actius

# %%
print("Actions:")
print(results_multi["action"].value_counts())

print("\nAssets:")
print(results_multi["asset"].value_counts())
# Out:
# Actions:
# action
# 1    172
# 2     53
# Name: count, dtype: int64
#
# Assets:
# asset
# 1    172
# 2     53
# Name: count, dtype: int64

# %% [markdown]
# ## 15. Corba d'equity

# %%
plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["real_equity"], label="Multi-Asset Agent Real Equity")
plt.title("Multi-Asset Real Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 16. Comparació visual amb buy-and-hold dels actius

# %%
bh_curves = pd.DataFrame(index=test_data.index)
bh_curves["BTC_BH"] = (1 + test_data["btc_target_ret"]).cumprod()
bh_curves["GLD_BH"] = (1 + test_data["gld_target_ret"]).cumprod()
bh_curves["USO_BH"] = (1 + test_data["uso_target_ret"]).cumprod()

plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["real_equity"], label="Multi-Asset Agent")
plt.plot(bh_curves.index, bh_curves["BTC_BH"], label="BTC Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["GLD_BH"], label="GLD Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["USO_BH"], label="USO Buy & Hold", linestyle="--")
plt.title("Multi-Asset Agent vs Buy & Hold Benchmarks")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 17. Guardat de resultats

# %%
results_dir = project_root / "results"
results_dir.mkdir(exist_ok=True)

results_multi.to_csv(results_dir / "results_multi_asset_btc_gld_uso.csv")
comparison_multi.to_csv(results_dir / "comparison_multi_asset_btc_gld_uso.csv")
benchmarks.to_csv(results_dir / "benchmarks_multi_asset_btc_gld_uso.csv")

print("Results saved in:", results_dir)
# Out:
# Results saved in: c:\Users\rfran\OneDrive\Documentos\UOC\Master\TFM\tfm-drl-trading\results

# %%
np.random.seed(42)
test_data_shuffled = test_data.sample(frac=1)

env_test_random = TradingEnv(
    data=test_data_shuffled,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

results_random = evaluate_model_multi_asset(
    model_multi,
    env_test_random,
    test_data_shuffled
)

compute_metrics_multi_asset(results_random)
# Out:
# {'cumulative_return': np.float64(-0.4225460760036365),
#  'sharpe': np.float64(-4.01150134211236),
#  'sortino': np.float64(-5.105613383108498),
#  'max_drawdown': np.float64(-0.5009165869442254),
#  'n_switches': 105}
