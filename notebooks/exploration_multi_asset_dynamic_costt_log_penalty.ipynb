# %% [markdown]
# # Experiment multi-asset: BTC vs GLD vs USO
#
# Aquest notebook reformula el problema com una tasca d'assignació dinàmica d'actius.
#
# L'agent decideix quin actiu mantenir en cada pas temporal:
#
# - `0 = BTC`
# - `1 = GLD`
# - `2 = USO`

# %%
import sys
from pathlib import Path

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_multi_asset_dynamic_cost_log_penalty import TradingEnv
from stable_baselines3 import PPO

# %% [markdown]
# ## 1. Configuració de l'experiment

# %%
EXPERIMENT_NAME = "multi_asset_dynamic_cost_log_penalty"
ACTION_TYPE = "asset_allocation_with_dynamic_cost_and_log_inactivity_penalty"

BASE_TRANSACTION_COST = 0.001
DYNAMIC_COST_WEIGHT = 0.05
INACTIVITY_PENALTY = 0.001

TOTAL_TIMESTEPS = 50000
TRAIN_SPLIT = 0.8

print("Experiment:", EXPERIMENT_NAME)
print("Action type:", ACTION_TYPE)
print("Base transaction cost:", BASE_TRANSACTION_COST)
print("Dynamic cost weight:", DYNAMIC_COST_WEIGHT)
print("Inactivity penalty:", INACTIVITY_PENALTY)
print("Timesteps:", TOTAL_TIMESTEPS)
print("Train split:", TRAIN_SPLIT)
# Out:
# Experiment: multi_asset_dynamic_cost_log_penalty
# Action type: asset_allocation_with_dynamic_cost_and_log_inactivity_penalty
# Base transaction cost: 0.001
# Dynamic cost weight: 0.05
# Inactivity penalty: 0.001
# Timesteps: 50000
# Train split: 0.8

# %% [markdown]
# ## 2. Descàrrega de dades

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)
uso = yf.download("USO", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
print("USO shape:", uso.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17354, 6)
# GLD shape: (5077, 6)
# USO shape: (5078, 6)

# %% [markdown]
# ## 3. Neteja de columnes

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)
uso.columns = uso.columns.get_level_values(0)

btc.columns.name = None
gld.columns.name = None
uso.columns.name = None

print(btc.columns)
print(gld.columns)
print(uso.columns)

btc.head(), gld.head(), uso.head()
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# (                              Adj Close         Close          High  \
#  Datetime
#  2024-05-03 00:00:00+00:00  59048.851562  59048.851562  59128.941406
#  2024-05-03 01:00:00+00:00  59359.304688  59359.304688  59490.843750
#  2024-05-03 02:00:00+00:00  59561.472656  59561.472656  59928.902344
#  2024-05-03 03:00:00+00:00  59740.558594  59740.558594  59992.253906
#  2024-05-03 04:00:00+00:00  59585.773438  59585.773438  59825.601562
#
#                                      Low          Open     Volume
#  Datetime
#  2024-05-03 00:00:00+00:00  58851.484375  59087.492188          0
#  2024-05-03 01:00:00+00:00  59040.808594  59053.320312          0
#  2024-05-03 02:00:00+00:00  59302.406250  59336.199219   26249216
#  2024-05-03 03:00:00+00:00  59557.214844  59557.214844  431472640
#  2024-05-03 04:00:00+00:00  59573.722656  59736.585938          0  ,
#                              Adj Close       Close        High         Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  181.940002  181.940002  182.235001  180.600006
#  2023-06-05 14:30:00+00:00  181.850006  181.850006  182.029999  181.649994
#  2023-06-05 15:30:00+00:00  181.919998  181.919998  182.151993  181.649994
#  2023-06-05 16:30:00+00:00  181.869995  181.869995  181.970001  181.779999
#  2023-06-05 17:30:00+00:00  182.169998  182.169998  182.330002  181.830002
#
#                                   Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  180.789993  1608462
#  2023-06-05 14:30:00+00:00  181.929993   521884
#  2023-06-05 15:30:00+00:00  181.852005   415074
#  2023-06-05 16:30:00+00:00  181.919998   675305
#  2023-06-05 17:30:00+00:00  181.875000  1027578  ,
#                             Adj Close      Close       High        Low  \
#  Datetime
#  2023-06-05 13:30:00+00:00  64.680000  64.680000  65.410004  64.220001
#  2023-06-05 14:30:00+00:00  64.930000  64.930000  64.959999  64.320000
#  2023-06-05 15:30:00+00:00  64.879997  64.879997  64.959999  64.580002
#  2023-06-05 16:30:00+00:00  64.629997  64.629997  65.040001  64.629997
#  2023-06-05 17:30:00+00:00  64.300003  64.300003  64.764999  64.239998
#
#                                  Open   Volume
#  Datetime
#  2023-06-05 13:30:00+00:00  65.370003  1253341
#  2023-06-05 14:30:00+00:00  64.669998   503423
#  2023-06-05 15:30:00+00:00  64.939102   273453
#  2023-06-05 16:30:00+00:00  64.879997   306210
#  2023-06-05 17:30:00+00:00  64.654999   277808  )

# %% [markdown]
# ## 4. Normalització temporal i sincronització

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()
uso_1h = uso[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")
uso_1h.index = uso_1h.index.floor("1h")

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})
uso_1h = uso_1h.rename(columns={"Close": "uso_close"})

print(btc_1h.head())
print(gld_1h.head())
print(uso_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-05-03 00:00:00+00:00  59048.851562
# 2024-05-03 01:00:00+00:00  59359.304688
# 2024-05-03 02:00:00+00:00  59561.472656
# 2024-05-03 03:00:00+00:00  59740.558594
# 2024-05-03 04:00:00+00:00  59585.773438
#                             gld_close
# Datetime
# 2023-06-05 13:00:00+00:00  181.940002
# 2023-06-05 14:00:00+00:00  181.850006
# 2023-06-05 15:00:00+00:00  181.919998
# 2023-06-05 16:00:00+00:00  181.869995
# 2023-06-05 17:00:00+00:00  182.169998
#                            uso_close
# Datetime
# 2023-06-05 13:00:00+00:00  64.680000
# 2023-06-05 14:00:00+00:00  64.930000
# 2023-06-05 15:00:00+00:00  64.879997
# 2023-06-05 16:00:00+00:00  64.629997
# 2023-06-05 17:00:00+00:00  64.300003

# %%
common_index = btc_1h.index.intersection(gld_1h.index).intersection(uso_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()
uso_sync = uso_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("USO sync shape:", uso_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3447, 1)
# GLD sync shape: (3447, 1)
# USO sync shape: (3447, 1)
# Start: 2024-05-03 13:00:00+00:00
# End: 2026-05-01 19:00:00+00:00

# %%
df = btc_sync.join(gld_sync, how="inner").join(uso_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3447, 3)
#                               btc_close   gld_close  uso_close
# Datetime
# 2024-05-03 13:00:00+00:00  61662.195312  211.570007  75.550003
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000

# %% [markdown]
# ## 5. Creació de retorns i agregació a 4 hores

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()
df["uso_ret_1h"] = df["uso_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 14:00:00+00:00  61660.226562  212.110001  75.570000   -0.000032
# 2024-05-03 15:00:00+00:00  61766.851562  212.589996  75.440002    0.001729
# 2024-05-03 16:00:00+00:00  61674.062500  212.835007  75.410004   -0.001502
# 2024-05-03 17:00:00+00:00  61852.609375  212.679993  75.070000    0.002895
# 2024-05-03 18:00:00+00:00  61821.207031  212.720001  75.099998   -0.000508
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 14:00:00+00:00    0.002552    0.000265
# 2024-05-03 15:00:00+00:00    0.002263   -0.001720
# 2024-05-03 16:00:00+00:00    0.001153   -0.000398
# 2024-05-03 17:00:00+00:00   -0.000728   -0.004509
# 2024-05-03 18:00:00+00:00    0.000188    0.000400

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "uso_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum",
    "uso_ret_1h": "sum",
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1151, 6)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-03 12:00:00+00:00  61766.851562  212.589996  75.440002    0.001697
# 2024-05-03 16:00:00+00:00  62025.589844  212.979996  75.150002    0.004191
# 2024-05-06 12:00:00+00:00  63701.535156  215.139999  75.970001    0.027139
# 2024-05-06 16:00:00+00:00  63191.597656  215.169998  75.650002   -0.007982
# 2024-05-07 12:00:00+00:00  63724.531250  214.300003  75.800003    0.008454
#
#                            gld_ret_1h  uso_ret_1h
# Datetime
# 2024-05-03 12:00:00+00:00    0.004815   -0.001456
# 2024-05-03 16:00:00+00:00    0.001835   -0.003841
# 2024-05-06 12:00:00+00:00    0.010143    0.010888
# 2024-05-06 16:00:00+00:00    0.000141   -0.004177
# 2024-05-07 12:00:00+00:00   -0.004047    0.002050

# %% [markdown]
# ## 6. Feature engineering

# %%
# Target returns: retorns utilitzats per calcular la recompensa
df_4h["btc_target_ret"] = df_4h["btc_close"].pct_change()
df_4h["gld_target_ret"] = df_4h["gld_close"].pct_change()
df_4h["uso_target_ret"] = df_4h["uso_close"].pct_change()

# Features bàsiques amb informació passada
df_4h["btc_ret_4h"] = df_4h["btc_target_ret"].shift(1)
df_4h["gld_ret_4h"] = df_4h["gld_target_ret"].shift(1)
df_4h["uso_ret_4h"] = df_4h["uso_target_ret"].shift(1)

df_4h["btc_vol_12"] = df_4h["btc_target_ret"].rolling(12).std().shift(1)
df_4h["gld_vol_12"] = df_4h["gld_target_ret"].rolling(12).std().shift(1)
df_4h["uso_vol_12"] = df_4h["uso_target_ret"].rolling(12).std().shift(1)

# Momentum passat: rendiment acumulat en finestres més llargues
df_4h["btc_mom_12"] = df_4h["btc_close"].pct_change(12).shift(1)
df_4h["gld_mom_12"] = df_4h["gld_close"].pct_change(12).shift(1)
df_4h["uso_mom_12"] = df_4h["uso_close"].pct_change(12).shift(1)

df_4h["btc_mom_24"] = df_4h["btc_close"].pct_change(24).shift(1)
df_4h["gld_mom_24"] = df_4h["gld_close"].pct_change(24).shift(1)
df_4h["uso_mom_24"] = df_4h["uso_close"].pct_change(24).shift(1)

# Relative strength: comparació de força relativa entre actius
df_4h["btc_vs_gld_mom_12"] = df_4h["btc_mom_12"] - df_4h["gld_mom_12"]
df_4h["btc_vs_uso_mom_12"] = df_4h["btc_mom_12"] - df_4h["uso_mom_12"]
df_4h["gld_vs_uso_mom_12"] = df_4h["gld_mom_12"] - df_4h["uso_mom_12"]

df_4h["btc_vs_gld_mom_24"] = df_4h["btc_mom_24"] - df_4h["gld_mom_24"]
df_4h["btc_vs_uso_mom_24"] = df_4h["btc_mom_24"] - df_4h["uso_mom_24"]
df_4h["gld_vs_uso_mom_24"] = df_4h["gld_mom_24"] - df_4h["uso_mom_24"]

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1126, 27)
#                               btc_close   gld_close  uso_close  btc_ret_1h  \
# Datetime
# 2024-05-21 16:00:00+00:00  69363.851562  224.220001  76.150002   -0.004709
# 2024-05-22 12:00:00+00:00  70434.546875  221.300003  75.595001    0.015375
# 2024-05-22 16:00:00+00:00  69718.234375  220.119995  74.889999   -0.010192
# 2024-05-23 12:00:00+00:00  68048.742188  216.869995  74.820000   -0.023934
# 2024-05-23 16:00:00+00:00  67128.031250  215.710007  74.459999   -0.013599
#
#                            gld_ret_1h  uso_ret_1h  btc_target_ret  \
# Datetime
# 2024-05-21 16:00:00+00:00    0.001611    0.005212       -0.004718
# 2024-05-22 12:00:00+00:00   -0.012989   -0.007253        0.015436
# 2024-05-22 16:00:00+00:00   -0.005336   -0.009350       -0.010170
# 2024-05-23 12:00:00+00:00   -0.014792   -0.000832       -0.023946
# 2024-05-23 16:00:00+00:00   -0.005357   -0.004796       -0.013530
#
#                            gld_target_ret  uso_target_ret  btc_ret_4h  ...  \
# Datetime                                                               ...
# 2024-05-21 16:00:00+00:00        0.001608        0.005214   -0.002706  ...
# 2024-05-22 12:00:00+00:00       -0.013023       -0.007288   -0.004718  ...
# 2024-05-22 16:00:00+00:00       -0.005332       -0.009326    0.015436  ...
# 2024-05-23 12:00:00+00:00       -0.014765       -0.000935   -0.010170  ...
# 2024-05-23 16:00:00+00:00       -0.005349       -0.004812   -0.023946  ...
#
#                            uso_mom_12  btc_mom_24  gld_mom_24  uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318    0.053013    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310    0.052775    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696    0.028633   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283    0.023005   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858    0.011992   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 7. Dataset de l'entorn multi-asset

# %%
feature_columns = [
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12",
    "uso_ret_4h",
    "uso_vol_12",

    "btc_mom_12",
    "gld_mom_12",
    "uso_mom_12",

    "btc_mom_24",
    "gld_mom_24",
    "uso_mom_24",

    "btc_vs_gld_mom_12",
    "btc_vs_uso_mom_12",
    "gld_vs_uso_mom_12",

    "btc_vs_gld_mom_24",
    "btc_vs_uso_mom_24",
    "gld_vs_uso_mom_24",
]

target_columns = [
    "btc_target_ret",
    "gld_target_ret",
    "uso_target_ret",
]

env_df = df_4h[feature_columns + target_columns].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1126, 21)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.002706    0.021136   -0.003072    0.005197
# 2024-05-22 12:00:00+00:00   -0.004718    0.021402    0.001608    0.005164
# 2024-05-22 16:00:00+00:00    0.015436    0.019438   -0.013023    0.006874
# 2024-05-23 12:00:00+00:00   -0.010170    0.019984   -0.005332    0.007115
# 2024-05-23 16:00:00+00:00   -0.023946    0.017984   -0.014765    0.007459
#
#                            uso_ret_4h  uso_vol_12  btc_mom_12  gld_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00   -0.012836    0.007127    0.106514    0.035670
# 2024-05-22 12:00:00+00:00    0.005214    0.007248    0.099664    0.036712
# 2024-05-22 16:00:00+00:00   -0.007288    0.005950    0.140127    0.018127
# 2024-05-23 12:00:00+00:00   -0.009326    0.006557    0.132473    0.009262
# 2024-05-23 16:00:00+00:00   -0.000935    0.006547    0.052487   -0.017487
#
#                            uso_mom_12  btc_mom_24  ...  uso_mom_24  \
# Datetime                                           ...
# 2024-05-21 16:00:00+00:00   -0.002436    0.128318  ...    0.004175
# 2024-05-22 12:00:00+00:00   -0.000131    0.118310  ...    0.013307
# 2024-05-22 16:00:00+00:00    0.008068    0.105696  ...   -0.004936
# 2024-05-23 12:00:00+00:00   -0.004122    0.103283  ...   -0.010046
# 2024-05-23 16:00:00+00:00   -0.005980    0.067858  ...   -0.012929
#
#                            btc_vs_gld_mom_12  btc_vs_uso_mom_12  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.070844           0.108950
# 2024-05-22 12:00:00+00:00           0.062953           0.099796
# 2024-05-22 16:00:00+00:00           0.122001           0.132060
# 2024-05-23 12:00:00+00:00           0.123211           0.136595
# 2024-05-23 16:00:00+00:00           0.069975           0.058467
#
#                            gld_vs_uso_mom_12  btc_vs_gld_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.038106           0.075304
# 2024-05-22 12:00:00+00:00           0.036843           0.065535
# 2024-05-22 16:00:00+00:00           0.010059           0.077064
# 2024-05-23 12:00:00+00:00           0.013384           0.080278
# 2024-05-23 16:00:00+00:00          -0.011508           0.055865
#
#                            btc_vs_uso_mom_24  gld_vs_uso_mom_24  \
# Datetime
# 2024-05-21 16:00:00+00:00           0.124142           0.048838
# 2024-05-22 12:00:00+00:00           0.105004           0.039468
# 2024-05-22 16:00:00+00:00           0.110632           0.033569
# 2024-05-23 12:00:00+00:00           0.113330           0.033051
# 2024-05-23 16:00:00+00:00           0.080787           0.024921
#
#                            btc_target_ret  gld_target_ret  uso_target_ret
# Datetime
# 2024-05-21 16:00:00+00:00       -0.004718        0.001608        0.005214
# 2024-05-22 12:00:00+00:00        0.015436       -0.013023       -0.007288
# 2024-05-22 16:00:00+00:00       -0.010170       -0.005332       -0.009326
# 2024-05-23 12:00:00+00:00       -0.023946       -0.014765       -0.000935
# 2024-05-23 16:00:00+00:00       -0.013530       -0.005349       -0.004812
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 8. Split train/test temporal

# %%
split_idx = int(len(env_df) * TRAIN_SPLIT)

train_data = env_df.iloc[:split_idx].copy()
test_data = env_df.iloc[split_idx:].copy()

print("train_data:", train_data.shape)
print("test_data:", test_data.shape)
# Out:
# train_data: (900, 21)
# test_data: (226, 21)

# %% [markdown]
# ## 9. Creació dels entorns

# %%
env_train_multi = TradingEnv(
    data=train_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

env_test_multi = TradingEnv(
    data=test_data,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

obs, info = env_train_multi.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.00270647  0.02113599 -0.00307235  0.00519702 -0.01283556  0.00712712
#   0.10651411  0.0356702  -0.0024362   0.12831771  0.05301337  0.00417543
#   0.07084391  0.10895031  0.0381064   0.07530435  0.12414228  0.04883793
#   0.          0.        ]
# Observation shape: (20,)
# Info: {}

# %% [markdown]
# ## 10. Entrenament PPO

# %%
model_multi = PPO(
    "MlpPolicy",
    env_train_multi,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_multi.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1007 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 256  |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.004461608 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -4.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00853    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00578    |
# |    value_loss           | 0.0153      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0005370353 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.78        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00363      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.694       |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0021674244 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.848       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.015       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.694      |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.011967707 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0971     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.694      |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.002283893 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000806    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.694      |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.008015978 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0982     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.602       |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0016375696 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.135       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00362      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 0.000943     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.602      |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.007190803 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.602      |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005028639 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.000577    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.706      |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.009862239 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.706     |
# | time/                   |            |
# |    fps                  | 557        |
# |    iterations           | 12         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.01264556 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | -0.225     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0318    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0177    |
# |    value_loss           | 0.00172    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.706       |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 13           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0067846607 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0227      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0252       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 0.00117      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.706       |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 14           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0069864094 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.937       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0354      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00851     |
# |    value_loss           | 0.00154      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.7          |
# | time/                   |               |
# |    fps                  | 563           |
# |    iterations           | 15            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 0.00047505135 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.0521        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00253      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000245     |
# |    value_loss           | 0.00131       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.7         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 16           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0063611986 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.0864      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000166     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.7       |
# | time/                   |            |
# |    fps                  | 566        |
# |    iterations           | 17         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4352       |
# | train/                  |            |
# |    approx_kl            | 0.00261533 |
# |    clip_fraction        | 0.0043     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.207     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00816   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00417   |
# |    value_loss           | 0.000808   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.768     |
# | time/                   |            |
# |    fps                  | 566        |
# |    iterations           | 18         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.00799443 |
# |    clip_fraction        | 0.0168     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.257     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0334    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00904   |
# |    value_loss           | 0.00102    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.768       |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 19           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0014110452 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.021        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0151      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 0.00102      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.768      |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 20          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.012200044 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.768      |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 21          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.004108641 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0423     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.71        |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 22           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0059108343 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00581      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00697     |
# |    value_loss           | 0.000976     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.71        |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 23           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0038042741 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0284      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00734     |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.71        |
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 24           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0013481481 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.659       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00963     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 0.000839     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.834     |
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 25         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 6400       |
# | train/                  |            |
# |    approx_kl            | 0.00696544 |
# |    clip_fraction        | 0.0254     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.0238     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0178    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 0.0013     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.834       |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 26           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0048717414 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0817       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0168      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00863     |
# |    value_loss           | 0.00181      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.834       |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 27           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0029372878 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0121      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 0.00091      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.834       |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 28           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0017611245 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0485      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00156     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 0.00129      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.783       |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 29           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 0.0012391412 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00715     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 0.00104      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.783       |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 30           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0032222439 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0578       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0024      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 0.00137      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.783      |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 31          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.008058971 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.639      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0276     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 0.000826    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.731      |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 32          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005229288 |
# |    clip_fraction        | 0.00547     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.731       |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 33           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0044948133 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.00539      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00173      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00588     |
# |    value_loss           | 0.00103      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.731       |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 34           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0070052706 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0108      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0019       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 0.000953     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.731       |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 35           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0021017613 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00158      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.000403     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.73       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 36          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.000738011 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.26       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00446    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 0.000391    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.73        |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 37           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0018004382 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0647       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00489     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -0.73      |
# | time/                   |            |
# |    fps                  | 555        |
# |    iterations           | 38         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.00934496 |
# |    clip_fraction        | 0.0344     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.0536    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0376    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0113    |
# |    value_loss           | 0.000552   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.752      |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 39          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.010888811 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00979    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.752      |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 40          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006009004 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.441      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0458     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.752      |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 41          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | 0.007142135 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00408    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00165     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.752       |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 42           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0013970253 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.0501      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00524      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 0.00117      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.778       |
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 43           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 11008        |
# | train/                  |              |
# |    approx_kl            | 0.0018309657 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0528      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0144      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 0.00108      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.778        |
# | time/                   |               |
# |    fps                  | 541           |
# |    iterations           | 44            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00026363065 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00297       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000434     |
# |    value_loss           | 0.00127       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.778       |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 45           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0061710225 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -1.91        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0207      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00633     |
# |    value_loss           | 0.000738     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.857      |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 46          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.009862852 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0229     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 0.000955    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.857       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 47           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12032        |
# | train/                  |              |
# |    approx_kl            | 0.0017484524 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000629     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 0.000847     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.857       |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 48           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0029378457 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.252       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00149      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 0.00137      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.857      |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 49          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.003176977 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00879    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 0.000442    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.844      |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 50          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.016140476 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00446    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00928    |
# |    value_loss           | 0.000637    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.844      |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 51          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 13056       |
# | train/                  |             |
# |    approx_kl            | 0.019933548 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.886      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0416     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.000832    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.844       |
# | time/                   |              |
# |    fps                  | 535          |
# |    iterations           | 52           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0030929728 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.0873       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00945     |
# |    value_loss           | 0.000648     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.848        |
# | time/                   |               |
# |    fps                  | 534           |
# |    iterations           | 53            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 13568         |
# | train/                  |               |
# |    approx_kl            | 0.00072703115 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.843        |
# |    explained_variance   | -0.0816       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00663      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.00286      |
# |    value_loss           | 0.000654      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.848      |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 54          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.022669889 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.0573      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.000695    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.848       |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 55           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0060712416 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.0792       |
# ...
# |    iterations           | 179          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0056486162 |
# |    clip_fraction        | 0.0746       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0146      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 0.000246     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.732       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 180          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0010888304 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | -0.165       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00173      |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 0.000291     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.732       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 181          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46336        |
# | train/                  |              |
# |    approx_kl            | 0.0009787378 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -0.00432     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.000508     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.732       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 182          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46592        |
# | train/                  |              |
# |    approx_kl            | 0.0013953494 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00652     |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 0.000255     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.723       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 183          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 46848        |
# | train/                  |              |
# |    approx_kl            | 0.0011599306 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.286       |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00256      |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 0.000564     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.723       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 184          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020128272 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | -0.0782      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00391      |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.000895     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.723       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 185          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 47360        |
# | train/                  |              |
# |    approx_kl            | 0.0025646572 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.278       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00308      |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 0.000309     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.723       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 186          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0012940934 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | 0.0236       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000499    |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00364     |
# |    value_loss           | 0.00063      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.724       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 187          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 47872        |
# | train/                  |              |
# |    approx_kl            | 0.0019771203 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | -0.0256      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0152      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00595     |
# |    value_loss           | 0.000498     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.724       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 188          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0031936753 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | -0.00592     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 0.000489     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.724       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 189          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0016383999 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.307       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00565      |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 0.000342     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.718       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 190          |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 48640        |
# | train/                  |              |
# |    approx_kl            | 0.0012493585 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00928     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 0.000533     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.718      |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 191         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 48896       |
# | train/                  |             |
# |    approx_kl            | 0.003141421 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.302      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00835    |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 0.000632    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.718       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 192          |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0036448205 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00454     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 0.000465     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -0.718      |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 193         |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 49408       |
# | train/                  |             |
# |    approx_kl            | 0.002082526 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00518    |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 0.00033     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -0.717       |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 194          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 49664        |
# | train/                  |              |
# |    approx_kl            | 0.0019016163 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00294     |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 0.000384     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.717        |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 195           |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 49920         |
# | train/                  |               |
# |    approx_kl            | 0.00084383786 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.313        |
# |    explained_variance   | 0.0297        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00727      |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -0.00249      |
# |    value_loss           | 0.000584      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -0.717        |
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 196           |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00015044585 |
# |    clip_fraction        | 0.0129        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.335        |
# |    explained_variance   | 0.127         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00194      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 0.000587      |
# -------------------------------------------

# %% [markdown]
# ## 11. Funcions d'avaluació

# %%
def evaluate_model_multi_asset(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    actions = []
    assets = []
    switching_costs = []
    inactivity_costs = []
    selected_returns = []
    selected_volatilities = []
    holding_durations = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        assets.append(info["asset"])
        switching_costs.append(info["switching_cost"])
        inactivity_costs.append(info["inactivity_cost"])
        selected_returns.append(info["selected_return"])
        selected_volatilities.append(info["selected_volatility"])
        holding_durations.append(info["holding_duration"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "action": actions,
        "asset": assets,
        "holding_duration": holding_durations,
        "selected_return": selected_returns,
        "selected_volatility": selected_volatilities,
        "switching_cost": switching_costs,
        "inactivity_cost": inactivity_costs,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    return results

def compute_metrics_multi_asset(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 1e-8:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 1e-8:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    asset_changes = results_df["asset"].diff().fillna(0)
    n_switches = int((asset_changes != 0).sum())

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_switches": n_switches,
    }

# %% [markdown]
# ## 12. Avaluació del model

# %%
results_multi = evaluate_model_multi_asset(model_multi, env_test_multi, test_data)

results_multi.head()
# Out:
#                              reward  action  asset  holding_duration  \
# Datetime
# 2025-12-23 20:00:00+00:00  0.004664       2      2                 0
# 2025-12-24 12:00:00+00:00  0.000009       1      1                 0
# 2025-12-24 16:00:00+00:00 -0.007493       1      1                 1
# 2025-12-26 12:00:00+00:00  0.001049       1      1                 2
# 2025-12-26 16:00:00+00:00  0.014064       1      1                 3
#
#                            selected_return  selected_volatility  \
# Datetime
# 2025-12-23 20:00:00+00:00         0.006011             0.006941
# 2025-12-24 12:00:00+00:00         0.001380             0.007418
# 2025-12-24 16:00:00+00:00        -0.006800             0.007381
# 2025-12-26 12:00:00+00:00         0.002148             0.007832
# 2025-12-26 16:00:00+00:00         0.015451             0.007175
#
#                            switching_cost  inactivity_cost    equity
# Datetime
# 2025-12-23 20:00:00+00:00        0.001347         0.000000  1.004664
# 2025-12-24 12:00:00+00:00        0.001371         0.000000  1.004673
# 2025-12-24 16:00:00+00:00        0.000000         0.000693  0.997146
# 2025-12-26 12:00:00+00:00        0.000000         0.001099  0.998191
# 2025-12-26 16:00:00+00:00        0.000000         0.001386  1.012230

# %%
metrics_multi = compute_metrics_multi_asset(results_multi)

comparison_multi = pd.DataFrame(
    [metrics_multi],
    index=["MultiAsset_BTC_GLD_USO"]
)

comparison_multi
# Out:
#                         cumulative_return    sharpe   sortino  max_drawdown  \
# MultiAsset_BTC_GLD_USO          -0.295848 -1.823708 -1.984132     -0.414325
#
#                         n_switches
# MultiAsset_BTC_GLD_USO          71

# %% [markdown]
# ## 13. Benchmarks buy-and-hold

# %%
btc_bh = (1 + test_data["btc_ret_4h"]).prod() - 1
gld_bh = (1 + test_data["gld_ret_4h"]).prod() - 1
uso_bh = (1 + test_data["uso_ret_4h"]).prod() - 1

benchmarks = pd.DataFrame(
    [{
        "BTC Buy & Hold": btc_bh,
        "GLD Buy & Hold": gld_bh,
        "USO Buy & Hold": uso_bh,
    }]
)

benchmarks
# Out:
#    BTC Buy & Hold  GLD Buy & Hold  USO Buy & Hold
# 0       -0.112645        0.042992        1.055277

# %% [markdown]
# ## 14. Distribució d'accions i actius

# %%
print("Actions:")
print(results_multi["action"].value_counts())

print("\nAssets:")
print(results_multi["asset"].value_counts())
# Out:
# Actions:
# action
# 1    189
# 2     36
# Name: count, dtype: int64
#
# Assets:
# asset
# 1    189
# 2     36
# Name: count, dtype: int64

# %% [markdown]
# ## 15. Corba d'equity

# %%
plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["equity"], label="Multi-Asset Agent")
plt.title("Multi-Asset Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 16. Comparació visual amb buy-and-hold dels actius

# %%
bh_curves = pd.DataFrame(index=test_data.index)
bh_curves["BTC_BH"] = (1 + test_data["btc_ret_4h"]).cumprod()
bh_curves["GLD_BH"] = (1 + test_data["gld_ret_4h"]).cumprod()
bh_curves["USO_BH"] = (1 + test_data["uso_ret_4h"]).cumprod()

plt.figure(figsize=(12, 5))
plt.plot(results_multi.index, results_multi["equity"], label="Multi-Asset Agent")
plt.plot(bh_curves.index, bh_curves["BTC_BH"], label="BTC Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["GLD_BH"], label="GLD Buy & Hold", linestyle="--")
plt.plot(bh_curves.index, bh_curves["USO_BH"], label="USO Buy & Hold", linestyle="--")
plt.title("Multi-Asset Agent vs Buy & Hold Benchmarks")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 17. Guardat de resultats

# %%
results_dir = project_root / "results"
results_dir.mkdir(exist_ok=True)

results_multi.to_csv(results_dir / "results_multi_asset_btc_gld_uso.csv")
comparison_multi.to_csv(results_dir / "comparison_multi_asset_btc_gld_uso.csv")
benchmarks.to_csv(results_dir / "benchmarks_multi_asset_btc_gld_uso.csv")

print("Results saved in:", results_dir)
# Out:
# Results saved in: c:\Users\rfran\OneDrive\Documentos\UOC\Master\TFM\tfm-drl-trading\results

# %%
np.random.seed(42)
test_data_shuffled = test_data.sample(frac=1)

env_test_random = TradingEnv(
    data=test_data_shuffled,
    feature_columns=feature_columns,
    base_transaction_cost=BASE_TRANSACTION_COST,
    dynamic_cost_weight=DYNAMIC_COST_WEIGHT,
    inactivity_penalty=INACTIVITY_PENALTY,
)

results_random = evaluate_model_multi_asset(
    model_multi,
    env_test_random,
    test_data_shuffled
)

compute_metrics_multi_asset(results_random)
# Out:
# {'cumulative_return': np.float64(-0.2550198697311524),
#  'sharpe': np.float64(-1.9314579426255152),
#  'sortino': np.float64(-2.356991426893912),
#  'max_drawdown': np.float64(-0.35859841931292913),
#  'n_switches': 73}
