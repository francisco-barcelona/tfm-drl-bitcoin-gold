# %% [markdown]
# Descàrrega de dades de Bitcoin i Or

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17352, 6)
# GLD shape: (5077, 6)

# %% [markdown]
# Neteja de columnes multi índex

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)

btc.head(), gld.head()
# Out:
# (Price                         Adj Close         Close          High  \
#  Datetime
#  2024-04-06 00:00:00+00:00  67964.968750  67964.968750  68049.796875
#  2024-04-06 01:00:00+00:00  67708.601562  67708.601562  67993.359375
#  2024-04-06 02:00:00+00:00  67593.031250  67593.031250  67787.695312
#  2024-04-06 03:00:00+00:00  67824.609375  67824.609375  67901.257812
#  2024-04-06 04:00:00+00:00  67769.640625  67769.640625  67831.867188
#
#  Price                               Low          Open  Volume
#  Datetime
#  2024-04-06 00:00:00+00:00  67736.460938  67845.937500       0
#  2024-04-06 01:00:00+00:00  67701.914062  67944.539062       0
#  2024-04-06 02:00:00+00:00  67500.640625  67730.359375       0
#  2024-04-06 03:00:00+00:00  67610.304688  67610.304688       0
#  2024-04-06 04:00:00+00:00  67660.664062  67825.687500       0  ,
#  Price                       Adj Close       Close        High         Low  \
#  Datetime
#  2023-05-05 13:30:00+00:00  186.610001  186.610001  186.910004  185.770004
#  2023-05-05 14:30:00+00:00  186.910004  186.910004  187.149994  186.350006
#  2023-05-05 15:30:00+00:00  187.110001  187.110001  187.369995  186.779999
#  2023-05-05 16:30:00+00:00  187.419998  187.419998  187.580002  187.119995
#  2023-05-05 17:30:00+00:00  187.210007  187.210007  187.440002  187.119995
#
#  Price                            Open   Volume
#  Datetime
#  2023-05-05 13:30:00+00:00  186.559998  5023067
#  2023-05-05 14:30:00+00:00  186.610001  1968205
#  2023-05-05 15:30:00+00:00  186.899994  1512052
#  2023-05-05 16:30:00+00:00  187.119995  1190210
#  2023-05-05 17:30:00+00:00  187.410004   699367  )

# %% [markdown]
# Verificació ràpida

# %%
print(btc.columns)
print(gld.columns)
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %% [markdown]
# Sincronització de dades de Bitcoin i Or.
# Rang de dates coherent (Bitcoin funciona 24 hores, però l'or no).
# Normalitzar timestamps a inici d'hora.
# Renombrar columnes.

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")

btc_1h.columns.name = None
gld_1h.columns.name = None

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})

print(btc_1h.head())
print(gld_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-04-06 00:00:00+00:00  67964.968750
# 2024-04-06 01:00:00+00:00  67708.601562
# 2024-04-06 02:00:00+00:00  67593.031250
# 2024-04-06 03:00:00+00:00  67824.609375
# 2024-04-06 04:00:00+00:00  67769.640625
#                             gld_close
# Datetime
# 2023-05-05 13:00:00+00:00  186.610001
# 2023-05-05 14:00:00+00:00  186.910004
# 2023-05-05 15:00:00+00:00  187.110001
# 2023-05-05 16:00:00+00:00  187.419998
# 2023-05-05 17:00:00+00:00  187.210007

# %% [markdown]
# Obtenir intersecció de dades

# %%
common_index = btc_1h.index.intersection(gld_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3440, 1)
# GLD sync shape: (3440, 1)
# Start: 2024-04-08 13:00:00+00:00
# End: 2026-04-02 19:00:00+00:00

# %% [markdown]
# Fusió de datasets de Bitcoin i Or

# %%
df = btc_sync.join(gld_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3440, 2)
#                               btc_close   gld_close
# Datetime
# 2024-04-08 13:00:00+00:00  71936.625000  215.324997
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004

# %% [markdown]
# Crear returns

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000   -0.003124    0.001974
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996    0.000652   -0.000742
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005    0.000061    0.001345
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004   -0.000650    0.004123
# 2024-04-08 18:00:00+00:00  71955.953125  216.559998    0.003341   -0.000969

# %% [markdown]
# Passar a 4 hores, resamplejant el dataset. Frame final.

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum"
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1149, 4)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 12:00:00+00:00  71758.664062  215.589996   -0.002472    0.001232
# 2024-04-08 16:00:00+00:00  71656.507812  216.475006   -0.001410    0.004107
# 2024-04-09 12:00:00+00:00  69157.882812  217.235001   -0.035167    0.003572
# 2024-04-09 16:00:00+00:00  69071.023438  217.663605   -0.001218    0.001976
# 2024-04-10 12:00:00+00:00  68634.343750  216.309998   -0.006228   -0.006228

# %% [markdown]
# Creació de features mínimes útils

# %%
df_4h["btc_ret_4h"] = df_4h["btc_close"].pct_change()
df_4h["gld_ret_4h"] = df_4h["gld_close"].pct_change()

df_4h["btc_vol_12"] = df_4h["btc_ret_4h"].rolling(12).std()
df_4h["gld_vol_12"] = df_4h["gld_ret_4h"].rolling(12).std()

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1137, 8)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312  221.139999   -0.025451    0.001010
# 2024-04-16 16:00:00+00:00  62777.230469  221.220001    0.013930    0.000366
# 2024-04-17 12:00:00+00:00  60446.308594  220.270004   -0.037492   -0.004296
# 2024-04-17 16:00:00+00:00  61150.746094  219.610001    0.011792   -0.002991
# 2024-04-18 12:00:00+00:00  63519.785156  220.740005    0.038442    0.005139
#
#                            btc_ret_4h  gld_ret_4h  btc_vol_12  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.000951    0.017926    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.000362    0.019254    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130   -0.004294    0.019521    0.007941
# 2024-04-17 16:00:00+00:00    0.011654   -0.002996    0.020439    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.005146    0.024826    0.007792

# %%
features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

df_model = df_4h[features].copy()

print(df_model.shape)
df_model.head()
# Out:
# (1137, 4)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.017926    0.000951    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.019254    0.000362    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130    0.019521   -0.004294    0.007941
# 2024-04-17 16:00:00+00:00    0.011654    0.020439   -0.002996    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.024826    0.005146    0.007792

# %%
env_df = df_4h[[
    "btc_close",
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12"
]].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1137, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Baseline només BTC

# %%
btc_features = ["btc_ret_4h", "btc_vol_12"]
env_btc = env_df[["btc_close"] + btc_features].copy()

print(env_btc.shape)
env_btc.head()
# Out:
# (1137, 3)
#                               btc_close  btc_ret_4h  btc_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826

# %% [markdown]
# Model amb senyal exògena (BTC + GLD)

# %%
btc_gld_features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]
env_btc_gld = env_df[["btc_close"] + btc_gld_features].copy()

print(env_btc_gld.shape)
env_btc_gld.head()
# Out:
# (1137, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Split de Train / Test

# %%
split_idx = int(len(env_df) * 0.8)

train_btc = env_btc.iloc[:split_idx].copy()
test_btc  = env_btc.iloc[split_idx:].copy()

train_btc_gld = env_btc_gld.iloc[:split_idx].copy()
test_btc_gld  = env_btc_gld.iloc[split_idx:].copy()

print("train_btc:", train_btc.shape)
print("test_btc:", test_btc.shape)
print("train_btc_gld:", train_btc_gld.shape)
print("test_btc_gld:", test_btc_gld.shape)
# Out:
# train_btc: (909, 3)
# test_btc: (228, 3)
# train_btc_gld: (909, 5)
# test_btc_gld: (228, 5)

# %% [markdown]
# Importació de l'entorn Gym

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_simple import TradingEnv

# %% [markdown]
# Crear entorn baseline

# %%
btc_feature_columns = ["btc_ret_4h", "btc_vol_12"]

env_train_btc_simple = TradingEnv(
    data=train_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
)

obs, info = env_train_btc_simple.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)

# %% [markdown]
# Test d'uns steps

# %%
obs, reward, done, truncated, info = env_train_btc_simple.step(1)  # long
print("Reward:", reward)
print("Done:", done)
print("Info:", info)

obs, reward, done, truncated, info = env_train_btc_simple.step(0)  # hold
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 obs, reward, done, truncated, info = env_train_btc_simple.step(1)  # long
#       2 print("Reward:", reward)
#       3 print("Done:", done)
#
# NameError: name 'env_train_btc_simple' is not defined

# %% [markdown]
# Test de l'entorn amb GLD

# %%
btc_gld_feature_columns = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

env_train_btc_gld_simple = TradingEnv(
    data=train_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
    reward_mode="risk_adjusted"
)


obs, info = env_train_btc_gld_simple.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.02525732  0.01792642  0.00095056  0.00777943  0.        ]
# Observation shape: (5,)
# Info: {}

# %%
obs, reward, done, truncated, info = env_train_btc_gld_simple.step(1)
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# Reward: 0.013911617460715106
# Done: False
# Info: {'step': 1, 'position': 1, 'asset_return': np.float64(0.013931024805929448)}

# %% [markdown]
# Crear entorns de test

# %%
env_test_btc_simple = TradingEnv(
    data=test_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
    reward_mode="risk_adjusted",
)

env_test_btc_gld_simple = TradingEnv(
    data=test_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
    reward_mode="risk_adjusted",
)

# %% [markdown]
# Entrenaments amb PPO

# %%
from stable_baselines3 import PPO

# %% [markdown]
# Model de BTC

# %%
model_btc_simple = PPO(
    "MlpPolicy",
    env_train_btc_simple,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_simple.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1153 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 256  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0007806872 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -3.43        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00128      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00098     |
# |    value_loss           | 0.00478      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 3           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.004268597 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.0428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000753    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.476      |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.007898534 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.476      |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 5           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.011213072 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0147      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00559    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00689    |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.476       |
# | time/                   |              |
# |    fps                  | 804          |
# |    iterations           | 6            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0032245289 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0291      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00235     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 0.00275      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.476       |
# | time/                   |              |
# |    fps                  | 799          |
# |    iterations           | 7            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0051381052 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00872     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 0.00294      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.38        |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 8            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0004579001 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00234      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000522    |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000395    |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.38        |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 9            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0025707579 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.000964     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00345     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 0.00633      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.38       |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 10          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.013422503 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.344      |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 11          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.012032436 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0189     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00933    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.344      |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 12          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.010524029 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00129     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 0.00249     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.344      |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 13          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.008800066 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | -0.0313     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00292    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00351     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.344       |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 14           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0028208764 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.00476      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00219     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.00185      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.178       |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 15           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0050630984 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.912       |
# |    explained_variance   | -0.0252      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00805      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.00181      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.178      |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 16          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012031081 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.00829     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00217    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.178       |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 17           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0072486186 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | -0.00306     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0226       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 0.00242      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0185     |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 18          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.005205686 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0123     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.023      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0185      |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 19           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0049582114 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.0294       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0213      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 0.00249      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0185     |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 20          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.005103665 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | -0.0306     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 0.00561     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0185      |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 21           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0027630178 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.0524       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.0022       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.172        |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 22           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0029209824 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | -0.0116      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00452      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 0.00163      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.172        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 23           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0023605952 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.0238       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00583      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 0.00319      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.172        |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 24           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067872573 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | -0.00742     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00389     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 0.00547      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 25           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0013374323 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | -0.0316      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00584      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 26           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0026209732 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.00186      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000186     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 0.00282      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 27          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.002538572 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | -0.0246     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00287     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.00758     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 28           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0023328096 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.076        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00924     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0595      |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 29          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.010223032 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | -0.0553     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0595       |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 30           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0038312469 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.0595       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00017     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0595       |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 31           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0017074647 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 0.00842      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00641     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000628    |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.024        |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 32           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027932224 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.0249       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0111       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.00243      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.024        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 33           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0021669583 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | -0.0378      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00407      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 0.00252      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.024       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 34          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.003423625 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.031       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00265    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.024        |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 35           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0016688763 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.0207       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00816      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.00282      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.0899        |
# | time/                   |               |
# |    fps                  | 724           |
# |    iterations           | 36            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00083833793 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.529        |
# |    explained_variance   | 0.0339        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00348       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000671     |
# |    value_loss           | 0.00227       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0899      |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 37          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.014175792 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.00683     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0899       |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 38           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0030680436 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | 0.00881      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00698     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 0.00503      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0899      |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 39          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.009316875 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | -0.00294    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00646    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 40          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004615673 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.034       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0046      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 41          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | 0.004203566 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | -0.0254     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.105        |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 42           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0017380861 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.0423       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00619     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 0.00207      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 43           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 11008        |
# | train/                  |              |
# |    approx_kl            | 0.0027890508 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.713       |
# |    explained_variance   | -0.0367      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0031      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 0.00288      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 44           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0014563499 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.026        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00546     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000878    |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 45           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0019417743 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.00605      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00425     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.00378      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 46           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0045504654 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.086        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0112      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00182      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 47          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.006650077 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | -0.0186     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00837    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 0.00236     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 48          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004282493 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | -0.000292   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00357    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.00591     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 49          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.011827752 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | -0.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00246     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0534       |
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 50           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0065434445 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | -0.0381      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0111      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00947     |
# |    value_loss           | 0.00186      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0534      |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 51          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 13056       |
# | train/                  |             |
# |    approx_kl            | 0.004555247 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0666      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00099     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.0534     |
# | time/                   |            |
# |    fps                  | 710        |
# |    iterations           | 52         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.00708784 |
# |    clip_fraction        | 0.0781     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.583     |
# |    explained_variance   | -0.0191    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.019     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00663   |
# |    value_loss           | 0.00346    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0534       |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 53           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 13568        |
# | train/                  |              |
# |    approx_kl            | 0.0018592926 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.0341       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00382     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 0.00348      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0575       |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 54           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0008209243 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.0198       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00666     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000802    |
# |    value_loss           | 0.00105      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0575       |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 55           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0070297844 |
# |    clip_fraction        | 0.0422       |
# ...
# |    time_elapsed         | 68           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0012010143 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00165     |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 0.00267      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.297       |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 180         |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.002103278 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.258      |
# |    explained_variance   | -0.00588    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00776    |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.304        |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 181          |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 46336        |
# | train/                  |              |
# |    approx_kl            | 0.0011591366 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00519      |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.00186      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.304       |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 182         |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 46592       |
# | train/                  |             |
# |    approx_kl            | 0.001991372 |
# |    clip_fraction        | 0.00547     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.00956     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00124     |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.000642   |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.304        |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 183          |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 46848        |
# | train/                  |              |
# |    approx_kl            | 0.0016619181 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | 0.00589      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00256     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.00201      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.304        |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 184          |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0016220717 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.183       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00651      |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 0.00225      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.31          |
# | time/                   |               |
# |    fps                  | 669           |
# |    iterations           | 185           |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 47360         |
# | train/                  |               |
# |    approx_kl            | 0.00050128205 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.159        |
# |    explained_variance   | 0.192         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000387      |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.000672     |
# |    value_loss           | 0.00127       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 186          |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0007103367 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00107      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.000599    |
# |    value_loss           | 0.00264      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.31        |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 187         |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 47872       |
# | train/                  |             |
# |    approx_kl            | 0.003277945 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.131      |
# |    explained_variance   | -0.022      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00153    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.00317     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.314        |
# | time/                   |              |
# |    fps                  | 668          |
# |    iterations           | 188          |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0001976362 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00314     |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.000363    |
# |    value_loss           | 0.00201      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.314        |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 189          |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0005262315 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | -0.089       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000851     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000916    |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.314         |
# | time/                   |               |
# |    fps                  | 667           |
# |    iterations           | 190           |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 48640         |
# | train/                  |               |
# |    approx_kl            | 0.00050863484 |
# |    clip_fraction        | 0.00625       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.127        |
# |    explained_variance   | 0.162         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00116       |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -0.000938     |
# |    value_loss           | 0.00238       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.314        |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 191          |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 48896        |
# | train/                  |              |
# |    approx_kl            | 0.0011795561 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | 0.0863       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00153      |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.00332      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.319        |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 192          |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0005038956 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.0649       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00183      |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 0.00146      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.319         |
# | time/                   |               |
# |    fps                  | 666           |
# |    iterations           | 193           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 49408         |
# | train/                  |               |
# |    approx_kl            | 0.00052127824 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.117        |
# |    explained_variance   | 0.0735        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00113       |
# |    n_updates            | 1920          |
# |    policy_gradient_loss | -0.00116      |
# |    value_loss           | 0.00217       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.319         |
# | time/                   |               |
# |    fps                  | 666           |
# |    iterations           | 194           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 49664         |
# | train/                  |               |
# |    approx_kl            | 0.00029761856 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.124        |
# |    explained_variance   | -0.0292       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -8.32e-05     |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 0.00356       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.319         |
# | time/                   |               |
# |    fps                  | 666           |
# |    iterations           | 195           |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 49920         |
# | train/                  |               |
# |    approx_kl            | 0.00052444846 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000745      |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -0.000512     |
# |    value_loss           | 0.00201       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.322        |
# | time/                   |              |
# |    fps                  | 666          |
# |    iterations           | 196          |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0020774128 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | -0.0868      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00147     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 0.00191      |
# ------------------------------------------

# %% [markdown]
# Model de BTC + GLD

# %%
model_btc_gld_simple = PPO(
    "MlpPolicy",
    env_train_btc_gld_simple,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_gld_simple.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 947 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.004919613 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -3.27       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 0.00563     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.012981104 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.105      |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.010342786 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00565    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -0.105        |
# | time/                   |               |
# |    fps                  | 704           |
# |    iterations           | 5             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 0.00032398058 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0.0208        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00141      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00075      |
# |    value_loss           | 0.00292       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.105       |
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 6            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0018449868 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0281      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00297     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 0.00273      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.105      |
# | time/                   |             |
# |    fps                  | 670         |
# |    iterations           | 7           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.004306521 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0051     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00522     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.42       |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.011536277 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00588     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.42       |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 9           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.011754673 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.008      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.42       |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 10          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007801243 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0.00215     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 0.00168     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.422      |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.012079628 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.00313     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.422       |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 12           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0010989152 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | -0.0764      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00847     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | -0.422     |
# | time/                   |            |
# |    fps                  | 656        |
# |    iterations           | 13         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3328       |
# | train/                  |            |
# |    approx_kl            | 0.01641109 |
# |    clip_fraction        | 0.0789     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.855     |
# |    explained_variance   | 0.0224     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0255    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00719   |
# |    value_loss           | 0.00189    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.422       |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 14           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0058028605 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.0808       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0036      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00859     |
# |    value_loss           | 0.00274      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.193       |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 15           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0030978126 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 0.00302      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00576     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 0.000944     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.193      |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 16          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008073103 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.0407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0097      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.00504     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.193       |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 17           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0027030152 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 0.00463      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0241      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 0.00182      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.151       |
# | time/                   |              |
# |    fps                  | 650          |
# |    iterations           | 18           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0025860402 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.0142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0157      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000767    |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.151       |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 19           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0010383227 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.726       |
# |    explained_variance   | 0.0348       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00754     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.00281      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.151       |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 20           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0025215347 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.0249       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000803     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 0.00282      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.151      |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 21          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.009359618 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.0205      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00989    |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | -0.124     |
# | time/                   |            |
# |    fps                  | 642        |
# |    iterations           | 22         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.00631136 |
# |    clip_fraction        | 0.0656     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.651     |
# |    explained_variance   | 0.0175     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0175    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00399   |
# |    value_loss           | 0.0016     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.124       |
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 23           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0063781864 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.639       |
# |    explained_variance   | 0.0839       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000615    |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -0.124        |
# | time/                   |               |
# |    fps                  | 640           |
# |    iterations           | 24            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00025801547 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.633        |
# |    explained_variance   | -0.0101       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00355       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -2.21e-05     |
# |    value_loss           | 0.00343       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.00845     |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 25           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0030287933 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.056        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0217      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00601     |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.00845     |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 26           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0047646915 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00582      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.00845     |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 27           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0043939757 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.0565       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0329      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00636     |
# |    value_loss           | 0.00302      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.00845     |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 28           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0054201195 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.0624       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.102        |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 29           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 7424         |
# | train/                  |              |
# |    approx_kl            | 0.0055197272 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0045      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 0.00137      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.102        |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 30           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0052600484 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0017      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 0.00275      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.102        |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 31           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0052130073 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | -0.0098      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0177      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 0.00362      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.18       |
# | time/                   |            |
# |    fps                  | 624        |
# |    iterations           | 32         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01926583 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.769     |
# |    explained_variance   | -0.0871    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0108    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.021     |
# |    value_loss           | 0.00238    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.18       |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 33         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 8448       |
# | train/                  |            |
# |    approx_kl            | 0.00813813 |
# |    clip_fraction        | 0.0969     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.768     |
# |    explained_variance   | 0.00772    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0221    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00737   |
# |    value_loss           | 0.00182    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.18         |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 34           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0042840447 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.0318       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00669     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.18         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 35           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0093626985 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.0483       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0506      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 0.00298      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.196        |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 36           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0030609309 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0015      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 0.00164      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.196        |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 37           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0018037502 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | 0.0486       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00125     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 0.00466      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 38          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.019672494 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.0173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00814    |
# |    value_loss           | 0.00347     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.196        |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 39           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0014089418 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0.054        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000773     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.235       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 40          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019702386 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.0374      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0372     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.235     |
# | time/                   |           |
# |    fps                  | 592       |
# |    iterations           | 41        |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 10496     |
# | train/                  |           |
# |    approx_kl            | 0.0148408 |
# |    clip_fraction        | 0.155     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.73     |
# |    explained_variance   | -0.125    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00137  |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.00867  |
# |    value_loss           | 0.00253   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.235      |
# | time/                   |            |
# |    fps                  | 590        |
# |    iterations           | 42         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 10752      |
# | train/                  |            |
# |    approx_kl            | 0.01753885 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.735     |
# |    explained_variance   | 0.0418     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0308    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.003      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.297        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 43           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 11008        |
# | train/                  |              |
# |    approx_kl            | 0.0071667074 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00875     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.297       |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 44          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.009718291 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | -0.218      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.297        |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 45           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0002477346 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | -0.432       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00016     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000281     |
# |    value_loss           | 0.00433      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.297        |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 46           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0045108814 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.0916       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.315       |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 47          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.007506378 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | -0.0304     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00416     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.315        |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 48           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0029137672 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.046        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00565      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.315        |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 49           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0026299509 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.0526       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000891    |
# |    value_loss           | 0.00242      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.328       |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 50          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.006388533 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.0438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00924    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.328        |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 51           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0026749927 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.0625       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000935    |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.328        |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 52           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0077959383 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | -0.264       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00695     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.328         |
# | time/                   |               |
# |    fps                  | 575           |
# |    iterations           | 53            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 13568         |
# | train/                  |               |
# |    approx_kl            | 9.2593255e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.558        |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00341      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -5.95e-05     |
# |    value_loss           | 0.00176       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.329        |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 54           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 8.197781e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.566       |
# |    explained_variance   | -0.0091      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00111     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -6.41e-05    |
# |    value_loss           | 0.00127      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.329        |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 55           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0060417447 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.618       |
# ...
# |    iterations           | 179          |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 45824        |
# | train/                  |              |
# |    approx_kl            | 0.0029300642 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.295       |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0033      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 0.00261      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.461        |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 180          |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0018224593 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.0233       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00446      |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.463       |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 181         |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 46336       |
# | train/                  |             |
# |    approx_kl            | 0.002854169 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00842    |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 0.00192     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.463        |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 182          |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 46592        |
# | train/                  |              |
# |    approx_kl            | 0.0023079305 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -0.0391      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 0.00192      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.463        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 183          |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 46848        |
# | train/                  |              |
# |    approx_kl            | 0.0024970197 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | 0.0379       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 0.0022       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.463         |
# | time/                   |               |
# |    fps                  | 554           |
# |    iterations           | 184           |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 9.1892434e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.257        |
# |    explained_variance   | 0.157         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00229       |
# |    n_updates            | 1830          |
# |    policy_gradient_loss | 0.000214      |
# |    value_loss           | 0.00226       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.464        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 185          |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 47360        |
# | train/                  |              |
# |    approx_kl            | 0.0014959578 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | 0.309        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00626      |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.464        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 186          |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0012085696 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | 0.0888       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00283      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.464       |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 187         |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 47872       |
# | train/                  |             |
# |    approx_kl            | 0.002705152 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.297      |
# |    explained_variance   | -0.0207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0086      |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.465        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 188          |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0038362811 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00486     |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00595     |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.465        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 189          |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 48384        |
# | train/                  |              |
# |    approx_kl            | 0.0012275148 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -0.072       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00652      |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000237    |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.465        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 190          |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 48640        |
# | train/                  |              |
# |    approx_kl            | 0.0007894824 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | 0.0167       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00402     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 0.00234      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.465         |
# | time/                   |               |
# |    fps                  | 554           |
# |    iterations           | 191           |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 48896         |
# | train/                  |               |
# |    approx_kl            | 0.00089742313 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.248        |
# |    explained_variance   | 0.105         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00344       |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.000463     |
# |    value_loss           | 0.00331       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.466        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 192          |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0016554534 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.288       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00649     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 0.00141      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.466        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 193          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 49408        |
# | train/                  |              |
# |    approx_kl            | 0.0013455744 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.338       |
# |    explained_variance   | 0.0154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00679     |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.466        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 194          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 49664        |
# | train/                  |              |
# |    approx_kl            | 0.0020754659 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | -0.0895      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0081      |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 0.00334      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.466       |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 195         |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.002646948 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00693    |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.469        |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 196          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0020255987 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.303       |
# |    explained_variance   | -0.146       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000505    |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 0.00188      |
# ------------------------------------------

# %% [markdown]
# Guardar models

# %%
model_btc_simple.save("../results/model_btc_baseline_simple")
model_btc_gld_simple.save("../results/model_btc_gld_simple")

# %% [markdown]
# Avaluació en Test.
# Retorna Equity Cruve, Rewards, Posicions i Retorns d'Estratègia.

# %%
import numpy as np
import pandas as pd

def evaluate_model(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    positions = []
    asset_returns = []
    actions = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        positions.append(info["position"])
        asset_returns.append(info["asset_return"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "position": positions,
        "asset_return": asset_returns,
        "action": actions,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    return results

# %% [markdown]
# Execució en els dos models

# %%
results_btc = evaluate_model(model_btc_simple, env_test_btc_simple, test_btc)
results_btc_gld = evaluate_model(model_btc_gld_simple, env_test_btc_gld_simple, test_btc_gld)

results_btc.head(), results_btc_gld.head()
# Out:
# (                             reward  position  asset_return  action    equity
#  Datetime
#  2025-12-03 20:00:00+00:00 -0.001096         1     -0.001096       1  0.998904
#  2025-12-04 12:00:00+00:00  0.001010         1      0.001011       0  0.999913
#  2025-12-04 16:00:00+00:00 -0.010533         1     -0.010522       0  0.989381
#  2025-12-04 20:00:00+00:00  0.005436         1      0.005439       0  0.994759
#  2025-12-05 12:00:00+00:00 -0.023934         1     -0.023877       0  0.970951,
#                                   reward  position  asset_return  action  \
#  Datetime
#  2025-12-03 20:00:00+00:00 -1.201407e-07         0     -0.001096       0
#  2025-12-04 12:00:00+00:00 -1.021311e-07         0      0.001011       0
#  2025-12-04 16:00:00+00:00 -1.107125e-05         0     -0.010522       0
#  2025-12-04 20:00:00+00:00 -2.958017e-06         0      0.005439       0
#  2025-12-05 12:00:00+00:00 -5.700889e-05         0     -0.023877       0
#
#                               equity
#  Datetime
#  2025-12-03 20:00:00+00:00  1.000000
#  2025-12-04 12:00:00+00:00  1.000000
#  2025-12-04 16:00:00+00:00  0.999989
#  2025-12-04 20:00:00+00:00  0.999986
#  2025-12-05 12:00:00+00:00  0.999929  )

# %%
results_btc["action"].value_counts()
results_btc_gld["action"].value_counts()
# Out:
# action
# 0    227
# Name: count, dtype: int64

# %% [markdown]
# Funció de mètriques bàsiques

# %%
def compute_metrics(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 0:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 0:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    position_changes = results_df["position"].diff().fillna(0)
    initial_trade = 1 if results_df["position"].iloc[0] != 0 else 0
    n_trades = int((position_changes != 0).sum() + initial_trade)

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_trades": int(n_trades),
    }

# %% [markdown]
# Aplicació de la funció de mètriques

# %%
metrics_btc = compute_metrics(results_btc)
metrics_btc_gld = compute_metrics(results_btc_gld)

metrics_btc, metrics_btc_gld
# Out:
# ({'cumulative_return': np.float64(-0.2850891188645419),
#   'sharpe': np.float64(-1.5749399725991462),
#   'sortino': np.float64(-2.0799167296416106),
#   'max_drawdown': np.float64(-0.3503595864090221),
#   'n_trades': 1},
#  {'cumulative_return': np.float64(-0.007826645299552015),
#   'sharpe': np.float64(-8.912333806200547),
#   'sortino': np.float64(-8.912333806200547),
#   'max_drawdown': np.float64(-0.007826526099180664),
#   'n_trades': 0})

# %% [markdown]
# Taula comparativa

# %%
comparison = pd.DataFrame([metrics_btc, metrics_btc_gld], index=["BTC", "BTC+GLD"])
comparison
# Out:
#          cumulative_return    sharpe   sortino  max_drawdown  n_trades
# BTC              -0.285089 -1.574940 -2.079917     -0.350360         1
# BTC+GLD          -0.007827 -8.912334 -8.912334     -0.007827         0

# %% [markdown]
# Gràfica d'Equity

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(results_btc.index, results_btc["equity"], label="BTC")
plt.plot(results_btc_gld.index, results_btc_gld["equity"], label="BTC+GLD")
plt.title("Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Comparació contra buy-and-hold

# %%
buy_hold_ret = test_btc["btc_close"].iloc[-1] / test_btc["btc_close"].iloc[0] - 1
print("Buy & Hold return:", buy_hold_ret)
# Out:
# Buy & Hold return: -0.2794302699733495

# %% [markdown]
# Veure accions dels dos models per separat

# %%
print("BTC actions:")
print(results_btc["action"].value_counts())

print("\nBTC+GLD actions:")
print(results_btc_gld["action"].value_counts())

print("\nBTC positions:")
print(results_btc["position"].value_counts())

print("\nBTC+GLD positions:")
print(results_btc_gld["position"].value_counts())
# Out:
# BTC actions:
# action
# 0    226
# 1      1
# Name: count, dtype: int64
#
# BTC+GLD actions:
# action
# 0    227
# Name: count, dtype: int64
#
# BTC positions:
# position
# 1    227
# Name: count, dtype: int64
#
# BTC+GLD positions:
# position
# 0    227
# Name: count, dtype: int64
