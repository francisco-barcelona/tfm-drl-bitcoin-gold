# %% [markdown]
# Descàrrega de dades de Bitcoin i Or

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
btc = yf.download("BTC-USD", period="730d", interval="1h", auto_adjust=False)
gld = yf.download("GLD", period="730d", interval="1h", auto_adjust=False)

print("BTC shape:", btc.shape)
print("GLD shape:", gld.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# BTC shape: (17351, 6)
# GLD shape: (5077, 6)

# %% [markdown]
# Neteja de columnes multi índex

# %%
btc.columns = btc.columns.get_level_values(0)
gld.columns = gld.columns.get_level_values(0)

btc.head(), gld.head()
# Out:
# (Price                         Adj Close         Close          High  \
#  Datetime
#  2024-04-07 00:00:00+00:00  69015.179688  69015.179688  69138.554688
#  2024-04-07 01:00:00+00:00  69572.406250  69572.406250  69608.593750
#  2024-04-07 02:00:00+00:00  69335.773438  69335.773438  69755.031250
#  2024-04-07 03:00:00+00:00  69431.601562  69431.601562  69502.390625
#  2024-04-07 04:00:00+00:00  69344.093750  69344.093750  69513.187500
#
#  Price                               Low          Open     Volume
#  Datetime
#  2024-04-07 00:00:00+00:00  68853.890625  68905.921875          0
#  2024-04-07 01:00:00+00:00  69021.453125  69021.453125  419897344
#  2024-04-07 02:00:00+00:00  69335.773438  69566.054688   84342784
#  2024-04-07 03:00:00+00:00  69269.484375  69329.781250   45486080
#  2024-04-07 04:00:00+00:00  69112.992188  69433.171875  162998272  ,
#  Price                       Adj Close       Close        High         Low  \
#  Datetime
#  2023-05-05 13:30:00+00:00  186.610001  186.610001  186.910004  185.770004
#  2023-05-05 14:30:00+00:00  186.910004  186.910004  187.149994  186.350006
#  2023-05-05 15:30:00+00:00  187.110001  187.110001  187.369995  186.779999
#  2023-05-05 16:30:00+00:00  187.419998  187.419998  187.580002  187.119995
#  2023-05-05 17:30:00+00:00  187.210007  187.210007  187.440002  187.119995
#
#  Price                            Open   Volume
#  Datetime
#  2023-05-05 13:30:00+00:00  186.559998  5023067
#  2023-05-05 14:30:00+00:00  186.610001  1968205
#  2023-05-05 15:30:00+00:00  186.899994  1512052
#  2023-05-05 16:30:00+00:00  187.119995  1190210
#  2023-05-05 17:30:00+00:00  187.410004   699367  )

# %% [markdown]
# Verificació ràpida

# %%
print(btc.columns)
print(gld.columns)
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %% [markdown]
# Sincronització de dades de Bitcoin i Or.
# Rang de dates coherent (Bitcoin funciona 24 hores, però l'or no).
# Normalitzar timestamps a inici d'hora.
# Renombrar columnes.

# %%
btc_1h = btc[["Close"]].copy()
gld_1h = gld[["Close"]].copy()

btc_1h.index = btc_1h.index.floor("1h")
gld_1h.index = gld_1h.index.floor("1h")

btc_1h.columns.name = None
gld_1h.columns.name = None

btc_1h = btc_1h.rename(columns={"Close": "btc_close"})
gld_1h = gld_1h.rename(columns={"Close": "gld_close"})

print(btc_1h.head())
print(gld_1h.head())
# Out:
#                               btc_close
# Datetime
# 2024-04-07 00:00:00+00:00  69015.179688
# 2024-04-07 01:00:00+00:00  69572.406250
# 2024-04-07 02:00:00+00:00  69335.773438
# 2024-04-07 03:00:00+00:00  69431.601562
# 2024-04-07 04:00:00+00:00  69344.093750
#                             gld_close
# Datetime
# 2023-05-05 13:00:00+00:00  186.610001
# 2023-05-05 14:00:00+00:00  186.910004
# 2023-05-05 15:00:00+00:00  187.110001
# 2023-05-05 16:00:00+00:00  187.419998
# 2023-05-05 17:00:00+00:00  187.210007

# %% [markdown]
# Obtenir intersecció de dades

# %%
common_index = btc_1h.index.intersection(gld_1h.index)

btc_sync = btc_1h.loc[common_index].copy()
gld_sync = gld_1h.loc[common_index].copy()

print("BTC sync shape:", btc_sync.shape)
print("GLD sync shape:", gld_sync.shape)
print("Start:", common_index.min())
print("End:", common_index.max())
# Out:
# BTC sync shape: (3440, 1)
# GLD sync shape: (3440, 1)
# Start: 2024-04-08 13:00:00+00:00
# End: 2026-04-02 19:00:00+00:00

# %% [markdown]
# Fusió de datasets de Bitcoin i Or

# %%
df = btc_sync.join(gld_sync, how="inner")

print("Merged shape:", df.shape)
df.head()
# Out:
# Merged shape: (3440, 2)
#                               btc_close   gld_close
# Datetime
# 2024-04-08 13:00:00+00:00  71936.625000  215.324997
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004

# %% [markdown]
# Crear returns

# %%
df["btc_ret_1h"] = df["btc_close"].pct_change()
df["gld_ret_1h"] = df["gld_close"].pct_change()

df = df.dropna().copy()

df.head()
# Out:
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 14:00:00+00:00  71711.898438  215.750000   -0.003124    0.001974
# 2024-04-08 15:00:00+00:00  71758.664062  215.589996    0.000652   -0.000742
# 2024-04-08 16:00:00+00:00  71763.023438  215.880005    0.000061    0.001345
# 2024-04-08 17:00:00+00:00  71716.382812  216.770004   -0.000650    0.004123
# 2024-04-08 18:00:00+00:00  71955.953125  216.559998    0.003341   -0.000969

# %% [markdown]
# Passar a 4 hores, resamplejant el dataset. Frame final.

# %%
df_4h = df.resample("4h").agg({
    "btc_close": "last",
    "gld_close": "last",
    "btc_ret_1h": "sum",
    "gld_ret_1h": "sum"
}).dropna().copy()

print("4H shape:", df_4h.shape)
df_4h.head()
# Out:
# 4H shape: (1149, 4)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h
# Datetime
# 2024-04-08 12:00:00+00:00  71758.664062  215.589996   -0.002472    0.001232
# 2024-04-08 16:00:00+00:00  71656.507812  216.475006   -0.001410    0.004107
# 2024-04-09 12:00:00+00:00  69157.882812  217.235001   -0.035167    0.003572
# 2024-04-09 16:00:00+00:00  69071.023438  217.663605   -0.001218    0.001976
# 2024-04-10 12:00:00+00:00  68634.343750  216.309998   -0.006228   -0.006228

# %% [markdown]
# Creació de features mínimes útils

# %%
df_4h["btc_ret_4h"] = df_4h["btc_close"].pct_change()
df_4h["gld_ret_4h"] = df_4h["gld_close"].pct_change()

df_4h["btc_vol_12"] = df_4h["btc_ret_4h"].rolling(12).std()
df_4h["gld_vol_12"] = df_4h["gld_ret_4h"].rolling(12).std()

df_4h = df_4h.dropna().copy()

print("Final 4H shape:", df_4h.shape)
df_4h.head()
# Out:
# Final 4H shape: (1137, 8)
#                               btc_close   gld_close  btc_ret_1h  gld_ret_1h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312  221.139999   -0.025451    0.001010
# 2024-04-16 16:00:00+00:00  62777.230469  221.220001    0.013930    0.000366
# 2024-04-17 12:00:00+00:00  60446.308594  220.270004   -0.037492   -0.004296
# 2024-04-17 16:00:00+00:00  61150.746094  219.610001    0.011792   -0.002991
# 2024-04-18 12:00:00+00:00  63519.785156  220.740005    0.038442    0.005139
#
#                            btc_ret_4h  gld_ret_4h  btc_vol_12  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.000951    0.017926    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.000362    0.019254    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130   -0.004294    0.019521    0.007941
# 2024-04-17 16:00:00+00:00    0.011654   -0.002996    0.020439    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.005146    0.024826    0.007792

# %%
features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

df_model = df_4h[features].copy()

print(df_model.shape)
df_model.head()
# Out:
# (1137, 4)
#                            btc_ret_4h  btc_vol_12  gld_ret_4h  gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00   -0.025257    0.017926    0.000951    0.007779
# 2024-04-16 16:00:00+00:00    0.013931    0.019254    0.000362    0.007769
# 2024-04-17 12:00:00+00:00   -0.037130    0.019521   -0.004294    0.007941
# 2024-04-17 16:00:00+00:00    0.011654    0.020439   -0.002996    0.008025
# 2024-04-18 12:00:00+00:00    0.038741    0.024826    0.005146    0.007792

# %%
env_df = df_4h[[
    "btc_close",
    "btc_ret_4h",
    "btc_vol_12",
    "gld_ret_4h",
    "gld_vol_12"
]].copy()

print(env_df.shape)
env_df.head()
# Out:
# (1137, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Baseline només BTC

# %%
btc_features = ["btc_ret_4h", "btc_vol_12"]
env_btc = env_df[["btc_close"] + btc_features].copy()

print(env_btc.shape)
env_btc.head()
# Out:
# (1137, 3)
#                               btc_close  btc_ret_4h  btc_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826

# %% [markdown]
# Model amb senyal exògena (BTC + GLD)

# %%
btc_gld_features = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]
env_btc_gld = env_df[["btc_close"] + btc_gld_features].copy()

print(env_btc_gld.shape)
env_btc_gld.head()
# Out:
# (1137, 5)
#                               btc_close  btc_ret_4h  btc_vol_12  gld_ret_4h  \
# Datetime
# 2024-04-16 12:00:00+00:00  61914.695312   -0.025257    0.017926    0.000951
# 2024-04-16 16:00:00+00:00  62777.230469    0.013931    0.019254    0.000362
# 2024-04-17 12:00:00+00:00  60446.308594   -0.037130    0.019521   -0.004294
# 2024-04-17 16:00:00+00:00  61150.746094    0.011654    0.020439   -0.002996
# 2024-04-18 12:00:00+00:00  63519.785156    0.038741    0.024826    0.005146
#
#                            gld_vol_12
# Datetime
# 2024-04-16 12:00:00+00:00    0.007779
# 2024-04-16 16:00:00+00:00    0.007769
# 2024-04-17 12:00:00+00:00    0.007941
# 2024-04-17 16:00:00+00:00    0.008025
# 2024-04-18 12:00:00+00:00    0.007792

# %% [markdown]
# Split de Train / Test

# %%
split_idx = int(len(env_df) * 0.8)

train_btc = env_btc.iloc[:split_idx].copy()
test_btc  = env_btc.iloc[split_idx:].copy()

train_btc_gld = env_btc_gld.iloc[:split_idx].copy()
test_btc_gld  = env_btc_gld.iloc[split_idx:].copy()

print("train_btc:", train_btc.shape)
print("test_btc:", test_btc.shape)
print("train_btc_gld:", train_btc_gld.shape)
print("test_btc_gld:", test_btc_gld.shape)
# Out:
# train_btc: (909, 3)
# test_btc: (228, 3)
# train_btc_gld: (909, 5)
# test_btc_gld: (228, 5)

# %% [markdown]
# Importació de l'entorn Gym

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from env.trading_env_simple import TradingEnv

# %% [markdown]
# Crear entorn baseline

# %%
btc_feature_columns = ["btc_ret_4h", "btc_vol_12"]

env_train_btc_simple = TradingEnv(
    data=train_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
)

obs, info = env_train_btc_simple.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.02525732  0.01792642  0.        ]
# Observation shape: (3,)
# Info: {}

# %% [markdown]
# Test d'uns steps

# %%
obs, reward, done, truncated, info = env_train_btc_simple.step(1)  # long
print("Reward:", reward)
print("Done:", done)
print("Info:", info)

obs, reward, done, truncated, info = env_train_btc_simple.step(0)  # hold
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# Reward: 0.013931024805929448
# Done: False
# Info: {'step': 1, 'position': 1, 'asset_return': np.float64(0.013931024805929448)}
# Reward: -0.037130052689411275
# Done: False
# Info: {'step': 2, 'position': 1, 'asset_return': np.float64(-0.037130052689411275)}

# %% [markdown]
# Test de l'entorn amb GLD

# %%
btc_gld_feature_columns = ["btc_ret_4h", "btc_vol_12", "gld_ret_4h", "gld_vol_12"]

env_train_btc_gld_simple = TradingEnv(
    data=train_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
)


obs, info = env_train_btc_gld_simple.reset()
print("Initial observation:", obs)
print("Observation shape:", obs.shape)
print("Info:", info)
# Out:
# Initial observation: [-0.02525732  0.01792642  0.00095056  0.00777943  0.        ]
# Observation shape: (5,)
# Info: {}

# %%
obs, reward, done, truncated, info = env_train_btc_gld_simple.step(1)
print("Reward:", reward)
print("Done:", done)
print("Info:", info)
# Out:
# Reward: 0.013931024805929448
# Done: False
# Info: {'step': 1, 'position': 1, 'asset_return': np.float64(0.013931024805929448)}

# %% [markdown]
# Crear entorns de test

# %%
env_test_btc_simple = TradingEnv(
    data=test_btc,
    feature_columns=btc_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
)

env_test_btc_gld_simple = TradingEnv(
    data=test_btc_gld,
    feature_columns=btc_gld_feature_columns,
    price_column="btc_close",
    transaction_cost=0.0,
)

# %% [markdown]
# Entrenaments amb PPO

# %%
from stable_baselines3 import PPO

# %% [markdown]
# Model de BTC

# %%
model_btc_simple = PPO(
    "MlpPolicy",
    env_train_btc_simple,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_simple.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1095 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 256  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0014463896 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.197       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00297     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.001765263 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00847    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0798     |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.002418362 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000592   |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0798     |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 5           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.010091921 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 0.00633     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0798     |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.001289892 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0469     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0798      |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 7            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0045750504 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00475      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00662     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 0.0023       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0694       |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 8            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0012027996 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00657      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 0.00269      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0694       |
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 9            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0050657666 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.0136      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00748      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 0.00545      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0694      |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 10          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.011345638 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00706    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00583     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.115       |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.004991454 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.00646    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0223     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.115        |
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 12           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0037596438 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.0134      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00667     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.00235      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.115        |
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 13           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0002840173 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0419      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00175     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 0.00504      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.115        |
# | time/                   |              |
# |    fps                  | 672          |
# |    iterations           | 14           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0005007442 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0265      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00268      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000279    |
# |    value_loss           | 0.00154      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.16         |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 15           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0018854563 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.000607    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00696     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 0.00185      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.16         |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 16           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0008997491 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00129     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00178     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000403    |
# |    value_loss           | 0.00567      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.16         |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 17           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 0.0032715818 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.0161      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0197      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 0.0055       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.165        |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 18           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0067877052 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.272       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000968    |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00645     |
# |    value_loss           | 0.00215      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.165        |
# | time/                   |              |
# |    fps                  | 662          |
# |    iterations           | 19           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0023536992 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00707     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00749     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.165        |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 20           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0021399567 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00733     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00387      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 0.00525      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.165        |
# | time/                   |              |
# |    fps                  | 655          |
# |    iterations           | 21           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0011567764 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0199      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0062       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 0.00175      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.129        |
# | time/                   |              |
# |    fps                  | 650          |
# |    iterations           | 22           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0023243537 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0197      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00843     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 0.000969     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.129        |
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 23           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0036352251 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0187      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00936     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 0.00269      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.129       |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 24          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018330771 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0029     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.146        |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 25           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0061767157 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.00793      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00746     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.146       |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 26          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.010836419 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0305     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0455     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.00419     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.146       |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 27          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.002944354 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.0438     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.146       |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 28          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.006379651 |
# |    clip_fraction        | 0.00352     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0057      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00137     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 29          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.013105668 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.00522     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0315     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 30          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.005179799 |
# |    clip_fraction        | 0.00234     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | -0.00123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.19         |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 31           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0010037285 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | -0.00584     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00172     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000981    |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 32           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0011356215 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | -0.0068      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00243      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.214       |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 33          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.003133023 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | -0.00148    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 34           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0152651705 |
# |    clip_fraction        | 0.206        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | 0.0184       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0192      |
# |    value_loss           | 0.00506      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 529          |
# |    iterations           | 35           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0016665086 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | -0.0348      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00023     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 0.00402      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.166        |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 36           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0029764953 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | -0.0246      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00948      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 0.00169      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.166       |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 37          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.004314565 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.00548     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00274    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.166       |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 38          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.002624852 |
# |    clip_fraction        | 0.0148      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.166        |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 39           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0075296424 |
# |    clip_fraction        | 0.0816       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | -0.00779     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.00206      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.166         |
# | time/                   |               |
# |    fps                  | 506           |
# |    iterations           | 40            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00068261265 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | -0.0305       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00703       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000239     |
# |    value_loss           | 0.00258       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.166       |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 41          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | 0.007031605 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | -0.000933   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 0.00291     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.166        |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 42           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0019965502 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.00885      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00577      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000864    |
# |    value_loss           | 0.00177      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 43           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 11008        |
# | train/                  |              |
# |    approx_kl            | 0.0056576272 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.0414       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00252     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 44          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.008982814 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 45           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0029326417 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | -0.0228      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00282     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 0.00373      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 46          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.006671308 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | -0.0504     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.159       |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 47          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.009517893 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | -0.0872     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00882    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.159        |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 48           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0063391537 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.887       |
# |    explained_variance   | -0.00278     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0143      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 0.00353      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.159       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 49          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12544       |
# | train/                  |             |
# |    approx_kl            | 0.010519104 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | -0.0266     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00573     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 0.00311     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 50          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.011909544 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -0.0574     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 51           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0037313465 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0207      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 0.00234      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.14       |
# | time/                   |            |
# |    fps                  | 494        |
# |    iterations           | 52         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.00331994 |
# |    clip_fraction        | 0.00234    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.983     |
# |    explained_variance   | -0.0309    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00575    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00458   |
# |    value_loss           | 0.00446    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 53          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.005391554 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00347     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00314     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.107       |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 54          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.010921741 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00111     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0233      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.107        |
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 55           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0015884677 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# ...
# | time/                   |          |
# |    fps                  | 533      |
# |    iterations           | 178      |
# |    time_elapsed         | 85       |
# |    total_timesteps      | 45568    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0103  |
# |    explained_variance   | 0.198    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000651 |
# |    n_updates            | 1770     |
# |    policy_gradient_loss | 1.05e-08 |
# |    value_loss           | 0.0013   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.432    |
# | time/                   |          |
# |    fps                  | 532      |
# |    iterations           | 179      |
# |    time_elapsed         | 85       |
# |    total_timesteps      | 45824    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0103  |
# |    explained_variance   | 0.162    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00119  |
# |    n_updates            | 1780     |
# |    policy_gradient_loss | 1.68e-09 |
# |    value_loss           | 0.00259  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.432     |
# | time/                   |           |
# |    fps                  | 533       |
# |    iterations           | 180       |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 46080     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0102   |
# |    explained_variance   | 0.018     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00156   |
# |    n_updates            | 1790      |
# |    policy_gradient_loss | -4.03e-09 |
# |    value_loss           | 0.00295   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.435     |
# | time/                   |           |
# |    fps                  | 533       |
# |    iterations           | 181       |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 46336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0102   |
# |    explained_variance   | 0.186     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000864  |
# |    n_updates            | 1800      |
# |    policy_gradient_loss | -7.43e-09 |
# |    value_loss           | 0.00183   |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.435         |
# | time/                   |               |
# |    fps                  | 533           |
# |    iterations           | 182           |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 46592         |
# | train/                  |               |
# |    approx_kl            | 0.00039970712 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00909      |
# |    explained_variance   | -0.00389      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00262      |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | -0.000736     |
# |    value_loss           | 0.00199       |
# -------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.435    |
# | time/                   |          |
# |    fps                  | 533      |
# |    iterations           | 183      |
# |    time_elapsed         | 87       |
# |    total_timesteps      | 46848    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0068  |
# |    explained_variance   | 0.0563   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00094  |
# |    n_updates            | 1820     |
# |    policy_gradient_loss | 5.51e-09 |
# |    value_loss           | 0.00218  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.435        |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 184          |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 6.069429e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00783     |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000947     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -4.55e-06    |
# |    value_loss           | 0.00238      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.437        |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 185          |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 47360        |
# | train/                  |              |
# |    approx_kl            | 0.0002859314 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00678     |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00291     |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000634    |
# |    value_loss           | 0.00123      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.437     |
# | time/                   |           |
# |    fps                  | 533       |
# |    iterations           | 186       |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 47616     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00515  |
# |    explained_variance   | 0.115     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00114   |
# |    n_updates            | 1850      |
# |    policy_gradient_loss | -1.62e-08 |
# |    value_loss           | 0.00259   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.437     |
# | time/                   |           |
# |    fps                  | 533       |
# |    iterations           | 187       |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 47872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00507  |
# |    explained_variance   | -0.0157   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00141   |
# |    n_updates            | 1860      |
# |    policy_gradient_loss | -4.52e-09 |
# |    value_loss           | 0.00325   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.44     |
# | time/                   |          |
# |    fps                  | 534      |
# |    iterations           | 188      |
# |    time_elapsed         | 90       |
# |    total_timesteps      | 48128    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00509 |
# |    explained_variance   | 0.163    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00115  |
# |    n_updates            | 1870     |
# |    policy_gradient_loss | 6.47e-09 |
# |    value_loss           | 0.002    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.44      |
# | time/                   |           |
# |    fps                  | 534       |
# |    iterations           | 189       |
# |    time_elapsed         | 90        |
# |    total_timesteps      | 48384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00516  |
# |    explained_variance   | -0.0196   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000931  |
# |    n_updates            | 1880      |
# |    policy_gradient_loss | -1.46e-10 |
# |    value_loss           | 0.00182   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.44     |
# | time/                   |          |
# |    fps                  | 534      |
# |    iterations           | 190      |
# |    time_elapsed         | 90       |
# |    total_timesteps      | 48640    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00505 |
# |    explained_variance   | 0.0492   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00116  |
# |    n_updates            | 1890     |
# |    policy_gradient_loss | 1.08e-08 |
# |    value_loss           | 0.00235  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 908       |
# |    ep_rew_mean          | 0.44      |
# | time/                   |           |
# |    fps                  | 534       |
# |    iterations           | 191       |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 48896     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00509  |
# |    explained_variance   | 0.0913    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00176   |
# |    n_updates            | 1900      |
# |    policy_gradient_loss | -7.87e-09 |
# |    value_loss           | 0.00332   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.443    |
# | time/                   |          |
# |    fps                  | 534      |
# |    iterations           | 192      |
# |    time_elapsed         | 91       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00509 |
# |    explained_variance   | 0.12     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00072  |
# |    n_updates            | 1910     |
# |    policy_gradient_loss | 6.98e-11 |
# |    value_loss           | 0.00146  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.443        |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 193          |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 49408        |
# | train/                  |              |
# |    approx_kl            | 0.0005154188 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00596     |
# |    explained_variance   | 0.0718       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00124      |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.000409    |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.443    |
# | time/                   |          |
# |    fps                  | 534      |
# |    iterations           | 194      |
# |    time_elapsed         | 92       |
# |    total_timesteps      | 49664    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00656 |
# |    explained_variance   | -0.0277  |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00162  |
# |    n_updates            | 1930     |
# |    policy_gradient_loss | 2.53e-08 |
# |    value_loss           | 0.00352  |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.443        |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 195          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 49920        |
# | train/                  |              |
# |    approx_kl            | 0.0015178542 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00886     |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00119      |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00088     |
# |    value_loss           | 0.00199      |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 908      |
# |    ep_rew_mean          | 0.445    |
# | time/                   |          |
# |    fps                  | 534      |
# |    iterations           | 196      |
# |    time_elapsed         | 93       |
# |    total_timesteps      | 50176    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0105  |
# |    explained_variance   | -0.0861  |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000857 |
# |    n_updates            | 1950     |
# |    policy_gradient_loss | 3.43e-08 |
# |    value_loss           | 0.00188  |
# --------------------------------------

# %% [markdown]
# Model de BTC + GLD

# %%
model_btc_gld_simple = PPO(
    "MlpPolicy",
    env_train_btc_gld_simple,
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    batch_size=64,
    gamma=0.99,
)

model_btc_gld_simple.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 778 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 256 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 512           |
# | train/                  |               |
# |    approx_kl            | 0.00024574692 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -14.6         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00235       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000757     |
# |    value_loss           | 0.0415        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0008337698 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0701      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00599     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 0.0027       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -0.435        |
# | time/                   |               |
# |    fps                  | 577           |
# |    iterations           | 4             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 0.00016779592 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.0305       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00235       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000291     |
# |    value_loss           | 0.00362       |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 908            |
# |    ep_rew_mean          | -0.435         |
# | time/                   |                |
# |    fps                  | 564            |
# |    iterations           | 5              |
# |    time_elapsed         | 2              |
# |    total_timesteps      | 1280           |
# | train/                  |                |
# |    approx_kl            | 0.000107530504 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.1           |
# |    explained_variance   | 0.00543        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.000558       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -0.000413      |
# |    value_loss           | 0.00462        |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -0.435        |
# | time/                   |               |
# |    fps                  | 556           |
# |    iterations           | 6             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00062646717 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0113        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000892     |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000888     |
# |    value_loss           | 0.00366       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.435       |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0009124945 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0372      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00245      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.00194      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.187       |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0025088422 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0164      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.187       |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0035812121 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0137       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 0.00306      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.187      |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.006801695 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0625     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.118      |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.012049605 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00677    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00411     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | -0.118     |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 12         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.00842868 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.0132     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00436   |
# |    value_loss           | 0.00182    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.118       |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 13           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0056532905 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00066      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0227      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 0.00511      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.118       |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 14           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0128015205 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0527      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0167      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00931     |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.179       |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 15           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0036566127 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.00387      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.011       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.179      |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010285532 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.179      |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.003004561 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00561    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0763      |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 18           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0070084073 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.0132       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00584     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 0.00343      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | -0.0763    |
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 19         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.00527166 |
# |    clip_fraction        | 0.00742    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | -0.0126    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000297   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0028    |
# |    value_loss           | 0.00301    |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -0.0763       |
# | time/                   |               |
# |    fps                  | 582           |
# |    iterations           | 20            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00083237444 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.00354       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.013        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000697     |
# |    value_loss           | 0.00374       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0763      |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 21           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0017567391 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0011       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0791     |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 22          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.002052526 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0208     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00124    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 0.00132     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0791      |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 23           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0026096767 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0167       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00762     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 0.00344      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0791      |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 24           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0056772316 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.0261      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.81e-05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 0.00191      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0121      |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 25           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0140057625 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 8.3e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0324      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.00213      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0121      |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 26           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0032233107 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0156       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00668     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 0.00392      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.0121      |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 27           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0015091307 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00111      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00477      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 0.00435      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.0121     |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 28          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.013024337 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0227     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | -0.028     |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 29         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 7424       |
# | train/                  |            |
# |    approx_kl            | 0.00474456 |
# |    clip_fraction        | 0.0648     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.000314  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00173   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00756   |
# |    value_loss           | 0.00116    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -0.028       |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 30           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0012925193 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.00516     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00198     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 0.00408      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.028      |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 31          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.000742465 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0026      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00996    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 0.00279     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.00333    |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 32          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003194781 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0403     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00671    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.00333    |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 33          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.014353716 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0383     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.00333    |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 34          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.016362293 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0395     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -0.00333    |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 35          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009424604 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -0.0246     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00132    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 0.00291     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0737      |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 36          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008576762 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.03        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00696    |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0737      |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 37          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.010471609 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00321    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 0.00313     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.0737      |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 38          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.014300462 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | -0.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00975    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.0737       |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 39           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0118871825 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.00424      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.011       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00777     |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.125      |
# | time/                   |            |
# |    fps                  | 581        |
# |    iterations           | 40         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00823041 |
# |    clip_fraction        | 0.0863     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.679     |
# |    explained_variance   | 0.0156     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00569   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00872   |
# |    value_loss           | 0.00218    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.125        |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 41           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10496        |
# | train/                  |              |
# |    approx_kl            | 0.0024907405 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.00782      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00378      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 0.005        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.125      |
# | time/                   |            |
# |    fps                  | 581        |
# |    iterations           | 42         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 10752      |
# | train/                  |            |
# |    approx_kl            | 0.00483263 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.66      |
# |    explained_variance   | 0.00382    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0251    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00139   |
# |    value_loss           | 0.00305    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.142       |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 43          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.013919666 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | -0.0486     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00708    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.142       |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 44          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.004280498 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | -0.00706    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 0.00478     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 908        |
# |    ep_rew_mean          | 0.142      |
# | time/                   |            |
# |    fps                  | 582        |
# |    iterations           | 45         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 11520      |
# | train/                  |            |
# |    approx_kl            | 0.00515445 |
# |    clip_fraction        | 0.0641     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.64      |
# |    explained_variance   | -0.0154    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0205    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00634   |
# |    value_loss           | 0.00364    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.142        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 46           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0054743644 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.032        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00624     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 0.00348      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 47           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 12032        |
# | train/                  |              |
# |    approx_kl            | 0.0077817226 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | -0.0167      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0262      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 0.00116      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 48           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0010443097 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.00751      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00293     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000718    |
# |    value_loss           | 0.00419      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.163        |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 49           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0017656737 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | -0.000155    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00138      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 0.00191      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.243        |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 50           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0010825191 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.0206       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00955     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.243       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 51          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 13056       |
# | train/                  |             |
# |    approx_kl            | 0.007138468 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | -0.026      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0171     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 0.0026      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.243        |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 52           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0025017099 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | -0.0179      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00214     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.00408      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.243       |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 53          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.006488844 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.00625     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0093     |
# |    value_loss           | 0.00368     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.218       |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 54          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.004518479 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.0082      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00968    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.218        |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 55           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0017313967 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# ...
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 179         |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 45824       |
# | train/                  |             |
# |    approx_kl            | 0.012995497 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.0627      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.00332     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 180          |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0025271534 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00127     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 0.00398      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.398        |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 181          |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 46336        |
# | train/                  |              |
# |    approx_kl            | 0.0094568785 |
# |    clip_fraction        | 0.0867       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.0994       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00812     |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00647     |
# |    value_loss           | 0.00223      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 182         |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 46592       |
# | train/                  |             |
# |    approx_kl            | 0.007546872 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.695      |
# |    explained_variance   | -0.0244     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.398        |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 183          |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 46848        |
# | train/                  |              |
# |    approx_kl            | 0.0058586495 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.642       |
# |    explained_variance   | 0.0337       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00462      |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 0.00279      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 184         |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005382089 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00152     |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.399       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 185         |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.007145278 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0226     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.399        |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 186          |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 47616        |
# | train/                  |              |
# |    approx_kl            | 0.0074530276 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.0612       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0138      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 0.00239      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.399        |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 187          |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 47872        |
# | train/                  |              |
# |    approx_kl            | 0.0038700155 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.0061       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00246      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.00327      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 188         |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.005494848 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.0863      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00221     |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 0.00201     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 189         |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 48384       |
# | train/                  |             |
# |    approx_kl            | 0.006924427 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 190         |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.014261795 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.065       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 0.00268     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 0.398         |
# | time/                   |               |
# |    fps                  | 565           |
# |    iterations           | 191           |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 48896         |
# | train/                  |               |
# |    approx_kl            | 0.00018724566 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.69         |
# |    explained_variance   | 0.0753        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000477      |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -5.55e-05     |
# |    value_loss           | 0.0033        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.397        |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 192          |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 9.231083e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000228    |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 7.19e-05     |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.397       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 193         |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 49408       |
# | train/                  |             |
# |    approx_kl            | 0.007536227 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00667     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00928    |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.397       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 194         |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 49664       |
# | train/                  |             |
# |    approx_kl            | 0.009908276 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | -0.0201     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 0.00356     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 0.397        |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 195          |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 49920        |
# | train/                  |              |
# |    approx_kl            | 0.0018981581 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.35e-05     |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.000545    |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 196         |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.007633142 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | -0.106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00161    |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.00196     |
# -----------------------------------------

# %% [markdown]
# Guardar models

# %%
model_btc_simple.save("../results/model_btc_baseline_simple")
model_btc_gld_simple.save("../results/model_btc_gld_simple")

# %% [markdown]
# Avaluació en Test.
# Retorna Equity Cruve, Rewards, Posicions i Retorns d'Estratègia.

# %%
import numpy as np
import pandas as pd

def evaluate_model(model, env, data_df):
    obs, info = env.reset()

    done = False
    truncated = False

    equity = [1.0]
    rewards = []
    positions = []
    asset_returns = []
    actions = []

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))

        rewards.append(reward)
        actions.append(int(action))
        positions.append(info["position"])
        asset_returns.append(info["asset_return"])

        equity.append(equity[-1] * (1.0 + reward))

    results = pd.DataFrame({
        "reward": rewards,
        "position": positions,
        "asset_return": asset_returns,
        "action": actions,
    }, index=data_df.index[1:1+len(rewards)])

    results["equity"] = equity[1:]
    return results

# %% [markdown]
# Execució en els dos models

# %%
results_btc = evaluate_model(model_btc_simple, env_test_btc_simple, test_btc)
results_btc_gld = evaluate_model(model_btc_gld_simple, env_test_btc_gld_simple, test_btc_gld)

results_btc.head(), results_btc_gld.head()
# Out:
# (                             reward  position  asset_return  action    equity
#  Datetime
#  2025-12-03 20:00:00+00:00 -0.001096         1     -0.001096       1  0.998904
#  2025-12-04 12:00:00+00:00  0.001011         1      0.001011       1  0.999913
#  2025-12-04 16:00:00+00:00 -0.010522         1     -0.010522       1  0.989392
#  2025-12-04 20:00:00+00:00  0.005439         1      0.005439       1  0.994773
#  2025-12-05 12:00:00+00:00 -0.023877         1     -0.023877       1  0.971022,
#                               reward  position  asset_return  action    equity
#  Datetime
#  2025-12-03 20:00:00+00:00 -0.001096         1     -0.001096       1  0.998904
#  2025-12-04 12:00:00+00:00  0.001011         1      0.001011       0  0.999913
#  2025-12-04 16:00:00+00:00 -0.010522         1     -0.010522       0  0.989392
#  2025-12-04 20:00:00+00:00  0.005439         1      0.005439       0  0.994773
#  2025-12-05 12:00:00+00:00 -0.023877         1     -0.023877       0  0.971022)

# %%
results_btc["action"].value_counts()
results_btc_gld["action"].value_counts()
# Out:
# action
# 0    226
# 1      1
# Name: count, dtype: int64

# %% [markdown]
# Funció de mètriques bàsiques

# %%
def compute_metrics(results_df, periods_per_year=252*2):
    rets = results_df["reward"].dropna()

    cumulative_return = (1 + rets).prod() - 1

    mean_ret = rets.mean()
    vol = rets.std()

    sharpe = np.nan
    if vol > 0:
        sharpe = (mean_ret / vol) * np.sqrt(periods_per_year)

    downside = rets[rets < 0].std()
    sortino = np.nan
    if downside > 0:
        sortino = (mean_ret / downside) * np.sqrt(periods_per_year)

    equity = results_df["equity"]
    running_max = equity.cummax()
    drawdown = equity / running_max - 1
    max_drawdown = drawdown.min()

    position_changes = results_df["position"].diff().fillna(0)
    initial_trade = 1 if results_df["position"].iloc[0] != 0 else 0
    n_trades = int((position_changes != 0).sum() + initial_trade)

    return {
        "cumulative_return": cumulative_return,
        "sharpe": sharpe,
        "sortino": sortino,
        "max_drawdown": max_drawdown,
        "n_trades": int(n_trades),
    }

# %% [markdown]
# Aplicació de la funció de mètriques

# %%
metrics_btc = compute_metrics(results_btc)
metrics_btc_gld = compute_metrics(results_btc_gld)

metrics_btc, metrics_btc_gld
# Out:
# ({'cumulative_return': np.float64(-0.2794302699733491),
#   'sharpe': np.float64(-1.5331251353365956),
#   'sortino': np.float64(-2.035742509494925),
#   'max_drawdown': np.float64(-0.3488435255314791),
#   'n_trades': 1},
#  {'cumulative_return': np.float64(-0.2794302699733491),
#   'sharpe': np.float64(-1.5331251353365956),
#   'sortino': np.float64(-2.035742509494925),
#   'max_drawdown': np.float64(-0.3488435255314791),
#   'n_trades': 1})

# %% [markdown]
# Taula comparativa

# %%
comparison = pd.DataFrame([metrics_btc, metrics_btc_gld], index=["BTC", "BTC+GLD"])
comparison
# Out:
#          cumulative_return    sharpe   sortino  max_drawdown  n_trades
# BTC               -0.27943 -1.533125 -2.035743     -0.348844         1
# BTC+GLD           -0.27943 -1.533125 -2.035743     -0.348844         1

# %% [markdown]
# Gràfica d'Equity

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(results_btc.index, results_btc["equity"], label="BTC")
plt.plot(results_btc_gld.index, results_btc_gld["equity"], label="BTC+GLD")
plt.title("Equity Curve on Test Set")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Comparació contra buy-and-hold

# %%
buy_hold_ret = test_btc["btc_close"].iloc[-1] / test_btc["btc_close"].iloc[0] - 1
print("Buy & Hold return:", buy_hold_ret)
# Out:
# Buy & Hold return: -0.2794302699733495

# %% [markdown]
# Veure accions dels dos models per separat

# %%
print("BTC actions:")
print(results_btc["action"].value_counts())

print("\nBTC+GLD actions:")
print(results_btc_gld["action"].value_counts())

print("\nBTC positions:")
print(results_btc["position"].value_counts())

print("\nBTC+GLD positions:")
print(results_btc_gld["position"].value_counts())
# Out:
# BTC actions:
# action
# 1    227
# Name: count, dtype: int64
#
# BTC+GLD actions:
# action
# 0    226
# 1      1
# Name: count, dtype: int64
#
# BTC positions:
# position
# 1    227
# Name: count, dtype: int64
#
# BTC+GLD positions:
# position
# 1    227
# Name: count, dtype: int64

# %%
print("Difference:", (results_btc["equity"] - results_btc_gld["equity"]).abs().sum())
# Out:
# Difference: 0.0

# %%
print(results_btc["asset_return"].head())
print(results_btc_gld["asset_return"].head())
# Out:
# Datetime
# 2025-12-03 20:00:00+00:00   -0.001096
# 2025-12-04 12:00:00+00:00    0.001011
# 2025-12-04 16:00:00+00:00   -0.010522
# 2025-12-04 20:00:00+00:00    0.005439
# 2025-12-05 12:00:00+00:00   -0.023877
# Name: asset_return, dtype: float64
# Datetime
# 2025-12-03 20:00:00+00:00   -0.001096
# 2025-12-04 12:00:00+00:00    0.001011
# 2025-12-04 16:00:00+00:00   -0.010522
# 2025-12-04 20:00:00+00:00    0.005439
# 2025-12-05 12:00:00+00:00   -0.023877
# Name: asset_return, dtype: float64

# %%
print(env_test_btc_simple.price_column)
print(env_test_btc_gld_simple.price_column)
# Out:
# btc_close
# btc_close
